# %% [markdown]
# # Lab 2: Policy Gradient Methods
#
# ## TDDE78 — Deep Reinforcement Learning
# ### Linköping University, Spring 2026
#
# ---
#
# In this lab you will implement two foundational policy gradient algorithms:
# - **REINFORCE** (Williams, 1992) — episodic Monte Carlo policy gradient with optional value baseline
# - **PPO** (Schulman et al., 2017) — proximal policy optimization with clipped surrogate objective and GAE
#
# The lab is divided into:
# - **Part A** — Implementation (fill in the TODO sections)
# - **Part B** — Experiments (run systematic evaluations and analyze results)
#
# **Instructions:** Complete all cells marked with `# TODO`. Do not modify the provided helper code unless explicitly asked.

# %% [markdown]
# ## Setup
#
# Run the cell below to import all necessary libraries and verify your environment.

# %%
import os
import sys
import numpy as np
import random
import torch
import torch.nn as nn
import torch.optim as optim
import torch.nn.functional as F
import gymnasium as gym
import matplotlib.pyplot as plt
from IPython.display import Video, display
import warnings
warnings.filterwarnings('ignore')

# Import lab utilities
from networks import DiscreteActorCritic
from utils import compute_returns, compute_gae, RolloutBuffer

# Device
device = torch.device('cuda' if torch.cuda.is_available() else 'cpu')
print(f'Using device: {device}')

# Resolve experiments directory relative to this notebook
_here = globals().get('__vsc_ipynb_file__', os.path.abspath(''))
_nb_dir = os.path.dirname(_here) if os.path.isfile(_here) else _here
EXPERIMENTS_DIR = os.path.normpath(os.path.join(_nb_dir, '..', 'experiments'))
print(f'Experiments directory: {EXPERIMENTS_DIR}')

def set_seed(seed=42):
    random.seed(seed)
    np.random.seed(seed)
    torch.manual_seed(seed)
    if torch.cuda.is_available():
        torch.cuda.manual_seed(seed)

set_seed(42)
print('Setup complete!')
# Out:
# Using device: cpu
# Experiments directory: /Users/dennisjohansson/Skola/Programering/VT4/TDDE78/tdde78lab/labs/lab2_policy_gradient/experiments
# Setup complete!

# %% [markdown]
# ---
#
# # Part A — Implementation
#
# ---

# %% [markdown]
# ## A.1 — Explore the Environment
#
# Before implementing the algorithms, let's understand the environment we will work with.
#
# **CartPole-v1** — balance a pole on a cart by pushing left or right (discrete actions).

# %%
env_cp = gym.make('CartPole-v1')
print('=== CartPole-v1 ===')
print(f'  Observation space: {env_cp.observation_space}  shape={env_cp.observation_space.shape}')
print(f'  Action space:      {env_cp.action_space}')
obs, _ = env_cp.reset(seed=42)
print(f'  Sample obs: {obs}')
env_cp.close()
# Out:
# === CartPole-v1 ===
#   Observation space: Box([-4.8               -inf -0.41887903        -inf], [4.8               inf 0.41887903        inf], (4,), float32)  shape=(4,)
#   Action space:      Discrete(2)
#   Sample obs: [ 0.0273956  -0.00611216  0.03585979  0.0197368 ]

# %% [markdown]
# ## A.2 — Actor-Critic Network
#
# Open `networks.py` and implement `DiscreteActorCritic`.
#
# It uses a **shared backbone** (2-layer MLP with Tanh) with separate **policy** and **value** heads:
#
# ```
# state → Linear(64) → Tanh → Linear(64) → Tanh → [features]
#                                                     ├── policy_head → logits (Categorical)
#                                                     └── value_head  → V(s)
# ```
#
# After implementing, run the test below.

# %%
# Test DiscreteActorCritic
from networks import DiscreteActorCritic

net_d = DiscreteActorCritic(state_dim=4, action_dim=2).to(device)
test_state = torch.randn(8, 4).to(device)
action, log_prob, entropy, value = net_d.get_action(test_state)

assert action.shape == (8,),    f'action shape should be (8,), got {action.shape}'
assert log_prob.shape == (8,),  f'log_prob shape should be (8,), got {log_prob.shape}'
assert entropy.shape == (8,),   f'entropy shape should be (8,), got {entropy.shape}'
assert value.shape == (8, 1),   f'value shape should be (8, 1), got {value.shape}'

# Test that providing an action gives the correct log_prob
fixed_action = torch.zeros(8, dtype=torch.long).to(device)
_, lp_fixed, _, _ = net_d.get_action(test_state, fixed_action)
assert lp_fixed.shape == (8,)

n_params = sum(p.numel() for p in net_d.parameters())
print(f'DiscreteActorCritic: action={action.shape}, log_prob={log_prob.shape}, '
      f'entropy={entropy.shape}, value={value.shape}, params={n_params:,}')
print('DiscreteActorCritic test passed!')
# Out:
# DiscreteActorCritic: action=torch.Size([8]), log_prob=torch.Size([8]), entropy=torch.Size([8]), value=torch.Size([8, 1]), params=4,675
# DiscreteActorCritic test passed!

# %% [markdown]
# ## A.3 — Utility Functions
#
# `utils.py` is fully provided — no implementation needed.
#
# It contains:
# - `compute_returns(rewards, gamma)` — Monte Carlo discounted returns
# - `compute_gae(rewards, values, dones, last_value, gamma, gae_lambda)` — GAE advantages
# - `RolloutBuffer` — rollout storage with GAE computation and mini-batch sampling
#
# Run the tests below to verify the utilities work correctly.

# %%
# Test compute_returns
from utils import compute_returns

# Simple episode: [1, 1, 1] with gamma=0.99
# G_0 = 1 + 0.99 + 0.99^2 = 2.9701
# G_1 = 1 + 0.99           = 1.99
# G_2 = 1
test_rewards = [1.0, 1.0, 1.0]
returns = compute_returns(test_rewards, gamma=0.99)

assert returns.shape == (3,), f'Expected shape (3,), got {returns.shape}'
assert returns.dtype == np.float32, f'Expected float32, got {returns.dtype}'
assert abs(returns[2] - 1.0) < 1e-5, f'G_2 should be 1.0, got {returns[2]}'
assert abs(returns[1] - 1.99) < 1e-4, f'G_1 should be 1.99, got {returns[1]}'
assert abs(returns[0] - 2.9701) < 1e-4, f'G_0 should be 2.9701, got {returns[0]}'
print(f'compute_returns: {returns}  (expected [2.970, 1.990, 1.000])')
print('compute_returns test passed!')
# Out:
# compute_returns: [2.9701 1.99   1.    ]  (expected [2.970, 1.990, 1.000])
# compute_returns test passed!

# %%
# Test compute_gae
from utils import compute_gae

rewards = [1.0, 1.0, 1.0]
values  = [0.5, 0.5, 0.5]
dones   = [False, False, True]  # episode ends at last step
advantages, returns = compute_gae(rewards, values, dones,
                                   last_value=0.0, gamma=0.99, gae_lambda=0.95)

assert advantages.shape == (3,), f'Expected shape (3,), got {advantages.shape}'
assert returns.shape == (3,),    f'Expected shape (3,), got {returns.shape}'
assert advantages.dtype == np.float32
# Returns should be close to advantages + values
np.testing.assert_allclose(returns, advantages + np.array(values, dtype=np.float32), rtol=1e-5)
print(f'advantages: {advantages}')
print(f'returns:    {returns}')
print('compute_gae test passed!')
# Out:
# advantages: [2.3730676 1.46525   0.5      ]
# returns:    [2.8730676 1.96525   1.       ]
# compute_gae test passed!

# %%
# Test RolloutBuffer
from utils import RolloutBuffer

buf = RolloutBuffer(n_steps=100, state_dim=4, action_dim=2, is_continuous=False)

for i in range(60):
    state    = np.random.randn(4).astype(np.float32)
    action   = np.random.randint(0, 2)
    reward   = float(np.random.randn())
    done     = (i % 20 == 19)
    log_prob = float(np.random.randn())
    value    = float(np.random.randn())
    buf.store(state, action, reward, done, log_prob, value)

assert len(buf) == 60, f'Expected 60, got {len(buf)}'

buf.compute_returns_and_advantages(last_value=0.0, gamma=0.99, gae_lambda=0.95)
assert buf.advantages is not None, 'advantages not set'
assert buf.returns is not None,    'returns not set'

batches = list(buf.get_batches(batch_size=16))
assert len(batches) >= 3, f'Expected >=3 batches, got {len(batches)}'
states_b, actions_b, log_probs_b, advs_b, rets_b, old_vals_b = batches[0]
assert states_b.shape[1] == 4,        f'State dim should be 4, got {states_b.shape[1]}'
assert actions_b.dtype == torch.int64, f'Discrete actions should be int64'
print(f'Batch shapes: states={states_b.shape}, actions={actions_b.shape}, '
      f'adv={advs_b.shape}, returns={rets_b.shape}')
print('RolloutBuffer test passed!')
# Out:
# Batch shapes: states=torch.Size([16, 4]), actions=torch.Size([16]), adv=torch.Size([16]), returns=torch.Size([16])
# RolloutBuffer test passed!

# %% [markdown]
# ## A.4 — REINFORCE Agent
#
# Implement the REINFORCE agent below.
#
# The agent collects **complete episodes** and updates the policy using:
#
# **With baseline** (`use_baseline=True`):
# $$\mathcal{L}(\theta) = -\frac{1}{T} \sum_t \log \pi_\theta(a_t \mid s_t) \cdot \hat{A}_t + c_V \cdot \mathcal{L}_V$$
# where $\hat{A}_t = G_t - V(s_t)$ and $\mathcal{L}_V = \text{MSE}(V(s_t),\, G_t)$.
#
# **Without baseline** (`use_baseline=False`):
# $$\mathcal{L}(\theta) = -\frac{1}{T} \sum_t \log \pi_\theta(a_t \mid s_t) \cdot G_t$$
# No value loss — $c_V \cdot \mathcal{L}_V = 0$.

# %%
class REINFORCEAgent:
    """
    REINFORCE agent with optional learned baseline.

    Args:
        state_dim    (int):   Dimension of state space.
        action_dim   (int):   Number of discrete actions.
        lr           (float): Learning rate.
        gamma        (float): Discount factor.
        use_baseline (bool):  If True, subtract V(s_t) from returns.
        value_coef   (float): Coefficient for value loss.
        seed         (int):   Random seed.
    """

    def __init__(self, state_dim, action_dim, lr=1e-3, gamma=0.99,
                 use_baseline=True, value_coef=0.5, seed=42):
        self.gamma = gamma
        self.use_baseline = use_baseline
        self.value_coef = value_coef

        # =====================================================================
        # TODO: Initialize the network and optimizer.
        #   - Create a DiscreteActorCritic network and move it to device.
        #   - Create an Adam optimizer for the network parameters.
        # =====================================================================
        self.network = DiscreteActorCritic(state_dim, action_dim).to(device)
        self.optimizer = optim.Adam(self.network.parameters(), lr=lr)

    def select_action(self, state):
        """Sample an action stochastically (no gradient)."""
        # =====================================================================
        # TODO: Select an action without computing gradients.
        #   - Convert the numpy state to a float tensor and add a batch dimension.
        #   - Use torch.no_grad() when calling the network — we are collecting
        #     data, not training.
        #   - Return the action and its log probability as Python scalars.
        # =====================================================================
        state_t = torch.FloatTensor(state).unsqueeze(0).to(device)

        with torch.no_grad():
            action, log_prob, _, _ = self.network.get_action(state_t)
        return action.item(), log_prob.item()

    def update(self, states, actions, rewards):
        """
        Perform one gradient update on a complete episode.

        Returns:
            pg_loss (float), value_loss (float)
        """
        # =====================================================================
        # TODO: Implement the REINFORCE gradient update.
        #
        # Step 1 — Compute discounted returns.
        #   Use compute_returns() to get G_t for each timestep.
        #   Convert to a float tensor. Also compute a normalized copy of the
        #   returns for stable value function training (zero mean, unit std).
        #   Skip normalization if the episode has only one step.
        #
        # Step 2 — Re-evaluate actions under the current policy WITH gradients.
        #   Convert states and actions to tensors, then call get_action() so
        #   that log_probs and values are part of the computation graph.
        #   Squeeze the value head output to remove the trailing dimension.
        #
        # Step 3 — Compute advantages and value loss.
        #   If use_baseline=True:
        #     Advantage = raw return minus the value baseline (detached).
        #     Normalize the advantages for gradient stability.
        #     Value loss = MSE between predicted values and normalized returns.
        #   If use_baseline=False:
        #     Advantage = normalized returns (no baseline subtraction).
        #     Value loss = 0  (the value head is not trained).
        #
        # Step 4 — Policy gradient loss.
        #   L_pg = -mean( log_prob * advantage )  over all timesteps.
        #
        # Step 5 — Total loss and optimizer step.
        #   Combine policy loss and value loss, backpropagate, clip gradients
        #   (max norm 0.5), and step the optimizer.
        #   Return both losses as Python floats.
        # =====================================================================
        # Step 1
        returns_np = compute_returns(rewards, self.gamma)
        returns = torch.FloatTensor(returns_np).to(device)

        returns_norm = returns
        if len(returns) > 1:
            returns_norm = (returns - returns.mean()) / (returns.std() + 1e-8)

        # Step 2
        states_t = torch.FloatTensor(np.array(states)).to(device)
        actions_t = torch.LongTensor(actions).to(device)
        _, log_probs, _, values = self.network.get_action(states_t, actions_t)
        values = values.squeeze(-1)

        # Step 3
        if self.use_baseline:
            advantages = returns - values.detach()
            if len(advantages) > 1:
                advantages = (advantages - advantages.mean()) / (advantages.std() + 1e-8)
            value_loss = F.mse_loss(values, returns_norm)
        else:
            advantages = returns_norm
            value_loss = torch.tensor(0.0, device=device)

        # Step 4
        pg_loss = -(log_probs * advantages).mean()

        # Step 5
        total_loss = pg_loss + self.value_coef * value_loss
        self.optimizer.zero_grad()
        total_loss.backward()
        torch.nn.utils.clip_grad_norm_(self.network.parameters(), max_norm=0.5)
        self.optimizer.step()

        return pg_loss.item(), value_loss.item()

print("REINFORCEAgent class defined!")
# Out:
# REINFORCEAgent class defined!

# %% [markdown]
# ## A.5 — REINFORCE Training Loop
#
# Implement the full training loop for REINFORCE. The loop collects one **complete episode** per iteration and calls `agent.update()` at the end.

# %%
def train_reinforce(env_name='CartPole-v1', num_episodes=600, lr=1e-3,
                    gamma=0.99, use_baseline=True, value_coef=0.5,
                    seed=42, solve_threshold=None):
    """
    Train a REINFORCE agent.

    Args:
        env_name        (str):   Gymnasium environment name.
        num_episodes    (int):   Maximum number of training episodes.
        lr              (float): Learning rate.
        gamma           (float): Discount factor.
        use_baseline    (bool):  Whether to use the value baseline.
        value_coef      (float): Coefficient for value loss.
        seed            (int):   Random seed.
        solve_threshold (float): Stop early when avg reward (last 100 eps) >= this.

    Returns:
        dict with keys: episode_rewards, episode_lengths, pg_losses, value_losses, agent
    """
    set_seed(seed)
    env = gym.make(env_name)
    state_dim  = env.observation_space.shape[0]
    action_dim = env.action_space.n

    agent = REINFORCEAgent(state_dim, action_dim, lr=lr, gamma=gamma,
                           use_baseline=use_baseline, value_coef=value_coef, seed=seed)

    episode_rewards, episode_lengths, pg_losses, value_losses = [], [], [], []

    # =========================================================================
    # TODO: Implement the REINFORCE episode loop.
    #
    # For each episode:
    #   1. Reset the environment with a per-episode seed for reproducibility.
    #   2. Collect a full episode by stepping through the environment:
    #        select an action, observe the next state and reward, and record
    #        states, actions, and rewards until the episode terminates.
    #   3. Call agent.update() on the collected episode data.
    #   4. Track episode reward, episode length, and both losses.
    #   5. Print a progress summary every 50 episodes (average reward and loss).
    #   6. Stop early if the rolling average over the last 100 episodes
    #      reaches solve_threshold (when solve_threshold is not None).
    # =========================================================================
    for episode in range(num_episodes):
        state, _ = env.reset(seed=seed + episode)
        done = False
        states, actions, rewards = [], [], []
        episode_reward = 0.0
        episode_length = 0

        while not done:
            action, _ = agent.select_action(state)
            next_state, reward, terminated, truncated, _ = env.step(action)
            done = terminated or truncated
            states.append(state)
            actions.append(action)
            rewards.append(reward)
            episode_reward += reward
            episode_length += 1
            state = next_state

        pg_loss, value_loss = agent.update(states, actions, rewards)
        episode_rewards.append(episode_reward)
        episode_lengths.append(episode_length)
        pg_losses.append(pg_loss)
        value_losses.append(value_loss)

        if (episode + 1) % 50 == 0:
            avg_reward = np.mean(episode_rewards[-50:])
            avg_pg_loss = np.mean(pg_losses[-50:])
            avg_value_loss = np.mean(value_losses[-50:])
            print(
                f"Episode {episode + 1}/{num_episodes} | "
                f"AvgReward(50)={avg_reward:.2f} | "
                f"PGLoss={avg_pg_loss:.4f} | "
                f"ValueLoss={avg_value_loss:.4f}"
            )

        if solve_threshold is not None and len(episode_rewards) >= 100:
            if np.mean(episode_rewards[-100:]) >= solve_threshold:
                print(
                    f"Solved in {episode + 1} episodes! "
                    f"AvgReward(100)={np.mean(episode_rewards[-100:]):.2f}"
                )
                break

    env.close()
    return {'episode_rewards': episode_rewards, 'episode_lengths': episode_lengths,
            'pg_losses': pg_losses, 'value_losses': value_losses, 'agent': agent}

print("train_reinforce defined!")
# Out:
# train_reinforce defined!

# %% [markdown]
# ## A.6 — Plotting Utilities
#
# Helper functions for visualizing training results. No changes needed here.

# %%
def _save_plot(fig, title):
    try:
        plots_dir = os.path.join(EXPERIMENTS_DIR, 'plots')
        os.makedirs(plots_dir, exist_ok=True)
        fname = title.lower().replace(' ', '_').replace('/', '_').replace('—', '').replace(':', '').strip('_') + '.png'
        fig.savefig(os.path.join(plots_dir, fname), dpi=150, bbox_inches='tight')
        print(f'Plot saved: {os.path.join(plots_dir, fname)}')
    except Exception as e:
        print(f'Could not save plot: {e}')


def plot_reinforce_results(results, title='REINFORCE Training', window=50):
    """Plot REINFORCE training curves (episode-based)."""
    fig, axes = plt.subplots(1, 3, figsize=(18, 5))
    rewards = results['episode_rewards']

    axes[0].plot(rewards, alpha=0.3, color='blue', label='Raw')
    if len(rewards) >= window:
        ma = np.convolve(rewards, np.ones(window) / window, mode='valid')
        axes[0].plot(range(window - 1, len(rewards)), ma, color='blue', label=f'{window}-ep avg')
    axes[0].set_xlabel('Episode'); axes[0].set_ylabel('Reward')
    axes[0].set_title(f'{title} — Episode Rewards'); axes[0].legend(); axes[0].grid(True, alpha=0.3)

    axes[1].plot(results['pg_losses'], alpha=0.5, color='red')
    axes[1].set_xlabel('Episode'); axes[1].set_ylabel('Policy Loss')
    axes[1].set_title(f'{title} — Policy Gradient Loss'); axes[1].grid(True, alpha=0.3)

    axes[2].plot(results['value_losses'], alpha=0.5, color='green')
    axes[2].set_xlabel('Episode'); axes[2].set_ylabel('Value Loss')
    axes[2].set_title(f'{title} — Value Loss'); axes[2].grid(True, alpha=0.3)

    plt.tight_layout()
    _save_plot(fig, title)
    plt.show()


def plot_ppo_results(results, title='PPO Training', window=20):
    """Plot PPO training curves (update-based)."""
    fig, axes = plt.subplots(1, 3, figsize=(18, 5))
    rewards = results['update_rewards']

    axes[0].plot(rewards, alpha=0.4, color='blue', label='Eval reward')
    if len(rewards) >= window:
        ma = np.convolve(rewards, np.ones(window) / window, mode='valid')
        axes[0].plot(range(window - 1, len(rewards)), ma, color='blue', label=f'{window}-update avg')
    axes[0].set_xlabel('PPO Update'); axes[0].set_ylabel('Reward')
    axes[0].set_title(f'{title} — Eval Reward'); axes[0].legend(); axes[0].grid(True, alpha=0.3)

    axes[1].plot(results['policy_losses'], alpha=0.5, color='red')
    axes[1].set_xlabel('PPO Update'); axes[1].set_ylabel('Policy Loss')
    axes[1].set_title(f'{title} — Policy Loss'); axes[1].grid(True, alpha=0.3)

    axes[2].plot(results['entropies'], alpha=0.5, color='purple')
    axes[2].set_xlabel('PPO Update'); axes[2].set_ylabel('Entropy')
    axes[2].set_title(f'{title} — Policy Entropy'); axes[2].grid(True, alpha=0.3)

    plt.tight_layout()
    _save_plot(fig, title)
    plt.show()


def plot_comparison(all_results, title='Comparison', window=50, x_label='Episode', reward_key='episode_rewards'):
    """Plot reward comparison across methods/seeds (mean ± std)."""
    fig, ax = plt.subplots(figsize=(10, 6))
    colors = ['blue', 'red', 'green', 'orange', 'purple']

    for idx, (name, results_list) in enumerate(all_results.items()):
        color = colors[idx % len(colors)]
        min_len = min(len(r[reward_key]) for r in results_list)
        all_rewards = np.array([r[reward_key][:min_len] for r in results_list])

        if min_len >= window:
            smoothed = np.array([np.convolve(row, np.ones(window) / window, mode='valid')
                                 for row in all_rewards])
            mean, std = smoothed.mean(axis=0), smoothed.std(axis=0)
            x = range(window - 1, min_len)
        else:
            mean, std = all_rewards.mean(axis=0), all_rewards.std(axis=0)
            x = range(min_len)

        ax.plot(x, mean, color=color, label=name)
        ax.fill_between(x, mean - std, mean + std, color=color, alpha=0.15)

    ax.set_xlabel(x_label); ax.set_ylabel('Reward'); ax.set_title(title)
    ax.legend(); ax.grid(True, alpha=0.3)
    plt.tight_layout()
    _save_plot(fig, title)
    plt.show()

print('Plotting utilities defined!')
# Out:
# Plotting utilities defined!

# %% [markdown]
# ## A.7 — Train REINFORCE on CartPole-v1
#
# Verify your REINFORCE implementation. The agent should reach average reward ≥ 475 within ~600 episodes.

# %%
set_seed(42)
results_rf = train_reinforce(
    env_name='CartPole-v1',
    num_episodes=2000,
    lr=1e-3,
    use_baseline=True,
    solve_threshold=475,
    seed=42,
)

plot_reinforce_results(results_rf, title='REINFORCE on CartPole-v1')

avg = np.mean(results_rf['episode_rewards'][-100:])
print(f'\nAverage reward (last 100 eps): {avg:.1f}')
print('CartPole SOLVED!' if avg >= 475 else 'Not yet solved — check your implementation.')
# Out:
# Episode 50/2000 | AvgReward(50)=24.36 | PGLoss=-0.0011 | ValueLoss=0.9992
# Episode 100/2000 | AvgReward(50)=26.90 | PGLoss=0.0002 | ValueLoss=0.9652
# Episode 150/2000 | AvgReward(50)=32.72 | PGLoss=-0.0076 | ValueLoss=0.9142
# Episode 200/2000 | AvgReward(50)=53.78 | PGLoss=-0.0011 | ValueLoss=1.0775
# Episode 250/2000 | AvgReward(50)=82.32 | PGLoss=-0.0036 | ValueLoss=1.0725
# Episode 300/2000 | AvgReward(50)=143.42 | PGLoss=-0.0211 | ValueLoss=1.0863
# Episode 350/2000 | AvgReward(50)=216.52 | PGLoss=-0.0125 | ValueLoss=1.0629
# Episode 400/2000 | AvgReward(50)=250.68 | PGLoss=-0.0128 | ValueLoss=1.1392
# Episode 450/2000 | AvgReward(50)=250.32 | PGLoss=-0.0135 | ValueLoss=0.6972
# Episode 500/2000 | AvgReward(50)=295.48 | PGLoss=-0.0033 | ValueLoss=1.2326
# Episode 550/2000 | AvgReward(50)=248.38 | PGLoss=-0.0104 | ValueLoss=0.5013
# Episode 600/2000 | AvgReward(50)=372.98 | PGLoss=-0.0110 | ValueLoss=0.9349
# Episode 650/2000 | AvgReward(50)=427.28 | PGLoss=-0.0062 | ValueLoss=0.7675
# Episode 700/2000 | AvgReward(50)=434.00 | PGLoss=-0.0016 | ValueLoss=0.7675
# Episode 750/2000 | AvgReward(50)=372.14 | PGLoss=-0.0041 | ValueLoss=0.5224
# Episode 800/2000 | AvgReward(50)=441.16 | PGLoss=-0.0020 | ValueLoss=0.8291
# Episode 850/2000 | AvgReward(50)=397.84 | PGLoss=-0.0033 | ValueLoss=0.7610
# Episode 900/2000 | AvgReward(50)=448.32 | PGLoss=-0.0015 | ValueLoss=0.7998
# Episode 950/2000 | AvgReward(50)=362.20 | PGLoss=-0.0044 | ValueLoss=0.3943
# Episode 1000/2000 | AvgReward(50)=349.74 | PGLoss=-0.0072 | ValueLoss=0.5119
# Episode 1050/2000 | AvgReward(50)=454.04 | PGLoss=-0.0008 | ValueLoss=0.9494
# Episode 1100/2000 | AvgReward(50)=470.34 | PGLoss=-0.0060 | ValueLoss=0.8584
# Solved in 1112 episodes! AvgReward(100)=476.16
# Plot saved: /Users/dennisjohansson/Skola/Programering/VT4/TDDE78/tdde78lab/labs/lab2_policy_gradient/experiments/plots/reinforce_on_cartpole-v1.png
# Average reward (last 100 eps): 476.2
# CartPole SOLVED!

# %% [markdown]
# ## Visualise — REINFORCE Agent on CartPole-v1

# %%
def record_video(agent, env_name, video_dir, episode_trigger=lambda ep: ep == 0, seed=42):
    """Record one episode of the agent and return the video path."""
    os.makedirs(video_dir, exist_ok=True)
    env = gym.make(env_name, render_mode='rgb_array')
    env = gym.wrappers.RecordVideo(env, video_folder=video_dir,
                                   episode_trigger=episode_trigger,
                                   disable_logger=True)
    obs, _ = env.reset(seed=seed)
    ep_reward = 0.0
    for _ in range(10000):
        state_t = torch.FloatTensor(obs).unsqueeze(0).to(device)
        with torch.no_grad():
            action, _, _, _ = agent.network.get_action(state_t)
        action_np = action.cpu().numpy().squeeze(0)
        obs, reward, terminated, truncated, _ = env.step(int(action_np))
        ep_reward += reward
        if terminated or truncated:
            break
    env.close()
    print(f'Episode reward: {ep_reward:.1f}')
    videos = sorted([f for f in os.listdir(video_dir) if f.endswith('.mp4')])
    return os.path.join(video_dir, videos[-1]) if videos else None


video_dir = os.path.join(EXPERIMENTS_DIR, 'videos', 'reinforce_cartpole')
video_path = record_video(results_rf['agent'], 'CartPole-v1', video_dir, seed=42)

if video_path:
    display(Video(video_path, embed=True, width=400))
else:
    print('No video found — check that ffmpeg is installed (sudo apt install ffmpeg).')
# Out:
# Episode reward: 500.0
# <video controls  width="400" >
#  <source src="data:video/mp4;base64,..." type="video/mp4">
#  Your browser does not support the video tag.
#  </video>

# %% [markdown]
# ## A.8 — PPO Agent
#
# Implement the PPO agent. This is the core of the lab.
#
# PPO operates in a **collect → update** cycle:
# 1. **collect_rollout**: gather `n_steps` transitions using the current policy, then compute GAE
# 2. **update**: run `n_epochs` passes over the rollout data with the clipped PPO objective
#
# $$L^{\text{CLIP}}(\theta) = \mathbb{E}_t \left[ \min\left( r_t(\theta) A_t, \; \text{clip}(r_t(\theta), 1-\varepsilon, 1+\varepsilon) A_t \right) \right]$$

# %%
class PPOAgent:
    """
    PPO agent for discrete action spaces (CartPole-v1).

    Implements PPO-Clip (Schulman et al., 2017) with:
    - Clipped surrogate objective
    - GAE advantage estimation
    - Advantage normalization per mini-batch
    - Value loss clipping
    - Entropy bonus for exploration
    - Gradient norm clipping
    - Env state carried between rollouts (CleanRL-style)

    Args:
        state_dim     (int):   Dimension of state space.
        action_dim    (int):   Number of discrete actions.
        lr            (float): Learning rate.
        gamma         (float): Discount factor.
        gae_lambda    (float): GAE lambda (0=TD, 1=MC).
        clip_eps      (float): PPO clipping parameter epsilon.
        n_epochs      (int):   Update epochs per rollout.
        batch_size    (int):   Mini-batch size.
        value_coef    (float): Weight for value loss.
        entropy_coef  (float): Weight for entropy bonus.
        n_steps       (int):   Environment steps per rollout.
        max_grad_norm (float): Gradient clipping threshold.
        seed          (int):   Random seed.
    """

    def __init__(self, state_dim, action_dim,
                 lr=2.5e-4, gamma=0.99, gae_lambda=0.95, clip_eps=0.2,
                 n_epochs=4, batch_size=64, value_coef=0.5, entropy_coef=0.01,
                 n_steps=512, max_grad_norm=0.5, seed=42):
        self.gamma = gamma
        self.gae_lambda = gae_lambda
        self.clip_eps = clip_eps
        self.n_epochs = n_epochs
        self.batch_size = batch_size
        self.value_coef = value_coef
        self.entropy_coef = entropy_coef
        self.n_steps = n_steps
        self.max_grad_norm = max_grad_norm

        # =====================================================================
        # TODO: Initialize the buffer, network, and optimizer.
        #   - Create a RolloutBuffer for discrete actions (is_continuous=False).
        #   - Create a DiscreteActorCritic network and move it to device.
        #   - Create an Adam optimizer with eps=1e-5 (CleanRL standard).
        #   - Set self.obs = None  (will be initialized by train_ppo).
        # =====================================================================
        self.buffer = RolloutBuffer(n_steps, state_dim, action_dim, is_continuous=False)
        self.network = DiscreteActorCritic(state_dim, action_dim).to(device)
        self.optimizer = optim.Adam(self.network.parameters(), lr=lr, eps=1e-5)
        self.obs = None

    def select_action(self, state):
        """
        Sample an action from the current policy (no gradient).

        Returns:
            action_np (np.ndarray): Sampled action as numpy scalar.
            log_prob  (float):      Log probability of the action.
            value     (float):      State value estimate V(s).
        """
        # =====================================================================
        # TODO: Select an action without computing gradients.
        #   - Convert state to a float tensor and add a batch dimension.
        #   - Call the network inside torch.no_grad().
        #   - Convert the action to a numpy scalar (cpu, squeeze the batch dim).
        #   - Return the action array, log_prob, and value as Python scalars.
        # =====================================================================
        state_t = torch.FloatTensor(state).unsqueeze(0).to(device)

        with torch.no_grad():
            action, log_prob, _, value = self.network.get_action(state_t)
        return action.cpu().numpy().squeeze(0), log_prob.item(), value.item()

    def collect_rollout(self, env):
        """
        Collect n_steps transitions and compute GAE advantages.

        PPO collects a fixed number of steps rather than full episodes.
        self.obs carries the environment state across rollout boundaries so
        training is not interrupted at episode endings (CleanRL-style).

        Args:
            env: A Gymnasium environment instance.

        Returns:
            float: Mean episode reward over completed episodes in this rollout.
        """
        # =====================================================================
        # TODO: Collect exactly n_steps transitions into the rollout buffer.
        #
        # Step 1 — Clear the buffer at the start of each rollout.
        #
        # Step 2 — Step loop (repeat n_steps times):
        #   a. Select an action from self.obs using select_action().
        #   b. Step the environment to get the next observation, reward,
        #      and done flags (terminated or truncated).
        #   c. Store the transition in the buffer (current obs, action,
        #      reward, done, log_prob, value).
        #   d. Accumulate the episode reward and update self.obs.
        #   e. On episode end: record the completed episode reward,
        #      reset the counter, and reset the environment into self.obs.
        #
        # Step 3 — Bootstrap the value at the last step.
        #   After the loop, run the network on self.obs (no gradient) to get
        #   V(s_T). This is the bootstrap value for GAE at the rollout boundary.
        #
        # Step 4 — Compute GAE advantages.
        #   Call buffer.compute_returns_and_advantages() with the bootstrap value.
        #
        # Step 5 — Return the mean episode reward (or 0.0 if no episode finished).
        # =====================================================================
        self.buffer.clear()
        ep_rewards = []
        current_ep_reward = 0.0

        for _ in range(self.n_steps):
            action_np, log_prob, value = self.select_action(self.obs)
            next_obs, reward, terminated, truncated, _ = env.step(int(action_np))
            done = terminated or truncated
            self.buffer.store(self.obs, action_np, reward, done, log_prob, value)
            current_ep_reward += reward
            self.obs = next_obs

            if done:
                ep_rewards.append(current_ep_reward)
                current_ep_reward = 0.0
                self.obs, _ = env.reset()
        state_t = torch.FloatTensor(self.obs).unsqueeze(0).to(device)

        with torch.no_grad():
            _, _, _, last_value = self.network.get_action(state_t)
        self.buffer.compute_returns_and_advantages(last_value.item(), self.gamma, self.gae_lambda)
        return np.mean(ep_rewards) if ep_rewards else 0.0

    def update(self):
        """
        Run n_epochs of PPO updates over the collected rollout.

        Returns:
            Tuple of (mean_policy_loss, mean_value_loss, mean_entropy)
        """
        # =====================================================================
        # TODO: Implement the PPO mini-batch update loop.
        #
        # Repeat for n_epochs:
        #   For each mini-batch from the buffer:
        #
        #   Step 1 — Move all batch tensors to device.
        #
        #   Step 2 — Normalize advantages per mini-batch.
        #     Zero mean, unit std — this is standard in CleanRL PPO.
        #
        #   Step 3 — Re-evaluate the collected actions under the current policy.
        #     Get new log_probs, entropy, and values from the network.
        #
        #   Step 4 — PPO clipped surrogate loss.
        #     Compute the probability ratio r = exp(new_log_prob - old_log_prob).
        #     Clip r to [1-eps, 1+eps] and take the min of clipped and unclipped
        #     objectives. Negate to turn maximization into minimization.
        #
        #   Step 5 — Value loss with clipping.
        #     Compute unclipped MSE between new values and returns.
        #     Also compute clipped values (prevent large per-epoch value shifts)
        #     and take the max of the two losses (pessimistic bound).
        #
        #   Step 6 — Entropy bonus.
        #     Negate entropy to encourage exploration.
        #
        #   Step 7 — Combine losses, backpropagate, clip gradients, step optimizer.
        #     total = policy_loss + value_coef * value_loss + entropy_coef * entropy_loss
        #
        # Return mean policy loss, value loss, and entropy across all mini-batches.
        # =====================================================================
        all_policy_losses, all_value_losses, all_entropies = [], [], []

        for _ in range(self.n_epochs):

            for batch in self.buffer.get_batches(self.batch_size):
                states, actions, old_log_probs, advantages, returns, old_values = batch
                states = states.to(device)
                actions = actions.to(device)
                old_log_probs = old_log_probs.to(device)
                advantages = advantages.to(device)
                returns = returns.to(device)
                old_values = old_values.to(device)

                advantages = (advantages - advantages.mean()) / (advantages.std() + 1e-8)

                _, new_log_probs, entropy, new_values = self.network.get_action(states, actions)
                new_values = new_values.squeeze(-1)

                log_ratio = new_log_probs - old_log_probs
                ratio = log_ratio.exp()

                surr1 = ratio * advantages
                surr2 = torch.clamp(ratio, 1.0 - self.clip_eps, 1.0 + self.clip_eps) * advantages
                policy_loss = -torch.min(surr1, surr2).mean()

                v_loss_unclip = F.mse_loss(new_values, returns)
                v_clipped = old_values + torch.clamp(
                    new_values - old_values, -self.clip_eps, self.clip_eps
                )
                v_loss_clipped = F.mse_loss(v_clipped, returns)
                value_loss = torch.max(v_loss_unclip, v_loss_clipped)

                entropy_loss = -entropy.mean()
                loss = policy_loss + self.value_coef * value_loss + self.entropy_coef * entropy_loss

                self.optimizer.zero_grad()
                loss.backward()
                nn.utils.clip_grad_norm_(self.network.parameters(), self.max_grad_norm)
                self.optimizer.step()

                all_policy_losses.append(policy_loss.item())
                all_value_losses.append(value_loss.item())
                all_entropies.append(entropy.mean().item())
                
        return np.mean(all_policy_losses), np.mean(all_value_losses), np.mean(all_entropies)

print("PPOAgent class defined!")
# Out:
# PPOAgent class defined!

# %% [markdown]
# ## A.9 — PPO Training Loop
#
# Implement `train_ppo`. Unlike REINFORCE, PPO uses a fixed number of **rollout-update cycles** rather than episodes, so tracking is update-based.

# %%
def evaluate_ppo(agent, env, num_episodes=5, seed=0):
    """Evaluate a PPO agent (discrete actions)."""
    rewards = []
    for ep in range(num_episodes):
        obs, _ = env.reset(seed=seed + ep)
        ep_reward = 0.0
        for _ in range(10000):
            state_t = torch.FloatTensor(obs).unsqueeze(0).to(device)
            with torch.no_grad():
                action, _, _, _ = agent.network.get_action(state_t)
            obs, reward, terminated, truncated, _ = env.step(int(action.item()))
            ep_reward += reward
            if terminated or truncated:
                break
        rewards.append(ep_reward)
    return np.mean(rewards)


def train_ppo(env_name='CartPole-v1', num_updates=200, n_steps=512,
              seed=42, solve_threshold=None, anneal_lr=True, **agent_kwargs):
    """
    Train a PPO agent with optional linear LR annealing (CleanRL-style).

    Args:
        env_name        (str):  Gymnasium environment name.
        num_updates     (int):  Number of rollout-update cycles.
        n_steps         (int):  Environment steps per rollout.
        seed            (int):  Random seed.
        solve_threshold (float): Stop early when avg eval reward >= this.
        anneal_lr       (bool): Linearly decay LR from initial value to 0.
        **agent_kwargs:         Passed to PPOAgent (lr, gae_lambda, clip_eps, etc.)

    Returns:
        dict with keys: update_rewards, policy_losses, value_losses, entropies, agent
    """
    set_seed(seed)
    env = gym.make(env_name)
    eval_env = gym.make(env_name)
    state_dim  = env.observation_space.shape[0]
    action_dim = env.action_space.n

    agent = PPOAgent(state_dim, action_dim, n_steps=n_steps, seed=seed, **agent_kwargs)

    # Initialize env state — carried between rollouts (CleanRL-style)
    agent.obs, _ = env.reset(seed=seed)

    # Linear LR annealing: lr * (1 - update / num_updates) — same as CleanRL
    if anneal_lr:
        scheduler = torch.optim.lr_scheduler.LambdaLR(
            agent.optimizer,
            lr_lambda=lambda step: 1.0 - step / num_updates
        )

    update_rewards, policy_losses, value_losses, entropies = [], [], [], []

    # =========================================================================
    # TODO: Implement the PPO update loop.
    #
    # For each update:
    #   1. Collect a rollout using the agent. The agent's internal obs is
    #      updated automatically — no manual env reset needed here.
    #   2. Run the PPO update on the collected rollout.
    #   3. Step the LR scheduler (if annealing is enabled).
    #   4. Evaluate the current policy on the eval environment and record
    #      the mean reward.
    #   5. Track policy loss, value loss, and entropy.
    #   6. Print a progress line every 20 updates showing the rolling average
    #      eval reward and current learning rate.
    #   7. Stop early if the rolling average over the last 10 updates
    #      reaches solve_threshold (when solve_threshold is not None).
    # =========================================================================
    for update in range(num_updates):
        rollout_reward = agent.collect_rollout(env)
        policy_loss, value_loss, entropy = agent.update()

        if anneal_lr:
            scheduler.step()

        eval_reward = evaluate_ppo(agent, eval_env, num_episodes=5, seed=seed + update)

        update_rewards.append(eval_reward)
        policy_losses.append(policy_loss)
        value_losses.append(value_loss)
        entropies.append(entropy)

        if (update + 1) % 20 == 0:
            avg_eval_reward = np.mean(update_rewards[-20:])
            current_lr = agent.optimizer.param_groups[0]['lr']
            print(
                f"Update {update + 1}/{num_updates} | "
                f"AvgEvalReward(20)={avg_eval_reward:.2f} | "
                f"PolicyLoss={policy_loss:.4f} | "
                f"ValueLoss={value_loss:.4f} | "
                f"Entropy={entropy:.4f} | "
                f"LR={current_lr:.6f}"
            )

        if solve_threshold is not None and len(update_rewards) >= 10:
            if np.mean(update_rewards[-10:]) >= solve_threshold:
                print(
                    f"Solved in {update + 1} updates! "
                    f"AvgEvalReward(10)={np.mean(update_rewards[-10:]):.2f}"
                )
                break

    env.close()
    eval_env.close()
    return {'update_rewards': update_rewards, 'policy_losses': policy_losses,
            'value_losses': value_losses, 'entropies': entropies, 'agent': agent}

print("train_ppo and evaluate_ppo defined!")
# Out:
# train_ppo and evaluate_ppo defined!

# %% [markdown]
# ## A.10 — Train PPO on CartPole-v1
#
# Verify your PPO implementation on CartPole.

# %%
set_seed(42)
results_ppo_cp = train_ppo(
    env_name='CartPole-v1',
    num_updates=1000,
    n_steps=2048,
    solve_threshold=475,
    seed=42,
    lr=3e-4,
    gae_lambda=0.95,
    clip_eps=0.2,
    n_epochs=4,
    batch_size=64,
    entropy_coef=0.01,
)

plot_ppo_results(results_ppo_cp, title='PPO on CartPole-v1')

avg = np.mean(results_ppo_cp['update_rewards'][-10:])
solved = avg >= 475 or len(results_ppo_cp['update_rewards']) < 1000
print(f'\nAverage eval reward (last 10 updates): {avg:.1f}')
print('CartPole SOLVED!' if solved else 'Not yet solved — check your implementation.')
# Out:
# Update 20/1000 | AvgEvalReward(20)=193.05 | PolicyLoss=0.0003 | ValueLoss=177.6461 | Entropy=0.5791 | LR=0.000294
# Update 40/1000 | AvgEvalReward(20)=225.88 | PolicyLoss=-0.0016 | ValueLoss=130.9398 | Entropy=0.6036 | LR=0.000288
# Update 60/1000 | AvgEvalReward(20)=288.84 | PolicyLoss=-0.0015 | ValueLoss=83.1271 | Entropy=0.6060 | LR=0.000282
# Update 80/1000 | AvgEvalReward(20)=302.60 | PolicyLoss=-0.0060 | ValueLoss=107.2539 | Entropy=0.5943 | LR=0.000276
# Update 100/1000 | AvgEvalReward(20)=337.66 | PolicyLoss=0.0016 | ValueLoss=157.5281 | Entropy=0.5939 | LR=0.000270
# Update 120/1000 | AvgEvalReward(20)=277.13 | PolicyLoss=-0.0000 | ValueLoss=100.0999 | Entropy=0.6056 | LR=0.000264
# Update 140/1000 | AvgEvalReward(20)=300.23 | PolicyLoss=-0.0041 | ValueLoss=113.7662 | Entropy=0.6052 | LR=0.000258
# Update 160/1000 | AvgEvalReward(20)=284.77 | PolicyLoss=-0.0014 | ValueLoss=199.3807 | Entropy=0.6022 | LR=0.000252
# Update 180/1000 | AvgEvalReward(20)=278.87 | PolicyLoss=-0.0002 | ValueLoss=130.8438 | Entropy=0.5950 | LR=0.000246
# Update 200/1000 | AvgEvalReward(20)=240.89 | PolicyLoss=-0.0023 | ValueLoss=205.0732 | Entropy=0.5830 | LR=0.000240
# Update 220/1000 | AvgEvalReward(20)=327.48 | PolicyLoss=-0.0032 | ValueLoss=183.6323 | Entropy=0.5974 | LR=0.000234
# Update 240/1000 | AvgEvalReward(20)=274.49 | PolicyLoss=-0.0012 | ValueLoss=119.0760 | Entropy=0.5879 | LR=0.000228
# Update 260/1000 | AvgEvalReward(20)=276.81 | PolicyLoss=-0.0014 | ValueLoss=126.4089 | Entropy=0.6073 | LR=0.000222
# Update 280/1000 | AvgEvalReward(20)=269.30 | PolicyLoss=-0.0054 | ValueLoss=288.6305 | Entropy=0.5796 | LR=0.000216
# Update 300/1000 | AvgEvalReward(20)=266.33 | PolicyLoss=-0.0015 | ValueLoss=147.4417 | Entropy=0.6080 | LR=0.000210
# Update 320/1000 | AvgEvalReward(20)=306.51 | PolicyLoss=0.0034 | ValueLoss=114.3007 | Entropy=0.5908 | LR=0.000204
# Update 340/1000 | AvgEvalReward(20)=282.99 | PolicyLoss=0.0006 | ValueLoss=147.4471 | Entropy=0.5875 | LR=0.000198
# Update 360/1000 | AvgEvalReward(20)=303.06 | PolicyLoss=-0.0104 | ValueLoss=369.1100 | Entropy=0.5800 | LR=0.000192
# Update 380/1000 | AvgEvalReward(20)=300.89 | PolicyLoss=-0.0045 | ValueLoss=142.9497 | Entropy=0.5975 | LR=0.000186
# Update 400/1000 | AvgEvalReward(20)=285.99 | PolicyLoss=-0.0011 | ValueLoss=166.8144 | Entropy=0.6021 | LR=0.000180
# Update 420/1000 | AvgEvalReward(20)=358.08 | PolicyLoss=-0.0005 | ValueLoss=115.4290 | Entropy=0.5933 | LR=0.000174
# Update 440/1000 | AvgEvalReward(20)=338.34 | PolicyLoss=-0.0057 | ValueLoss=256.4308 | Entropy=0.5599 | LR=0.000168
# Update 460/1000 | AvgEvalReward(20)=391.64 | PolicyLoss=-0.0010 | ValueLoss=138.7508 | Entropy=0.5862 | LR=0.000162
# Update 480/1000 | AvgEvalReward(20)=341.61 | PolicyLoss=-0.0059 | ValueLoss=136.6553 | Entropy=0.5974 | LR=0.000156
# Update 500/1000 | AvgEvalReward(20)=350.18 | PolicyLoss=-0.0050 | ValueLoss=151.7012 | Entropy=0.5726 | LR=0.000150
# Update 520/1000 | AvgEvalReward(20)=326.91 | PolicyLoss=-0.0030 | ValueLoss=142.5532 | Entropy=0.6028 | LR=0.000144
# Update 540/1000 | AvgEvalReward(20)=309.46 | PolicyLoss=-0.0019 | ValueLoss=138.5118 | Entropy=0.5950 | LR=0.000138
# Update 560/1000 | AvgEvalReward(20)=343.02 | PolicyLoss=-0.0026 | ValueLoss=153.4601 | Entropy=0.5918 | LR=0.000132
# Update 580/1000 | AvgEvalReward(20)=351.81 | PolicyLoss=-0.0006 | ValueLoss=192.2557 | Entropy=0.6129 | LR=0.000126
# Update 600/1000 | AvgEvalReward(20)=320.52 | PolicyLoss=-0.0064 | ValueLoss=145.3621 | Entropy=0.5793 | LR=0.000120
# Update 620/1000 | AvgEvalReward(20)=338.11 | PolicyLoss=-0.0021 | ValueLoss=171.9659 | Entropy=0.6003 | LR=0.000114
# Update 640/1000 | AvgEvalReward(20)=290.82 | PolicyLoss=-0.0050 | ValueLoss=242.0780 | Entropy=0.5612 | LR=0.000108
# Update 660/1000 | AvgEvalReward(20)=348.95 | PolicyLoss=-0.0003 | ValueLoss=141.4104 | Entropy=0.5886 | LR=0.000102
# Update 680/1000 | AvgEvalReward(20)=355.87 | PolicyLoss=-0.0011 | ValueLoss=155.0628 | Entropy=0.5763 | LR=0.000096
# Update 700/1000 | AvgEvalReward(20)=335.41 | PolicyLoss=-0.0008 | ValueLoss=157.1297 | Entropy=0.5727 | LR=0.000090
# Update 720/1000 | AvgEvalReward(20)=388.38 | PolicyLoss=-0.0013 | ValueLoss=117.7907 | Entropy=0.5965 | LR=0.000084
# Update 740/1000 | AvgEvalReward(20)=367.69 | PolicyLoss=-0.0007 | ValueLoss=118.5446 | Entropy=0.5905 | LR=0.000078
# Update 760/1000 | AvgEvalReward(20)=390.59 | PolicyLoss=-0.0009 | ValueLoss=116.3218 | Entropy=0.5837 | LR=0.000072
# Update 780/1000 | AvgEvalReward(20)=424.23 | PolicyLoss=-0.0007 | ValueLoss=140.4216 | Entropy=0.5921 | LR=0.000066
# Update 800/1000 | AvgEvalReward(20)=390.26 | PolicyLoss=-0.0004 | ValueLoss=147.4196 | Entropy=0.5798 | LR=0.000060
# Update 820/1000 | AvgEvalReward(20)=387.95 | PolicyLoss=-0.0008 | ValueLoss=131.8236 | Entropy=0.5614 | LR=0.000054
# Update 840/1000 | AvgEvalReward(20)=361.79 | PolicyLoss=-0.0016 | ValueLoss=144.6169 | Entropy=0.5717 | LR=0.000048
# Update 860/1000 | AvgEvalReward(20)=401.92 | PolicyLoss=-0.0007 | ValueLoss=113.6735 | Entropy=0.5597 | LR=0.000042
# Update 880/1000 | AvgEvalReward(20)=436.98 | PolicyLoss=-0.0005 | ValueLoss=137.1542 | Entropy=0.5535 | LR=0.000036
# Update 900/1000 | AvgEvalReward(20)=420.70 | PolicyLoss=-0.0010 | ValueLoss=163.5116 | Entropy=0.5629 | LR=0.000030
# Update 920/1000 | AvgEvalReward(20)=437.81 | PolicyLoss=-0.0014 | ValueLoss=169.6118 | Entropy=0.5733 | LR=0.000024
# Update 940/1000 | AvgEvalReward(20)=438.31 | PolicyLoss=-0.0004 | ValueLoss=115.6114 | Entropy=0.5615 | LR=0.000018
# Update 960/1000 | AvgEvalReward(20)=451.02 | PolicyLoss=-0.0003 | ValueLoss=118.3582 | Entropy=0.5889 | LR=0.000012
# Solved in 963 updates! AvgEvalReward(10)=475.28
# Plot saved: /Users/dennisjohansson/Skola/Programering/VT4/TDDE78/tdde78lab/labs/lab2_policy_gradient/experiments/plots/ppo_on_cartpole-v1.png
# Average eval reward (last 10 updates): 475.3
# CartPole SOLVED!

# %% [markdown]
# ## Visualise — PPO Agent on CartPole-v1

# %%
video_dir = os.path.join(EXPERIMENTS_DIR, 'videos', 'ppo_cartpole')
video_path = record_video(results_ppo_cp['agent'], 'CartPole-v1', video_dir, seed=42)

if video_path:
    display(Video(video_path, embed=True, width=400))
else:
    print('No video found — check that ffmpeg is installed (sudo apt install ffmpeg).')
# Out:
# Episode reward: 375.0
# <video controls  width="400" >
#  <source src="data:video/mp4;base64,..." type="video/mp4">
#  Your browser does not support the video tag.
#  </video>

# %% [markdown]
# ---
#
# # Part B — Experiments
#
# ---
#
# Now that your implementation works, run systematic experiments to understand the algorithms.
#
# **Important:** For all experiments, run at least **3 different seeds** and report mean ± std.

# %% [markdown]
# ## B.1 — Ablation: Baseline in REINFORCE
#
# Does the value baseline actually help? Compare REINFORCE with and without the baseline
# on CartPole-v1 with 3 seeds.
#
# - `use_baseline=True` — subtracts V(s) from returns as advantage
# - `use_baseline=False` — uses normalized returns directly
#
# Run `num_episodes=2000` with seeds `[42, 123, 456]`.

# %%
seeds = [42, 123, 456]

baseline_results = {
    'REINFORCE (with baseline)': [
        train_reinforce(env_name='CartPole-v1', num_episodes=2000, use_baseline=True, seed=s)
        for s in seeds
    ],
    'REINFORCE (no baseline)': [
        train_reinforce(env_name='CartPole-v1', num_episodes=2000, use_baseline=False, seed=s)
        for s in seeds
    ],
}

plot_comparison(baseline_results, title='REINFORCE: Baseline Ablation on CartPole-v1',
                window=50, x_label='Episode', reward_key='episode_rewards')

for name, results_list in baseline_results.items():
    final = [np.mean(r['episode_rewards'][-100:]) for r in results_list]
    print(f'{name}: {np.mean(final):.1f} ± {np.std(final):.1f}')
# Out:
# Episode 50/2000 | AvgReward(50)=24.36 | PGLoss=-0.0011 | ValueLoss=0.9992
# Episode 100/2000 | AvgReward(50)=26.90 | PGLoss=0.0002 | ValueLoss=0.9652
# Episode 150/2000 | AvgReward(50)=32.72 | PGLoss=-0.0076 | ValueLoss=0.9142
# Episode 200/2000 | AvgReward(50)=53.78 | PGLoss=-0.0011 | ValueLoss=1.0775
# Episode 250/2000 | AvgReward(50)=82.32 | PGLoss=-0.0036 | ValueLoss=1.0725
# Episode 300/2000 | AvgReward(50)=143.42 | PGLoss=-0.0211 | ValueLoss=1.0863
# Episode 350/2000 | AvgReward(50)=216.52 | PGLoss=-0.0125 | ValueLoss=1.0629
# Episode 400/2000 | AvgReward(50)=250.68 | PGLoss=-0.0128 | ValueLoss=1.1392
# Episode 450/2000 | AvgReward(50)=250.32 | PGLoss=-0.0135 | ValueLoss=0.6972
# Episode 500/2000 | AvgReward(50)=295.48 | PGLoss=-0.0033 | ValueLoss=1.2326
# Episode 550/2000 | AvgReward(50)=248.38 | PGLoss=-0.0104 | ValueLoss=0.5013
# Episode 600/2000 | AvgReward(50)=372.98 | PGLoss=-0.0110 | ValueLoss=0.9349
# Episode 650/2000 | AvgReward(50)=427.28 | PGLoss=-0.0062 | ValueLoss=0.7675
# Episode 700/2000 | AvgReward(50)=434.00 | PGLoss=-0.0016 | ValueLoss=0.7675
# Episode 750/2000 | AvgReward(50)=372.14 | PGLoss=-0.0041 | ValueLoss=0.5224
# Episode 800/2000 | AvgReward(50)=441.16 | PGLoss=-0.0020 | ValueLoss=0.8291
# Episode 850/2000 | AvgReward(50)=397.84 | PGLoss=-0.0033 | ValueLoss=0.7610
# Episode 900/2000 | AvgReward(50)=448.32 | PGLoss=-0.0015 | ValueLoss=0.7998
# Episode 950/2000 | AvgReward(50)=362.20 | PGLoss=-0.0044 | ValueLoss=0.3943
# Episode 1000/2000 | AvgReward(50)=349.74 | PGLoss=-0.0072 | ValueLoss=0.5119
# Episode 1050/2000 | AvgReward(50)=454.04 | PGLoss=-0.0008 | ValueLoss=0.9494
# Episode 1100/2000 | AvgReward(50)=470.34 | PGLoss=-0.0060 | ValueLoss=0.8584
# Episode 1150/2000 | AvgReward(50)=483.80 | PGLoss=-0.0008 | ValueLoss=0.9208
# Episode 1200/2000 | AvgReward(50)=476.28 | PGLoss=-0.0048 | ValueLoss=0.8648
# Episode 1250/2000 | AvgReward(50)=423.56 | PGLoss=-0.0029 | ValueLoss=0.7464
# Episode 1300/2000 | AvgReward(50)=345.02 | PGLoss=-0.0039 | ValueLoss=0.7721
# Episode 1350/2000 | AvgReward(50)=284.48 | PGLoss=-0.0105 | ValueLoss=0.5974
# Episode 1400/2000 | AvgReward(50)=403.54 | PGLoss=-0.0044 | ValueLoss=0.8183
# Episode 1450/2000 | AvgReward(50)=252.88 | PGLoss=-0.0083 | ValueLoss=0.2580
# Episode 1500/2000 | AvgReward(50)=433.48 | PGLoss=-0.0062 | ValueLoss=0.6708
# Episode 1550/2000 | AvgReward(50)=476.86 | PGLoss=-0.0035 | ValueLoss=0.9236
# Episode 1600/2000 | AvgReward(50)=385.82 | PGLoss=-0.0095 | ValueLoss=0.7640
# Episode 1650/2000 | AvgReward(50)=491.50 | PGLoss=-0.0008 | ValueLoss=1.0175
# Episode 1700/2000 | AvgReward(50)=380.78 | PGLoss=-0.0062 | ValueLoss=0.7546
# Episode 1750/2000 | AvgReward(50)=474.70 | PGLoss=-0.0044 | ValueLoss=0.9668
# Episode 1800/2000 | AvgReward(50)=500.00 | PGLoss=-0.0004 | ValueLoss=0.9826
# Episode 1850/2000 | AvgReward(50)=500.00 | PGLoss=0.0014 | ValueLoss=1.0050
# Episode 1900/2000 | AvgReward(50)=486.26 | PGLoss=-0.0002 | ValueLoss=0.9705
# Episode 1950/2000 | AvgReward(50)=493.90 | PGLoss=-0.0051 | ValueLoss=1.0211
# Episode 2000/2000 | AvgReward(50)=441.44 | PGLoss=-0.0019 | ValueLoss=0.8703
# Episode 50/2000 | AvgReward(50)=23.10 | PGLoss=0.0006 | ValueLoss=0.9659
# Episode 100/2000 | AvgReward(50)=22.96 | PGLoss=0.0011 | ValueLoss=0.9593
# Episode 150/2000 | AvgReward(50)=28.76 | PGLoss=-0.0068 | ValueLoss=0.9471
# Episode 200/2000 | AvgReward(50)=32.38 | PGLoss=0.0038 | ValueLoss=0.8835
# Episode 250/2000 | AvgReward(50)=47.42 | PGLoss=-0.0081 | ValueLoss=0.8337
# Episode 300/2000 | AvgReward(50)=106.80 | PGLoss=-0.0168 | ValueLoss=1.0407
# Episode 350/2000 | AvgReward(50)=111.38 | PGLoss=-0.0118 | ValueLoss=1.1238
# Episode 400/2000 | AvgReward(50)=160.76 | PGLoss=-0.0134 | ValueLoss=1.0625
# Episode 450/2000 | AvgReward(50)=197.18 | PGLoss=-0.0128 | ValueLoss=0.9105
# Episode 500/2000 | AvgReward(50)=157.62 | PGLoss=-0.0104 | ValueLoss=0.5949
# Episode 550/2000 | AvgReward(50)=267.46 | PGLoss=-0.0075 | ValueLoss=0.6730
# Episode 600/2000 | AvgReward(50)=338.20 | PGLoss=-0.0111 | ValueLoss=0.8504
# Episode 650/2000 | AvgReward(50)=253.12 | PGLoss=-0.0102 | ValueLoss=0.4006
# Episode 700/2000 | AvgReward(50)=289.56 | PGLoss=-0.0080 | ValueLoss=0.3679
# Episode 750/2000 | AvgReward(50)=340.98 | PGLoss=-0.0062 | ValueLoss=0.4174
# Episode 800/2000 | AvgReward(50)=406.66 | PGLoss=-0.0063 | ValueLoss=0.6732
# Episode 850/2000 | AvgReward(50)=453.12 | PGLoss=-0.0054 | ValueLoss=0.8562
# Episode 900/2000 | AvgReward(50)=472.86 | PGLoss=-0.0040 | ValueLoss=0.8664
# Episode 950/2000 | AvgReward(50)=403.80 | PGLoss=-0.0032 | ValueLoss=0.5521
# Episode 1000/2000 | AvgReward(50)=407.86 | PGLoss=-0.0078 | ValueLoss=0.5166
# Episode 1050/2000 | AvgReward(50)=401.08 | PGLoss=-0.0051 | ValueLoss=0.5465
# Episode 1100/2000 | AvgReward(50)=450.14 | PGLoss=-0.0068 | ValueLoss=0.8054
# Episode 1150/2000 | AvgReward(50)=461.24 | PGLoss=-0.0058 | ValueLoss=0.8996
# Episode 1200/2000 | AvgReward(50)=475.82 | PGLoss=-0.0067 | ValueLoss=0.8506
# Episode 1250/2000 | AvgReward(50)=451.26 | PGLoss=-0.0096 | ValueLoss=0.8124
# Episode 1300/2000 | AvgReward(50)=461.62 | PGLoss=-0.0024 | ValueLoss=0.9784
# Episode 1350/2000 | AvgReward(50)=465.52 | PGLoss=-0.0045 | ValueLoss=0.8394
# Episode 1400/2000 | AvgReward(50)=434.26 | PGLoss=-0.0083 | ValueLoss=0.8926
# Episode 1450/2000 | AvgReward(50)=410.12 | PGLoss=-0.0061 | ValueLoss=0.7975
# Episode 1500/2000 | AvgReward(50)=434.58 | PGLoss=-0.0087 | ValueLoss=0.8081
# Episode 1550/2000 | AvgReward(50)=481.10 | PGLoss=-0.0029 | ValueLoss=0.9127
# Episode 1600/2000 | AvgReward(50)=474.48 | PGLoss=-0.0016 | ValueLoss=0.8582
# Episode 1650/2000 | AvgReward(50)=224.72 | PGLoss=-0.0126 | ValueLoss=0.2561
# Episode 1700/2000 | AvgReward(50)=291.16 | PGLoss=-0.0055 | ValueLoss=0.3041
# Episode 1750/2000 | AvgReward(50)=65.00 | PGLoss=0.0053 | ValueLoss=0.4253
# Episode 1800/2000 | AvgReward(50)=103.28 | PGLoss=-0.0174 | ValueLoss=0.4168
# Episode 1850/2000 | AvgReward(50)=227.78 | PGLoss=-0.0051 | ValueLoss=0.1254
# Episode 1900/2000 | AvgReward(50)=496.78 | PGLoss=-0.0045 | ValueLoss=0.9712
# Episode 1950/2000 | AvgReward(50)=500.00 | PGLoss=-0.0048 | ValueLoss=0.7854
# Episode 2000/2000 | AvgReward(50)=500.00 | PGLoss=-0.0025 | ValueLoss=0.8261
# Episode 50/2000 | AvgReward(50)=23.52 | PGLoss=-0.0014 | ValueLoss=0.9906
# Episode 100/2000 | AvgReward(50)=26.90 | PGLoss=-0.0057 | ValueLoss=0.9404
# Episode 150/2000 | AvgReward(50)=37.72 | PGLoss=-0.0052 | ValueLoss=0.9502
# Episode 200/2000 | AvgReward(50)=59.02 | PGLoss=-0.0049 | ValueLoss=0.9164
# Episode 250/2000 | AvgReward(50)=134.62 | PGLoss=-0.0184 | ValueLoss=1.0809
# Episode 300/2000 | AvgReward(50)=171.12 | PGLoss=-0.0135 | ValueLoss=1.1472
# Episode 350/2000 | AvgReward(50)=189.32 | PGLoss=-0.0116 | ValueLoss=0.8720
# Episode 400/2000 | AvgReward(50)=296.08 | PGLoss=-0.0112 | ValueLoss=0.9992
# Episode 450/2000 | AvgReward(50)=216.30 | PGLoss=-0.0107 | ValueLoss=0.3898
# Episode 500/2000 | AvgReward(50)=147.26 | PGLoss=-0.0038 | ValueLoss=1.1590
# Episode 550/2000 | AvgReward(50)=231.78 | PGLoss=-0.0148 | ValueLoss=0.7194
# Episode 600/2000 | AvgReward(50)=359.82 | PGLoss=-0.0131 | ValueLoss=0.7389
# Episode 650/2000 | AvgReward(50)=290.68 | PGLoss=-0.0117 | ValueLoss=0.5244
# Episode 700/2000 | AvgReward(50)=364.36 | PGLoss=-0.0064 | ValueLoss=0.9687
# Episode 750/2000 | AvgReward(50)=445.24 | PGLoss=-0.0055 | ValueLoss=0.8238
# Episode 800/2000 | AvgReward(50)=342.64 | PGLoss=-0.0068 | ValueLoss=0.4204
# Episode 850/2000 | AvgReward(50)=347.60 | PGLoss=-0.0111 | ValueLoss=0.4646
# Episode 900/2000 | AvgReward(50)=465.26 | PGLoss=-0.0040 | ValueLoss=0.8813
# Episode 950/2000 | AvgReward(50)=399.72 | PGLoss=-0.0055 | ValueLoss=0.6469
# Episode 1000/2000 | AvgReward(50)=448.38 | PGLoss=-0.0029 | ValueLoss=0.8913
# Episode 1050/2000 | AvgReward(50)=474.36 | PGLoss=-0.0036 | ValueLoss=0.9065
# Episode 1100/2000 | AvgReward(50)=471.52 | PGLoss=-0.0052 | ValueLoss=0.9521
# Episode 1150/2000 | AvgReward(50)=492.74 | PGLoss=-0.0073 | ValueLoss=0.9072
# Episode 1200/2000 | AvgReward(50)=452.34 | PGLoss=-0.0045 | ValueLoss=0.8076
# Episode 1250/2000 | AvgReward(50)=450.22 | PGLoss=-0.0063 | ValueLoss=0.7981
# Episode 1300/2000 | AvgReward(50)=459.72 | PGLoss=-0.0035 | ValueLoss=0.9112
# Episode 1350/2000 | AvgReward(50)=493.50 | PGLoss=-0.0007 | ValueLoss=0.9239
# Episode 1400/2000 | AvgReward(50)=478.12 | PGLoss=-0.0005 | ValueLoss=0.9498
# Episode 1450/2000 | AvgReward(50)=475.90 | PGLoss=-0.0040 | ValueLoss=0.9392
# Episode 1500/2000 | AvgReward(50)=496.60 | PGLoss=-0.0004 | ValueLoss=0.9558
# Episode 1550/2000 | AvgReward(50)=500.00 | PGLoss=-0.0057 | ValueLoss=0.6934
# Episode 1600/2000 | AvgReward(50)=498.40 | PGLoss=-0.0013 | ValueLoss=0.9276
# Episode 1650/2000 | AvgReward(50)=500.00 | PGLoss=-0.0075 | ValueLoss=0.9346
# Episode 1700/2000 | AvgReward(50)=500.00 | PGLoss=0.0011 | ValueLoss=0.9888
# Episode 1750/2000 | AvgReward(50)=500.00 | PGLoss=-0.0040 | ValueLoss=0.9474
# Episode 1800/2000 | AvgReward(50)=500.00 | PGLoss=-0.0039 | ValueLoss=0.9137
# Episode 1850/2000 | AvgReward(50)=476.80 | PGLoss=0.0004 | ValueLoss=0.8119
# Episode 1900/2000 | AvgReward(50)=423.34 | PGLoss=-0.0118 | ValueLoss=0.7002
# Episode 1950/2000 | AvgReward(50)=476.28 | PGLoss=-0.0084 | ValueLoss=0.7920
# Episode 2000/2000 | AvgReward(50)=500.00 | PGLoss=-0.0048 | ValueLoss=0.9477
# Episode 50/2000 | AvgReward(50)=32.78 | PGLoss=-0.0015 | ValueLoss=0.0000
# Episode 100/2000 | AvgReward(50)=67.32 | PGLoss=-0.0051 | ValueLoss=0.0000
# Episode 150/2000 | AvgReward(50)=155.70 | PGLoss=-0.0125 | ValueLoss=0.0000
# Episode 200/2000 | AvgReward(50)=174.02 | PGLoss=-0.0099 | ValueLoss=0.0000
# Episode 250/2000 | AvgReward(50)=244.52 | PGLoss=-0.0143 | ValueLoss=0.0000
# Episode 300/2000 | AvgReward(50)=272.22 | PGLoss=-0.0059 | ValueLoss=0.0000
# Episode 350/2000 | AvgReward(50)=371.64 | PGLoss=-0.0042 | ValueLoss=0.0000
# Episode 400/2000 | AvgReward(50)=362.92 | PGLoss=-0.0066 | ValueLoss=0.0000
# Episode 450/2000 | AvgReward(50)=475.62 | PGLoss=-0.0030 | ValueLoss=0.0000
# Episode 500/2000 | AvgReward(50)=497.48 | PGLoss=-0.0054 | ValueLoss=0.0000
# Episode 550/2000 | AvgReward(50)=500.00 | PGLoss=-0.0051 | ValueLoss=0.0000
# Episode 600/2000 | AvgReward(50)=477.38 | PGLoss=-0.0044 | ValueLoss=0.0000
# Episode 650/2000 | AvgReward(50)=471.52 | PGLoss=-0.0042 | ValueLoss=0.0000
# Episode 700/2000 | AvgReward(50)=489.56 | PGLoss=0.0007 | ValueLoss=0.0000
# Episode 750/2000 | AvgReward(50)=470.54 | PGLoss=-0.0017 | ValueLoss=0.0000
# Episode 800/2000 | AvgReward(50)=489.42 | PGLoss=-0.0021 | ValueLoss=0.0000
# Episode 850/2000 | AvgReward(50)=457.26 | PGLoss=-0.0016 | ValueLoss=0.0000
# Episode 900/2000 | AvgReward(50)=500.00 | PGLoss=-0.0005 | ValueLoss=0.0000
# Episode 950/2000 | AvgReward(50)=500.00 | PGLoss=-0.0014 | ValueLoss=0.0000
# Episode 1000/2000 | AvgReward(50)=498.16 | PGLoss=0.0000 | ValueLoss=0.0000
# Episode 1050/2000 | AvgReward(50)=500.00 | PGLoss=-0.0010 | ValueLoss=0.0000
# Episode 1100/2000 | AvgReward(50)=500.00 | PGLoss=0.0011 | ValueLoss=0.0000
# Episode 1150/2000 | AvgReward(50)=500.00 | PGLoss=-0.0025 | ValueLoss=0.0000
# Episode 1200/2000 | AvgReward(50)=500.00 | PGLoss=-0.0012 | ValueLoss=0.0000
# Episode 1250/2000 | AvgReward(50)=476.80 | PGLoss=-0.0085 | ValueLoss=0.0000
# Episode 1300/2000 | AvgReward(50)=466.02 | PGLoss=-0.0053 | ValueLoss=0.0000
# Episode 1350/2000 | AvgReward(50)=459.50 | PGLoss=-0.0078 | ValueLoss=0.0000
# Episode 1400/2000 | AvgReward(50)=477.30 | PGLoss=-0.0047 | ValueLoss=0.0000
# Episode 1450/2000 | AvgReward(50)=497.74 | PGLoss=-0.0031 | ValueLoss=0.0000
# Episode 1500/2000 | AvgReward(50)=496.40 | PGLoss=-0.0070 | ValueLoss=0.0000
# Episode 1550/2000 | AvgReward(50)=486.94 | PGLoss=0.0012 | ValueLoss=0.0000
# Episode 1600/2000 | AvgReward(50)=434.54 | PGLoss=-0.0097 | ValueLoss=0.0000
# Episode 1650/2000 | AvgReward(50)=493.46 | PGLoss=-0.0021 | ValueLoss=0.0000
# Episode 1700/2000 | AvgReward(50)=496.44 | PGLoss=-0.0010 | ValueLoss=0.0000
# Episode 1750/2000 | AvgReward(50)=474.36 | PGLoss=0.0007 | ValueLoss=0.0000
# Episode 1800/2000 | AvgReward(50)=161.62 | PGLoss=-0.0175 | ValueLoss=0.0000
# Episode 1850/2000 | AvgReward(50)=329.90 | PGLoss=-0.0099 | ValueLoss=0.0000
# Episode 1900/2000 | AvgReward(50)=500.00 | PGLoss=-0.0008 | ValueLoss=0.0000
# Episode 1950/2000 | AvgReward(50)=500.00 | PGLoss=-0.0033 | ValueLoss=0.0000
# Episode 2000/2000 | AvgReward(50)=500.00 | PGLoss=-0.0003 | ValueLoss=0.0000
# Episode 50/2000 | AvgReward(50)=25.94 | PGLoss=-0.0077 | ValueLoss=0.0000
# Episode 100/2000 | AvgReward(50)=109.96 | PGLoss=-0.0156 | ValueLoss=0.0000
# Episode 150/2000 | AvgReward(50)=193.44 | PGLoss=-0.0153 | ValueLoss=0.0000
# Episode 200/2000 | AvgReward(50)=398.86 | PGLoss=-0.0060 | ValueLoss=0.0000
# Episode 250/2000 | AvgReward(50)=396.10 | PGLoss=-0.0065 | ValueLoss=0.0000
# Episode 300/2000 | AvgReward(50)=457.36 | PGLoss=-0.0022 | ValueLoss=0.0000
# Episode 350/2000 | AvgReward(50)=374.02 | PGLoss=-0.0053 | ValueLoss=0.0000
# Episode 400/2000 | AvgReward(50)=173.42 | PGLoss=-0.0110 | ValueLoss=0.0000
# Episode 450/2000 | AvgReward(50)=357.96 | PGLoss=-0.0062 | ValueLoss=0.0000
# Episode 500/2000 | AvgReward(50)=487.90 | PGLoss=-0.0037 | ValueLoss=0.0000
# Episode 550/2000 | AvgReward(50)=471.46 | PGLoss=-0.0065 | ValueLoss=0.0000
# Episode 600/2000 | AvgReward(50)=494.76 | PGLoss=-0.0075 | ValueLoss=0.0000
# Episode 650/2000 | AvgReward(50)=500.00 | PGLoss=-0.0054 | ValueLoss=0.0000
# Episode 700/2000 | AvgReward(50)=500.00 | PGLoss=-0.0040 | ValueLoss=0.0000
# Episode 750/2000 | AvgReward(50)=498.92 | PGLoss=-0.0076 | ValueLoss=0.0000
# Episode 800/2000 | AvgReward(50)=495.96 | PGLoss=-0.0048 | ValueLoss=0.0000
# Episode 850/2000 | AvgReward(50)=289.78 | PGLoss=-0.0118 | ValueLoss=0.0000
# Episode 900/2000 | AvgReward(50)=206.58 | PGLoss=-0.0159 | ValueLoss=0.0000
# Episode 950/2000 | AvgReward(50)=491.48 | PGLoss=-0.0001 | ValueLoss=0.0000
# Episode 1000/2000 | AvgReward(50)=472.12 | PGLoss=-0.0044 | ValueLoss=0.0000
# Episode 1050/2000 | AvgReward(50)=482.34 | PGLoss=-0.0012 | ValueLoss=0.0000
# Episode 1100/2000 | AvgReward(50)=495.20 | PGLoss=-0.0009 | ValueLoss=0.0000
# Episode 1150/2000 | AvgReward(50)=485.08 | PGLoss=0.0002 | ValueLoss=0.0000
# Episode 1200/2000 | AvgReward(50)=486.44 | PGLoss=0.0021 | ValueLoss=0.0000
# Episode 1250/2000 | AvgReward(50)=498.50 | PGLoss=-0.0022 | ValueLoss=0.0000
# Episode 1300/2000 | AvgReward(50)=500.00 | PGLoss=-0.0017 | ValueLoss=0.0000
# Episode 1350/2000 | AvgReward(50)=500.00 | PGLoss=-0.0025 | ValueLoss=0.0000
# Episode 1400/2000 | AvgReward(50)=498.74 | PGLoss=-0.0017 | ValueLoss=0.0000
# Episode 1450/2000 | AvgReward(50)=500.00 | PGLoss=-0.0022 | ValueLoss=0.0000
# Episode 1500/2000 | AvgReward(50)=494.44 | PGLoss=-0.0058 | ValueLoss=0.0000
# Episode 1550/2000 | AvgReward(50)=500.00 | PGLoss=-0.0037 | ValueLoss=0.0000
# Episode 1600/2000 | AvgReward(50)=500.00 | PGLoss=0.0001 | ValueLoss=0.0000
# Episode 1650/2000 | AvgReward(50)=500.00 | PGLoss=-0.0002 | ValueLoss=0.0000
# Episode 1700/2000 | AvgReward(50)=500.00 | PGLoss=-0.0032 | ValueLoss=0.0000
# Episode 1750/2000 | AvgReward(50)=500.00 | PGLoss=-0.0042 | ValueLoss=0.0000
# Episode 1800/2000 | AvgReward(50)=500.00 | PGLoss=0.0022 | ValueLoss=0.0000
# Episode 1850/2000 | AvgReward(50)=500.00 | PGLoss=0.0012 | ValueLoss=0.0000
# Episode 1900/2000 | AvgReward(50)=493.32 | PGLoss=-0.0010 | ValueLoss=0.0000
# Episode 1950/2000 | AvgReward(50)=500.00 | PGLoss=-0.0019 | ValueLoss=0.0000
# Episode 2000/2000 | AvgReward(50)=500.00 | PGLoss=0.0033 | ValueLoss=0.0000
# Episode 50/2000 | AvgReward(50)=25.80 | PGLoss=-0.0052 | ValueLoss=0.0000
# Episode 100/2000 | AvgReward(50)=67.36 | PGLoss=-0.0198 | ValueLoss=0.0000
# Episode 150/2000 | AvgReward(50)=218.18 | PGLoss=-0.0144 | ValueLoss=0.0000
# Episode 200/2000 | AvgReward(50)=386.82 | PGLoss=-0.0087 | ValueLoss=0.0000
# Episode 250/2000 | AvgReward(50)=289.52 | PGLoss=-0.0089 | ValueLoss=0.0000
# Episode 300/2000 | AvgReward(50)=332.58 | PGLoss=-0.0092 | ValueLoss=0.0000
# Episode 350/2000 | AvgReward(50)=428.12 | PGLoss=-0.0102 | ValueLoss=0.0000
# Episode 400/2000 | AvgReward(50)=388.44 | PGLoss=-0.0052 | ValueLoss=0.0000
# Episode 450/2000 | AvgReward(50)=482.72 | PGLoss=-0.0070 | ValueLoss=0.0000
# Episode 500/2000 | AvgReward(50)=481.72 | PGLoss=-0.0017 | ValueLoss=0.0000
# Episode 550/2000 | AvgReward(50)=489.02 | PGLoss=0.0037 | ValueLoss=0.0000
# Episode 600/2000 | AvgReward(50)=448.82 | PGLoss=-0.0083 | ValueLoss=0.0000
# Episode 650/2000 | AvgReward(50)=465.92 | PGLoss=-0.0061 | ValueLoss=0.0000
# Episode 700/2000 | AvgReward(50)=497.28 | PGLoss=-0.0009 | ValueLoss=0.0000
# Episode 750/2000 | AvgReward(50)=500.00 | PGLoss=0.0002 | ValueLoss=0.0000
# Episode 800/2000 | AvgReward(50)=473.26 | PGLoss=-0.0059 | ValueLoss=0.0000
# Episode 850/2000 | AvgReward(50)=475.78 | PGLoss=-0.0013 | ValueLoss=0.0000
# Episode 900/2000 | AvgReward(50)=483.22 | PGLoss=-0.0046 | ValueLoss=0.0000
# Episode 950/2000 | AvgReward(50)=497.64 | PGLoss=-0.0027 | ValueLoss=0.0000
# Episode 1000/2000 | AvgReward(50)=500.00 | PGLoss=0.0001 | ValueLoss=0.0000
# Episode 1050/2000 | AvgReward(50)=495.34 | PGLoss=-0.0016 | ValueLoss=0.0000
# Episode 1100/2000 | AvgReward(50)=500.00 | PGLoss=-0.0007 | ValueLoss=0.0000
# Episode 1150/2000 | AvgReward(50)=465.76 | PGLoss=-0.0060 | ValueLoss=0.0000
# Episode 1200/2000 | AvgReward(50)=499.34 | PGLoss=-0.0063 | ValueLoss=0.0000
# Episode 1250/2000 | AvgReward(50)=477.82 | PGLoss=-0.0071 | ValueLoss=0.0000
# Episode 1300/2000 | AvgReward(50)=491.62 | PGLoss=-0.0083 | ValueLoss=0.0000
# Episode 1350/2000 | AvgReward(50)=337.52 | PGLoss=-0.0167 | ValueLoss=0.0000
# Episode 1400/2000 | AvgReward(50)=195.16 | PGLoss=-0.0163 | ValueLoss=0.0000
# Episode 1450/2000 | AvgReward(50)=225.26 | PGLoss=-0.0185 | ValueLoss=0.0000
# Episode 1500/2000 | AvgReward(50)=470.56 | PGLoss=-0.0022 | ValueLoss=0.0000
# Episode 1550/2000 | AvgReward(50)=181.84 | PGLoss=-0.0235 | ValueLoss=0.0000
# Episode 1600/2000 | AvgReward(50)=286.00 | PGLoss=-0.0109 | ValueLoss=0.0000
# Episode 1650/2000 | AvgReward(50)=381.72 | PGLoss=-0.0138 | ValueLoss=0.0000
# Episode 1700/2000 | AvgReward(50)=470.26 | PGLoss=-0.0094 | ValueLoss=0.0000
# Episode 1750/2000 | AvgReward(50)=500.00 | PGLoss=-0.0015 | ValueLoss=0.0000
# Episode 1800/2000 | AvgReward(50)=500.00 | PGLoss=-0.0013 | ValueLoss=0.0000
# Episode 1850/2000 | AvgReward(50)=500.00 | PGLoss=-0.0019 | ValueLoss=0.0000
# Episode 1900/2000 | AvgReward(50)=500.00 | PGLoss=0.0004 | ValueLoss=0.0000
# Episode 1950/2000 | AvgReward(50)=500.00 | PGLoss=-0.0007 | ValueLoss=0.0000
# Episode 2000/2000 | AvgReward(50)=500.00 | PGLoss=-0.0013 | ValueLoss=0.0000
# Plot saved: /Users/dennisjohansson/Skola/Programering/VT4/TDDE78/tdde78lab/labs/lab2_policy_gradient/experiments/plots/reinforce_baseline_ablation_on_cartpole-v1.png
# REINFORCE (with baseline): 485.3 ± 13.4
# REINFORCE (no baseline): 500.0 ± 0.0

# %% [markdown]
# ## B.2 — Ablation: GAE Lambda (PPO on LunarLander-v3)
#
# GAE interpolates between one-step TD ($\lambda = 0$, low variance, high bias)
# and Monte Carlo ($\lambda = 1$, high variance, zero bias).
#
# Test lambda values **0.0**, **0.95**, and **1.0** on **LunarLander-v3**
# (`num_updates=600, n_steps=2048, n_epochs=4`) with seeds `[42, 123, 456]`.
#
# Use `n_epochs=4` (standard PPO). Do **not** set `solve_threshold` so you see
# the full 600-update learning curve.
#
# Which $\lambda$ works best and why?

# %%
seeds = [42, 123, 456]
gae_lambdas = [0.0, 0.95, 1.0]  # TD (high bias), default, MC (no bias)

# No solve_threshold — we want the full learning curve for each lambda.
gae_results = {}
for lam in gae_lambdas:
    gae_results[f'lambda={lam}'] = [
        train_ppo(env_name='LunarLander-v3', num_updates=600, n_steps=2048, seed=s,
                  gae_lambda=lam, lr=3e-4, clip_eps=0.2, n_epochs=4,
                  batch_size=64, entropy_coef=0.01)
        for s in seeds
    ]

plot_comparison(gae_results, title='PPO: Effect of GAE Lambda on LunarLander-v3',
                window=20, x_label='PPO Update', reward_key='update_rewards')

for name, results_list in gae_results.items():
    final = [np.mean(r['update_rewards'][-20:]) for r in results_list]
    print(f'{name}: {np.mean(final):.1f} ± {np.std(final):.1f}')
# Out:
# Update 20/600 | AvgEvalReward(20)=-161.39 | PolicyLoss=-0.0123 | ValueLoss=36.0815 | Entropy=0.7922 | LR=0.000290
# Update 40/600 | AvgEvalReward(20)=-148.55 | PolicyLoss=-0.0066 | ValueLoss=39.0521 | Entropy=0.6424 | LR=0.000280
# Update 60/600 | AvgEvalReward(20)=-104.71 | PolicyLoss=-0.0042 | ValueLoss=31.4502 | Entropy=0.5466 | LR=0.000270
# Update 80/600 | AvgEvalReward(20)=-50.99 | PolicyLoss=-0.0112 | ValueLoss=10.1002 | Entropy=0.5800 | LR=0.000260
# Update 100/600 | AvgEvalReward(20)=-29.23 | PolicyLoss=-0.0164 | ValueLoss=1.8126 | Entropy=0.7333 | LR=0.000250
# Update 120/600 | AvgEvalReward(20)=-111.29 | PolicyLoss=-0.0146 | ValueLoss=6.2953 | Entropy=0.6729 | LR=0.000240
# Update 140/600 | AvgEvalReward(20)=-106.03 | PolicyLoss=-0.0155 | ValueLoss=5.6435 | Entropy=0.6762 | LR=0.000230
# Update 160/600 | AvgEvalReward(20)=-88.77 | PolicyLoss=-0.0095 | ValueLoss=17.1649 | Entropy=0.7331 | LR=0.000220
# Update 180/600 | AvgEvalReward(20)=-63.42 | PolicyLoss=-0.0199 | ValueLoss=0.6603 | Entropy=0.6864 | LR=0.000210
# Update 200/600 | AvgEvalReward(20)=4.45 | PolicyLoss=-0.0080 | ValueLoss=0.3296 | Entropy=0.7170 | LR=0.000200
# Update 220/600 | AvgEvalReward(20)=32.26 | PolicyLoss=-0.0099 | ValueLoss=19.6029 | Entropy=0.5362 | LR=0.000190
# Update 240/600 | AvgEvalReward(20)=13.44 | PolicyLoss=-0.0091 | ValueLoss=6.0504 | Entropy=0.7004 | LR=0.000180
# Update 260/600 | AvgEvalReward(20)=93.66 | PolicyLoss=-0.0058 | ValueLoss=23.8034 | Entropy=0.7339 | LR=0.000170
# Update 280/600 | AvgEvalReward(20)=126.90 | PolicyLoss=-0.0055 | ValueLoss=27.7726 | Entropy=0.7547 | LR=0.000160
# Update 300/600 | AvgEvalReward(20)=65.07 | PolicyLoss=-0.0022 | ValueLoss=39.2645 | Entropy=0.7484 | LR=0.000150
# Update 320/600 | AvgEvalReward(20)=34.82 | PolicyLoss=-0.0022 | ValueLoss=29.5833 | Entropy=0.7793 | LR=0.000140
# Update 340/600 | AvgEvalReward(20)=10.44 | PolicyLoss=-0.0105 | ValueLoss=21.6866 | Entropy=0.7373 | LR=0.000130
# Update 360/600 | AvgEvalReward(20)=-21.44 | PolicyLoss=-0.0153 | ValueLoss=7.7271 | Entropy=0.7318 | LR=0.000120
# Update 380/600 | AvgEvalReward(20)=-11.03 | PolicyLoss=-0.0042 | ValueLoss=7.3010 | Entropy=0.8172 | LR=0.000110
# Update 400/600 | AvgEvalReward(20)=49.69 | PolicyLoss=-0.0036 | ValueLoss=12.1353 | Entropy=0.6886 | LR=0.000100
# Update 420/600 | AvgEvalReward(20)=79.72 | PolicyLoss=-0.0035 | ValueLoss=7.3751 | Entropy=0.6348 | LR=0.000090
# Update 440/600 | AvgEvalReward(20)=150.23 | PolicyLoss=-0.0073 | ValueLoss=17.3544 | Entropy=0.6760 | LR=0.000080
# Update 460/600 | AvgEvalReward(20)=150.33 | PolicyLoss=-0.0013 | ValueLoss=28.2704 | Entropy=0.5958 | LR=0.000070
# Update 480/600 | AvgEvalReward(20)=146.13 | PolicyLoss=-0.0013 | ValueLoss=35.4873 | Entropy=0.7763 | LR=0.000060
# Update 500/600 | AvgEvalReward(20)=101.33 | PolicyLoss=-0.0024 | ValueLoss=11.0712 | Entropy=0.6507 | LR=0.000050
# Update 520/600 | AvgEvalReward(20)=78.05 | PolicyLoss=-0.0152 | ValueLoss=18.5924 | Entropy=0.7355 | LR=0.000040
# Update 540/600 | AvgEvalReward(20)=77.62 | PolicyLoss=-0.0012 | ValueLoss=11.8093 | Entropy=0.7090 | LR=0.000030
# Update 560/600 | AvgEvalReward(20)=79.36 | PolicyLoss=-0.0013 | ValueLoss=15.1012 | Entropy=0.7138 | LR=0.000020
# Update 580/600 | AvgEvalReward(20)=55.42 | PolicyLoss=-0.0025 | ValueLoss=10.3850 | Entropy=0.7149 | LR=0.000010
# Update 600/600 | AvgEvalReward(20)=72.04 | PolicyLoss=-0.0000 | ValueLoss=6.1707 | Entropy=0.6688 | LR=0.000000
# Update 20/600 | AvgEvalReward(20)=-168.03 | PolicyLoss=-0.0012 | ValueLoss=52.8756 | Entropy=0.7316 | LR=0.000290
# Update 40/600 | AvgEvalReward(20)=-133.76 | PolicyLoss=-0.0050 | ValueLoss=23.0249 | Entropy=0.7286 | LR=0.000280
# Update 60/600 | AvgEvalReward(20)=-104.18 | PolicyLoss=-0.0063 | ValueLoss=30.6239 | Entropy=0.6023 | LR=0.000270
# Update 80/600 | AvgEvalReward(20)=-74.74 | PolicyLoss=-0.0052 | ValueLoss=18.8658 | Entropy=0.6612 | LR=0.000260
# Update 100/600 | AvgEvalReward(20)=-66.68 | PolicyLoss=-0.0168 | ValueLoss=1.9548 | Entropy=0.6608 | LR=0.000250
# Update 120/600 | AvgEvalReward(20)=-97.14 | PolicyLoss=-0.0116 | ValueLoss=1.3826 | Entropy=0.5884 | LR=0.000240
# Update 140/600 | AvgEvalReward(20)=-87.90 | PolicyLoss=-0.0072 | ValueLoss=0.9692 | Entropy=0.5720 | LR=0.000230
# Update 160/600 | AvgEvalReward(20)=-91.41 | PolicyLoss=-0.0072 | ValueLoss=0.7908 | Entropy=0.6014 | LR=0.000220
# Update 180/600 | AvgEvalReward(20)=-62.26 | PolicyLoss=-0.0068 | ValueLoss=1.2312 | Entropy=0.6760 | LR=0.000210
# Update 200/600 | AvgEvalReward(20)=-174.28 | PolicyLoss=-0.0088 | ValueLoss=19.8882 | Entropy=0.5858 | LR=0.000200
# Update 220/600 | AvgEvalReward(20)=-97.55 | PolicyLoss=-0.0051 | ValueLoss=21.3979 | Entropy=0.6056 | LR=0.000190
# Update 240/600 | AvgEvalReward(20)=8.24 | PolicyLoss=-0.0079 | ValueLoss=2.8982 | Entropy=0.7069 | LR=0.000180
# Update 260/600 | AvgEvalReward(20)=50.69 | PolicyLoss=-0.0165 | ValueLoss=10.4782 | Entropy=0.7167 | LR=0.000170
# Update 280/600 | AvgEvalReward(20)=37.98 | PolicyLoss=-0.0073 | ValueLoss=23.2903 | Entropy=0.7912 | LR=0.000160
# Update 300/600 | AvgEvalReward(20)=64.83 | PolicyLoss=-0.0080 | ValueLoss=12.0464 | Entropy=0.7338 | LR=0.000150
# Update 320/600 | AvgEvalReward(20)=36.19 | PolicyLoss=-0.0047 | ValueLoss=36.4039 | Entropy=0.7741 | LR=0.000140
# Update 340/600 | AvgEvalReward(20)=52.11 | PolicyLoss=-0.0032 | ValueLoss=23.0040 | Entropy=0.6794 | LR=0.000130
# Update 360/600 | AvgEvalReward(20)=-13.61 | PolicyLoss=-0.0291 | ValueLoss=22.5787 | Entropy=0.7282 | LR=0.000120
# Update 380/600 | AvgEvalReward(20)=-68.30 | PolicyLoss=-0.0136 | ValueLoss=5.5545 | Entropy=0.7934 | LR=0.000110
# Update 400/600 | AvgEvalReward(20)=-88.75 | PolicyLoss=-0.0059 | ValueLoss=1.1249 | Entropy=0.7725 | LR=0.000100
# Update 420/600 | AvgEvalReward(20)=-41.07 | PolicyLoss=-0.0039 | ValueLoss=10.4782 | Entropy=0.7635 | LR=0.000090
# Update 440/600 | AvgEvalReward(20)=2.28 | PolicyLoss=-0.0025 | ValueLoss=11.2421 | Entropy=0.7252 | LR=0.000080
# Update 460/600 | AvgEvalReward(20)=38.75 | PolicyLoss=-0.0146 | ValueLoss=30.9842 | Entropy=0.6405 | LR=0.000070
# Update 480/600 | AvgEvalReward(20)=-2.95 | PolicyLoss=-0.0084 | ValueLoss=21.8961 | Entropy=0.7341 | LR=0.000060
# Update 500/600 | AvgEvalReward(20)=58.86 | PolicyLoss=-0.0068 | ValueLoss=12.5247 | Entropy=0.6501 | LR=0.000050
# Update 520/600 | AvgEvalReward(20)=10.19 | PolicyLoss=-0.0035 | ValueLoss=29.5171 | Entropy=0.6576 | LR=0.000040
# Update 540/600 | AvgEvalReward(20)=35.25 | PolicyLoss=-0.0008 | ValueLoss=26.0152 | Entropy=0.7297 | LR=0.000030
# Update 560/600 | AvgEvalReward(20)=23.02 | PolicyLoss=-0.0008 | ValueLoss=14.2511 | Entropy=0.8082 | LR=0.000020
# Update 580/600 | AvgEvalReward(20)=11.51 | PolicyLoss=-0.0004 | ValueLoss=17.2334 | Entropy=0.7068 | LR=0.000010
# Update 600/600 | AvgEvalReward(20)=22.30 | PolicyLoss=-0.0000 | ValueLoss=0.8779 | Entropy=0.8122 | LR=0.000000
# Update 20/600 | AvgEvalReward(20)=-155.41 | PolicyLoss=-0.0161 | ValueLoss=36.0953 | Entropy=0.8540 | LR=0.000290
# Update 40/600 | AvgEvalReward(20)=-154.05 | PolicyLoss=-0.0119 | ValueLoss=32.6854 | Entropy=0.6637 | LR=0.000280
# Update 60/600 | AvgEvalReward(20)=-104.74 | PolicyLoss=-0.0023 | ValueLoss=21.0382 | Entropy=0.5821 | LR=0.000270
# Update 80/600 | AvgEvalReward(20)=-37.05 | PolicyLoss=-0.0152 | ValueLoss=9.0327 | Entropy=0.6291 | LR=0.000260
# Update 100/600 | AvgEvalReward(20)=-43.09 | PolicyLoss=-0.0133 | ValueLoss=1.5303 | Entropy=0.7311 | LR=0.000250
# Update 120/600 | AvgEvalReward(20)=-97.44 | PolicyLoss=-0.0117 | ValueLoss=14.6368 | Entropy=0.7231 | LR=0.000240
# Update 140/600 | AvgEvalReward(20)=-100.44 | PolicyLoss=-0.0081 | ValueLoss=19.1162 | Entropy=0.6980 | LR=0.000230
# Update 160/600 | AvgEvalReward(20)=-107.41 | PolicyLoss=-0.0111 | ValueLoss=13.7187 | Entropy=0.6925 | LR=0.000220
# Update 180/600 | AvgEvalReward(20)=-93.81 | PolicyLoss=-0.0094 | ValueLoss=17.5551 | Entropy=0.7313 | LR=0.000210
# Update 200/600 | AvgEvalReward(20)=-76.30 | PolicyLoss=-0.0162 | ValueLoss=1.2519 | Entropy=0.7121 | LR=0.000200
# Update 220/600 | AvgEvalReward(20)=25.45 | PolicyLoss=-0.0063 | ValueLoss=6.9835 | Entropy=0.7031 | LR=0.000190
# Update 240/600 | AvgEvalReward(20)=18.20 | PolicyLoss=-0.0035 | ValueLoss=1.6385 | Entropy=0.7500 | LR=0.000180
# Update 260/600 | AvgEvalReward(20)=-19.47 | PolicyLoss=-0.0071 | ValueLoss=6.6455 | Entropy=0.6827 | LR=0.000170
# Update 280/600 | AvgEvalReward(20)=-10.85 | PolicyLoss=-0.0063 | ValueLoss=18.9860 | Entropy=0.7725 | LR=0.000160
# Update 300/600 | AvgEvalReward(20)=-37.12 | PolicyLoss=-0.0025 | ValueLoss=17.2710 | Entropy=0.6413 | LR=0.000150
# Update 320/600 | AvgEvalReward(20)=-61.20 | PolicyLoss=-0.0057 | ValueLoss=2.1113 | Entropy=0.8269 | LR=0.000140
# Update 340/600 | AvgEvalReward(20)=-38.58 | PolicyLoss=-0.0097 | ValueLoss=7.0354 | Entropy=0.7595 | LR=0.000130
# Update 360/600 | AvgEvalReward(20)=12.44 | PolicyLoss=-0.0053 | ValueLoss=1.0425 | Entropy=0.6520 | LR=0.000120
# Update 380/600 | AvgEvalReward(20)=13.27 | PolicyLoss=-0.0042 | ValueLoss=7.3389 | Entropy=0.6704 | LR=0.000110
# Update 400/600 | AvgEvalReward(20)=1.21 | PolicyLoss=-0.0061 | ValueLoss=5.5344 | Entropy=0.7483 | LR=0.000100
# Update 420/600 | AvgEvalReward(20)=-14.28 | PolicyLoss=-0.0079 | ValueLoss=6.6458 | Entropy=0.7209 | LR=0.000090
# Update 440/600 | AvgEvalReward(20)=11.94 | PolicyLoss=-0.0014 | ValueLoss=11.1104 | Entropy=0.6507 | LR=0.000080
# Update 460/600 | AvgEvalReward(20)=4.20 | PolicyLoss=-0.0119 | ValueLoss=6.4818 | Entropy=0.6354 | LR=0.000070
# Update 480/600 | AvgEvalReward(20)=4.92 | PolicyLoss=-0.0069 | ValueLoss=7.1533 | Entropy=0.6006 | LR=0.000060
# Update 500/600 | AvgEvalReward(20)=-18.10 | PolicyLoss=-0.0040 | ValueLoss=22.7388 | Entropy=0.6595 | LR=0.000050
# Update 520/600 | AvgEvalReward(20)=8.10 | PolicyLoss=-0.0012 | ValueLoss=11.5244 | Entropy=0.6584 | LR=0.000040
# Update 540/600 | AvgEvalReward(20)=27.95 | PolicyLoss=-0.0012 | ValueLoss=21.6387 | Entropy=0.6398 | LR=0.000030
# Update 560/600 | AvgEvalReward(20)=15.37 | PolicyLoss=-0.0008 | ValueLoss=18.9005 | Entropy=0.6521 | LR=0.000020
# Update 580/600 | AvgEvalReward(20)=-16.06 | PolicyLoss=-0.0006 | ValueLoss=7.5865 | Entropy=0.6490 | LR=0.000010
# Update 600/600 | AvgEvalReward(20)=2.61 | PolicyLoss=-0.0001 | ValueLoss=5.7355 | Entropy=0.7129 | LR=0.000000
# Update 20/600 | AvgEvalReward(20)=-120.00 | PolicyLoss=-0.0015 | ValueLoss=456.8763 | Entropy=1.1403 | LR=0.000290
# Update 40/600 | AvgEvalReward(20)=-80.52 | PolicyLoss=-0.0013 | ValueLoss=300.9886 | Entropy=1.2400 | LR=0.000280
# Update 60/600 | AvgEvalReward(20)=-90.40 | PolicyLoss=-0.0011 | ValueLoss=108.9148 | Entropy=1.1134 | LR=0.000270
# Update 80/600 | AvgEvalReward(20)=-68.16 | PolicyLoss=-0.0011 | ValueLoss=193.8175 | Entropy=1.0606 | LR=0.000260
# Update 100/600 | AvgEvalReward(20)=-0.59 | PolicyLoss=-0.0022 | ValueLoss=46.8599 | Entropy=1.0162 | LR=0.000250
# Update 120/600 | AvgEvalReward(20)=-19.40 | PolicyLoss=-0.0018 | ValueLoss=134.8652 | Entropy=0.9391 | LR=0.000240
# Update 140/600 | AvgEvalReward(20)=-5.68 | PolicyLoss=-0.0002 | ValueLoss=90.8233 | Entropy=0.8852 | LR=0.000230
# Update 160/600 | AvgEvalReward(20)=11.02 | PolicyLoss=-0.0016 | ValueLoss=281.0301 | Entropy=0.8102 | LR=0.000220
# Update 180/600 | AvgEvalReward(20)=69.64 | PolicyLoss=-0.0027 | ValueLoss=221.8354 | Entropy=0.8841 | LR=0.000210
# Update 200/600 | AvgEvalReward(20)=84.59 | PolicyLoss=-0.0002 | ValueLoss=289.5832 | Entropy=0.8388 | LR=0.000200
# Update 220/600 | AvgEvalReward(20)=77.93 | PolicyLoss=-0.0018 | ValueLoss=382.4434 | Entropy=0.7988 | LR=0.000190
# Update 240/600 | AvgEvalReward(20)=54.34 | PolicyLoss=-0.0019 | ValueLoss=276.3801 | Entropy=0.7976 | LR=0.000180
# Update 260/600 | AvgEvalReward(20)=96.48 | PolicyLoss=0.0001 | ValueLoss=313.0404 | Entropy=0.6785 | LR=0.000170
# Update 280/600 | AvgEvalReward(20)=104.44 | PolicyLoss=-0.0006 | ValueLoss=279.9490 | Entropy=0.7411 | LR=0.000160
# Update 300/600 | AvgEvalReward(20)=84.58 | PolicyLoss=-0.0015 | ValueLoss=193.9283 | Entropy=0.6198 | LR=0.000150
# Update 320/600 | AvgEvalReward(20)=80.18 | PolicyLoss=-0.0013 | ValueLoss=202.7761 | Entropy=0.6721 | LR=0.000140
# Update 340/600 | AvgEvalReward(20)=117.91 | PolicyLoss=0.0001 | ValueLoss=319.4735 | Entropy=0.7652 | LR=0.000130
# Update 360/600 | AvgEvalReward(20)=100.63 | PolicyLoss=-0.0018 | ValueLoss=197.6175 | Entropy=0.7271 | LR=0.000120
# Update 380/600 | AvgEvalReward(20)=78.00 | PolicyLoss=-0.0003 | ValueLoss=306.4502 | Entropy=0.6674 | LR=0.000110
# Update 400/600 | AvgEvalReward(20)=148.00 | PolicyLoss=0.0001 | ValueLoss=278.7863 | Entropy=0.7686 | LR=0.000100
# Update 420/600 | AvgEvalReward(20)=124.91 | PolicyLoss=-0.0006 | ValueLoss=279.9145 | Entropy=0.6780 | LR=0.000090
# Update 440/600 | AvgEvalReward(20)=107.07 | PolicyLoss=-0.0006 | ValueLoss=101.4013 | Entropy=0.6877 | LR=0.000080
# Update 460/600 | AvgEvalReward(20)=129.37 | PolicyLoss=-0.0009 | ValueLoss=274.1669 | Entropy=0.6980 | LR=0.000070
# Update 480/600 | AvgEvalReward(20)=151.13 | PolicyLoss=-0.0003 | ValueLoss=216.2733 | Entropy=0.6312 | LR=0.000060
# Update 500/600 | AvgEvalReward(20)=88.37 | PolicyLoss=-0.0002 | ValueLoss=238.7222 | Entropy=0.6911 | LR=0.000050
# Update 520/600 | AvgEvalReward(20)=91.06 | PolicyLoss=-0.0005 | ValueLoss=302.6721 | Entropy=0.5892 | LR=0.000040
# Update 540/600 | AvgEvalReward(20)=93.24 | PolicyLoss=0.0003 | ValueLoss=136.9328 | Entropy=0.8187 | LR=0.000030
# Update 560/600 | AvgEvalReward(20)=123.95 | PolicyLoss=-0.0004 | ValueLoss=327.6550 | Entropy=0.7256 | LR=0.000020
# Update 580/600 | AvgEvalReward(20)=146.83 | PolicyLoss=-0.0010 | ValueLoss=155.8361 | Entropy=0.7069 | LR=0.000010
# Update 600/600 | AvgEvalReward(20)=161.80 | PolicyLoss=-0.0000 | ValueLoss=172.5750 | Entropy=0.5592 | LR=0.000000
# Update 20/600 | AvgEvalReward(20)=-151.64 | PolicyLoss=-0.0045 | ValueLoss=530.0458 | Entropy=1.1996 | LR=0.000290
# Update 40/600 | AvgEvalReward(20)=-119.97 | PolicyLoss=-0.0051 | ValueLoss=680.1271 | Entropy=1.1082 | LR=0.000280
# Update 60/600 | AvgEvalReward(20)=-103.19 | PolicyLoss=-0.0022 | ValueLoss=611.3436 | Entropy=0.9874 | LR=0.000270
# Update 80/600 | AvgEvalReward(20)=-151.94 | PolicyLoss=0.0003 | ValueLoss=424.1918 | Entropy=1.0559 | LR=0.000260
# Update 100/600 | AvgEvalReward(20)=-115.63 | PolicyLoss=0.0018 | ValueLoss=358.9816 | Entropy=1.0416 | LR=0.000250
# Update 120/600 | AvgEvalReward(20)=-152.64 | PolicyLoss=-0.0009 | ValueLoss=232.8028 | Entropy=0.9583 | LR=0.000240
# Update 140/600 | AvgEvalReward(20)=-119.63 | PolicyLoss=-0.0026 | ValueLoss=256.2682 | Entropy=0.9383 | LR=0.000230
# Update 160/600 | AvgEvalReward(20)=-121.45 | PolicyLoss=-0.0001 | ValueLoss=281.8822 | Entropy=0.9901 | LR=0.000220
# Update 180/600 | AvgEvalReward(20)=-127.33 | PolicyLoss=-0.0011 | ValueLoss=291.6098 | Entropy=0.9434 | LR=0.000210
# Update 200/600 | AvgEvalReward(20)=-100.18 | PolicyLoss=-0.0027 | ValueLoss=158.3262 | Entropy=0.9845 | LR=0.000200
# Update 220/600 | AvgEvalReward(20)=-92.91 | PolicyLoss=-0.0048 | ValueLoss=139.4920 | Entropy=1.0467 | LR=0.000190
# Update 240/600 | AvgEvalReward(20)=-66.82 | PolicyLoss=-0.0061 | ValueLoss=65.4985 | Entropy=0.9962 | LR=0.000180
# Update 260/600 | AvgEvalReward(20)=-66.93 | PolicyLoss=-0.0001 | ValueLoss=157.8384 | Entropy=1.0504 | LR=0.000170
# Update 280/600 | AvgEvalReward(20)=-95.59 | PolicyLoss=-0.0025 | ValueLoss=102.9351 | Entropy=0.9292 | LR=0.000160
# Update 300/600 | AvgEvalReward(20)=-36.30 | PolicyLoss=-0.0010 | ValueLoss=193.0727 | Entropy=0.8028 | LR=0.000150
# Update 320/600 | AvgEvalReward(20)=-66.20 | PolicyLoss=-0.0025 | ValueLoss=117.6239 | Entropy=0.8843 | LR=0.000140
# Update 340/600 | AvgEvalReward(20)=-20.40 | PolicyLoss=0.0001 | ValueLoss=186.7523 | Entropy=0.9383 | LR=0.000130
# Update 360/600 | AvgEvalReward(20)=-39.47 | PolicyLoss=-0.0003 | ValueLoss=327.3275 | Entropy=0.8077 | LR=0.000120
# Update 380/600 | AvgEvalReward(20)=-4.41 | PolicyLoss=-0.0008 | ValueLoss=200.8025 | Entropy=0.8438 | LR=0.000110
# Update 400/600 | AvgEvalReward(20)=0.03 | PolicyLoss=-0.0008 | ValueLoss=177.7809 | Entropy=0.9084 | LR=0.000100
# Update 420/600 | AvgEvalReward(20)=-13.49 | PolicyLoss=-0.0008 | ValueLoss=130.4144 | Entropy=0.8592 | LR=0.000090
# Update 440/600 | AvgEvalReward(20)=13.41 | PolicyLoss=-0.0002 | ValueLoss=280.8427 | Entropy=0.8295 | LR=0.000080
# Update 460/600 | AvgEvalReward(20)=47.90 | PolicyLoss=0.0007 | ValueLoss=228.6144 | Entropy=0.8902 | LR=0.000070
# Update 480/600 | AvgEvalReward(20)=18.91 | PolicyLoss=-0.0001 | ValueLoss=157.5387 | Entropy=0.9268 | LR=0.000060
# Update 500/600 | AvgEvalReward(20)=51.24 | PolicyLoss=0.0000 | ValueLoss=263.9709 | Entropy=0.8483 | LR=0.000050
# Update 520/600 | AvgEvalReward(20)=61.37 | PolicyLoss=-0.0010 | ValueLoss=73.6025 | Entropy=0.9243 | LR=0.000040
# Update 540/600 | AvgEvalReward(20)=68.79 | PolicyLoss=-0.0003 | ValueLoss=93.4205 | Entropy=0.8414 | LR=0.000030
# Update 560/600 | AvgEvalReward(20)=53.67 | PolicyLoss=-0.0000 | ValueLoss=288.4601 | Entropy=0.8411 | LR=0.000020
# Update 580/600 | AvgEvalReward(20)=81.36 | PolicyLoss=-0.0001 | ValueLoss=233.1748 | Entropy=0.8090 | LR=0.000010
# Update 600/600 | AvgEvalReward(20)=68.85 | PolicyLoss=0.0000 | ValueLoss=317.2477 | Entropy=0.8246 | LR=0.000000
# Update 20/600 | AvgEvalReward(20)=-131.93 | PolicyLoss=-0.0047 | ValueLoss=628.0172 | Entropy=1.1011 | LR=0.000290
# Update 40/600 | AvgEvalReward(20)=-100.53 | PolicyLoss=-0.0001 | ValueLoss=346.9046 | Entropy=1.0933 | LR=0.000280
# Update 60/600 | AvgEvalReward(20)=-90.47 | PolicyLoss=-0.0009 | ValueLoss=233.8681 | Entropy=1.0343 | LR=0.000270
# Update 80/600 | AvgEvalReward(20)=-106.52 | PolicyLoss=-0.0042 | ValueLoss=173.3668 | Entropy=1.0884 | LR=0.000260
# Update 100/600 | AvgEvalReward(20)=-58.27 | PolicyLoss=-0.0044 | ValueLoss=125.0705 | Entropy=1.0511 | LR=0.000250
# Update 120/600 | AvgEvalReward(20)=-99.19 | PolicyLoss=-0.0005 | ValueLoss=102.0145 | Entropy=1.0229 | LR=0.000240
# Update 140/600 | AvgEvalReward(20)=-55.69 | PolicyLoss=-0.0033 | ValueLoss=138.6620 | Entropy=1.0266 | LR=0.000230
# Update 160/600 | AvgEvalReward(20)=-23.67 | PolicyLoss=-0.0054 | ValueLoss=80.8464 | Entropy=1.0522 | LR=0.000220
# Update 180/600 | AvgEvalReward(20)=-10.92 | PolicyLoss=-0.0025 | ValueLoss=172.0399 | Entropy=1.0176 | LR=0.000210
# Update 200/600 | AvgEvalReward(20)=-23.49 | PolicyLoss=-0.0026 | ValueLoss=284.5256 | Entropy=0.9359 | LR=0.000200
# Update 220/600 | AvgEvalReward(20)=-14.10 | PolicyLoss=-0.0003 | ValueLoss=366.3391 | Entropy=0.9705 | LR=0.000190
# Update 240/600 | AvgEvalReward(20)=28.09 | PolicyLoss=-0.0003 | ValueLoss=85.4270 | Entropy=0.9532 | LR=0.000180
# Update 260/600 | AvgEvalReward(20)=23.17 | PolicyLoss=-0.0008 | ValueLoss=22.9413 | Entropy=0.8974 | LR=0.000170
# Update 280/600 | AvgEvalReward(20)=28.47 | PolicyLoss=0.0002 | ValueLoss=97.6242 | Entropy=0.9581 | LR=0.000160
# Update 300/600 | AvgEvalReward(20)=63.74 | PolicyLoss=-0.0005 | ValueLoss=63.8075 | Entropy=1.0405 | LR=0.000150
# Update 320/600 | AvgEvalReward(20)=38.08 | PolicyLoss=-0.0025 | ValueLoss=134.6411 | Entropy=0.8918 | LR=0.000140
# Update 340/600 | AvgEvalReward(20)=55.59 | PolicyLoss=0.0006 | ValueLoss=99.5962 | Entropy=0.9462 | LR=0.000130
# Update 360/600 | AvgEvalReward(20)=64.44 | PolicyLoss=-0.0007 | ValueLoss=65.0762 | Entropy=0.9406 | LR=0.000120
# Update 380/600 | AvgEvalReward(20)=61.45 | PolicyLoss=-0.0034 | ValueLoss=174.1261 | Entropy=0.7263 | LR=0.000110
# Update 400/600 | AvgEvalReward(20)=52.42 | PolicyLoss=-0.0002 | ValueLoss=124.1507 | Entropy=0.8286 | LR=0.000100
# Update 420/600 | AvgEvalReward(20)=36.79 | PolicyLoss=-0.0024 | ValueLoss=25.1780 | Entropy=0.8868 | LR=0.000090
# Update 440/600 | AvgEvalReward(20)=28.63 | PolicyLoss=-0.0004 | ValueLoss=207.1245 | Entropy=0.8700 | LR=0.000080
# Update 460/600 | AvgEvalReward(20)=34.30 | PolicyLoss=-0.0004 | ValueLoss=43.6123 | Entropy=0.9244 | LR=0.000070
# Update 480/600 | AvgEvalReward(20)=70.75 | PolicyLoss=0.0001 | ValueLoss=87.1313 | Entropy=0.8837 | LR=0.000060
# Update 500/600 | AvgEvalReward(20)=48.21 | PolicyLoss=0.0002 | ValueLoss=251.4712 | Entropy=0.8681 | LR=0.000050
# Update 520/600 | AvgEvalReward(20)=64.50 | PolicyLoss=-0.0000 | ValueLoss=83.0435 | Entropy=0.7741 | LR=0.000040
# Update 540/600 | AvgEvalReward(20)=89.12 | PolicyLoss=-0.0004 | ValueLoss=121.9892 | Entropy=0.9312 | LR=0.000030
# Update 560/600 | AvgEvalReward(20)=70.86 | PolicyLoss=0.0000 | ValueLoss=48.4930 | Entropy=0.9713 | LR=0.000020
# Update 580/600 | AvgEvalReward(20)=73.07 | PolicyLoss=-0.0000 | ValueLoss=16.5515 | Entropy=0.9261 | LR=0.000010
# Update 600/600 | AvgEvalReward(20)=53.15 | PolicyLoss=-0.0000 | ValueLoss=46.9985 | Entropy=0.8670 | LR=0.000000
# Update 20/600 | AvgEvalReward(20)=-133.00 | PolicyLoss=-0.0054 | ValueLoss=2243.6186 | Entropy=1.3039 | LR=0.000290
# Update 40/600 | AvgEvalReward(20)=-96.98 | PolicyLoss=-0.0060 | ValueLoss=2125.4699 | Entropy=1.1932 | LR=0.000280
# Update 60/600 | AvgEvalReward(20)=-87.48 | PolicyLoss=0.0014 | ValueLoss=3683.0009 | Entropy=1.1787 | LR=0.000270
# Update 80/600 | AvgEvalReward(20)=-76.01 | PolicyLoss=0.0016 | ValueLoss=2047.1099 | Entropy=1.1500 | LR=0.000260
# Update 100/600 | AvgEvalReward(20)=-143.40 | PolicyLoss=0.0014 | ValueLoss=5386.0521 | Entropy=1.0923 | LR=0.000250
# Update 120/600 | AvgEvalReward(20)=-140.11 | PolicyLoss=-0.0014 | ValueLoss=1420.7545 | Entropy=1.1092 | LR=0.000240
# Update 140/600 | AvgEvalReward(20)=-100.96 | PolicyLoss=0.0009 | ValueLoss=383.3709 | Entropy=0.9907 | LR=0.000230
# Update 160/600 | AvgEvalReward(20)=-102.48 | PolicyLoss=0.0006 | ValueLoss=1534.0834 | Entropy=0.9983 | LR=0.000220
# Update 180/600 | AvgEvalReward(20)=-109.87 | PolicyLoss=0.0001 | ValueLoss=2881.9564 | Entropy=0.9538 | LR=0.000210
# Update 200/600 | AvgEvalReward(20)=-138.01 | PolicyLoss=0.0001 | ValueLoss=3092.4540 | Entropy=0.9585 | LR=0.000200
# Update 220/600 | AvgEvalReward(20)=-139.21 | PolicyLoss=0.0015 | ValueLoss=3564.0704 | Entropy=1.0075 | LR=0.000190
# Update 240/600 | AvgEvalReward(20)=-122.60 | PolicyLoss=-0.0005 | ValueLoss=2504.3813 | Entropy=1.0067 | LR=0.000180
# Update 260/600 | AvgEvalReward(20)=-159.85 | PolicyLoss=-0.0021 | ValueLoss=2041.0694 | Entropy=1.1010 | LR=0.000170
# Update 280/600 | AvgEvalReward(20)=-128.95 | PolicyLoss=-0.0028 | ValueLoss=3157.8819 | Entropy=1.1029 | LR=0.000160
# Update 300/600 | AvgEvalReward(20)=-135.76 | PolicyLoss=-0.0013 | ValueLoss=770.6562 | Entropy=0.9704 | LR=0.000150
# Update 320/600 | AvgEvalReward(20)=-135.45 | PolicyLoss=-0.0005 | ValueLoss=591.0031 | Entropy=1.0389 | LR=0.000140
# Update 340/600 | AvgEvalReward(20)=-120.73 | PolicyLoss=0.0001 | ValueLoss=1059.7912 | Entropy=1.1107 | LR=0.000130
# Update 360/600 | AvgEvalReward(20)=-127.55 | PolicyLoss=-0.0008 | ValueLoss=2177.6927 | Entropy=1.0094 | LR=0.000120
# Update 380/600 | AvgEvalReward(20)=-147.97 | PolicyLoss=-0.0009 | ValueLoss=957.7669 | Entropy=1.0179 | LR=0.000110
# Update 400/600 | AvgEvalReward(20)=-111.15 | PolicyLoss=0.0000 | ValueLoss=1464.4713 | Entropy=1.0847 | LR=0.000100
# Update 420/600 | AvgEvalReward(20)=-114.99 | PolicyLoss=0.0001 | ValueLoss=2050.6279 | Entropy=1.0920 | LR=0.000090
# Update 440/600 | AvgEvalReward(20)=-120.35 | PolicyLoss=0.0008 | ValueLoss=4872.2122 | Entropy=1.1729 | LR=0.000080
# Update 460/600 | AvgEvalReward(20)=-106.47 | PolicyLoss=0.0003 | ValueLoss=2207.5869 | Entropy=1.0894 | LR=0.000070
# Update 480/600 | AvgEvalReward(20)=-151.81 | PolicyLoss=0.0001 | ValueLoss=2095.6467 | Entropy=1.1269 | LR=0.000060
# Update 500/600 | AvgEvalReward(20)=-142.07 | PolicyLoss=-0.0004 | ValueLoss=2165.0214 | Entropy=1.1689 | LR=0.000050
# Update 520/600 | AvgEvalReward(20)=-115.63 | PolicyLoss=-0.0003 | ValueLoss=1596.4469 | Entropy=1.1737 | LR=0.000040
# Update 540/600 | AvgEvalReward(20)=-112.60 | PolicyLoss=0.0002 | ValueLoss=1818.3501 | Entropy=1.1775 | LR=0.000030
# Update 560/600 | AvgEvalReward(20)=-110.40 | PolicyLoss=0.0001 | ValueLoss=1306.9623 | Entropy=1.1692 | LR=0.000020
# Update 580/600 | AvgEvalReward(20)=-94.43 | PolicyLoss=0.0001 | ValueLoss=978.9854 | Entropy=1.1850 | LR=0.000010
# Update 600/600 | AvgEvalReward(20)=-109.27 | PolicyLoss=0.0000 | ValueLoss=1852.3282 | Entropy=1.1849 | LR=0.000000
# Update 20/600 | AvgEvalReward(20)=-130.89 | PolicyLoss=-0.0061 | ValueLoss=2071.8032 | Entropy=1.2709 | LR=0.000290
# Update 40/600 | AvgEvalReward(20)=-60.63 | PolicyLoss=0.0012 | ValueLoss=1528.9986 | Entropy=1.2181 | LR=0.000280
# Update 60/600 | AvgEvalReward(20)=-86.72 | PolicyLoss=0.0037 | ValueLoss=1818.2729 | Entropy=1.1787 | LR=0.000270
# Update 80/600 | AvgEvalReward(20)=-103.62 | PolicyLoss=-0.0035 | ValueLoss=3050.9404 | Entropy=1.1681 | LR=0.000260
# Update 100/600 | AvgEvalReward(20)=-99.67 | PolicyLoss=0.0012 | ValueLoss=3699.0734 | Entropy=1.0662 | LR=0.000250
# Update 120/600 | AvgEvalReward(20)=-97.72 | PolicyLoss=-0.0056 | ValueLoss=3784.3223 | Entropy=1.0750 | LR=0.000240
# Update 140/600 | AvgEvalReward(20)=-77.72 | PolicyLoss=0.0020 | ValueLoss=1153.9574 | Entropy=1.0974 | LR=0.000230
# Update 160/600 | AvgEvalReward(20)=-103.66 | PolicyLoss=-0.0006 | ValueLoss=1315.3228 | Entropy=1.1128 | LR=0.000220
# Update 180/600 | AvgEvalReward(20)=-98.63 | PolicyLoss=-0.0027 | ValueLoss=1748.8472 | Entropy=1.0721 | LR=0.000210
# Update 200/600 | AvgEvalReward(20)=-88.83 | PolicyLoss=0.0022 | ValueLoss=1951.2439 | Entropy=1.1230 | LR=0.000200
# Update 220/600 | AvgEvalReward(20)=-112.45 | PolicyLoss=0.0002 | ValueLoss=2197.6215 | Entropy=1.1690 | LR=0.000190
# Update 240/600 | AvgEvalReward(20)=-181.57 | PolicyLoss=-0.0031 | ValueLoss=5028.1204 | Entropy=1.1451 | LR=0.000180
# Update 260/600 | AvgEvalReward(20)=-168.46 | PolicyLoss=-0.0005 | ValueLoss=3248.4346 | Entropy=1.1459 | LR=0.000170
# Update 280/600 | AvgEvalReward(20)=-104.02 | PolicyLoss=-0.0013 | ValueLoss=1933.8838 | Entropy=1.1860 | LR=0.000160
# Update 300/600 | AvgEvalReward(20)=-95.40 | PolicyLoss=0.0007 | ValueLoss=852.9864 | Entropy=1.2061 | LR=0.000150
# Update 320/600 | AvgEvalReward(20)=-109.82 | PolicyLoss=0.0005 | ValueLoss=4718.0770 | Entropy=1.0684 | LR=0.000140
# Update 340/600 | AvgEvalReward(20)=-110.48 | PolicyLoss=-0.0001 | ValueLoss=5760.1829 | Entropy=1.0577 | LR=0.000130
# Update 360/600 | AvgEvalReward(20)=-103.11 | PolicyLoss=-0.0013 | ValueLoss=4309.3081 | Entropy=1.1679 | LR=0.000120
# Update 380/600 | AvgEvalReward(20)=-86.08 | PolicyLoss=-0.0004 | ValueLoss=1500.3567 | Entropy=1.1752 | LR=0.000110
# Update 400/600 | AvgEvalReward(20)=-89.74 | PolicyLoss=-0.0006 | ValueLoss=772.7868 | Entropy=1.2237 | LR=0.000100
# Update 420/600 | AvgEvalReward(20)=-76.21 | PolicyLoss=0.0011 | ValueLoss=852.8428 | Entropy=1.1188 | LR=0.000090
# Update 440/600 | AvgEvalReward(20)=-85.95 | PolicyLoss=-0.0002 | ValueLoss=2242.0514 | Entropy=1.1521 | LR=0.000080
# Update 460/600 | AvgEvalReward(20)=-76.65 | PolicyLoss=-0.0001 | ValueLoss=1092.4123 | Entropy=1.1191 | LR=0.000070
# Update 480/600 | AvgEvalReward(20)=-82.32 | PolicyLoss=-0.0016 | ValueLoss=2816.4315 | Entropy=1.1366 | LR=0.000060
# Update 500/600 | AvgEvalReward(20)=-60.43 | PolicyLoss=-0.0002 | ValueLoss=738.3292 | Entropy=1.1742 | LR=0.000050
# Update 520/600 | AvgEvalReward(20)=-70.71 | PolicyLoss=0.0000 | ValueLoss=809.8510 | Entropy=1.1574 | LR=0.000040
# Update 540/600 | AvgEvalReward(20)=-76.79 | PolicyLoss=-0.0003 | ValueLoss=509.9784 | Entropy=1.1923 | LR=0.000030
# Update 560/600 | AvgEvalReward(20)=-68.73 | PolicyLoss=-0.0001 | ValueLoss=1131.7686 | Entropy=1.1617 | LR=0.000020
# Update 580/600 | AvgEvalReward(20)=-56.42 | PolicyLoss=-0.0001 | ValueLoss=462.5492 | Entropy=1.1898 | LR=0.000010
# Update 600/600 | AvgEvalReward(20)=-61.29 | PolicyLoss=-0.0000 | ValueLoss=1067.8111 | Entropy=1.1785 | LR=0.000000
# Update 20/600 | AvgEvalReward(20)=-101.88 | PolicyLoss=-0.0028 | ValueLoss=1028.6491 | Entropy=1.2422 | LR=0.000290
# Update 40/600 | AvgEvalReward(20)=-61.81 | PolicyLoss=0.0003 | ValueLoss=2014.9818 | Entropy=1.1416 | LR=0.000280
# Update 60/600 | AvgEvalReward(20)=-56.63 | PolicyLoss=0.0017 | ValueLoss=2327.0880 | Entropy=1.0876 | LR=0.000270
# Update 80/600 | AvgEvalReward(20)=-102.48 | PolicyLoss=0.0012 | ValueLoss=4109.4575 | Entropy=1.0083 | LR=0.000260
# Update 100/600 | AvgEvalReward(20)=-84.67 | PolicyLoss=-0.0101 | ValueLoss=3134.2355 | Entropy=1.0352 | LR=0.000250
# Update 120/600 | AvgEvalReward(20)=-88.96 | PolicyLoss=0.0032 | ValueLoss=4634.4281 | Entropy=1.0161 | LR=0.000240
# Update 140/600 | AvgEvalReward(20)=-92.33 | PolicyLoss=0.0013 | ValueLoss=1957.0762 | Entropy=1.1735 | LR=0.000230
# Update 160/600 | AvgEvalReward(20)=-88.81 | PolicyLoss=-0.0008 | ValueLoss=2349.0960 | Entropy=1.2416 | LR=0.000220
# Update 180/600 | AvgEvalReward(20)=-119.76 | PolicyLoss=-0.0005 | ValueLoss=1797.4152 | Entropy=1.2369 | LR=0.000210
# Update 200/600 | AvgEvalReward(20)=-123.82 | PolicyLoss=-0.0005 | ValueLoss=1908.0869 | Entropy=1.2038 | LR=0.000200
# Update 220/600 | AvgEvalReward(20)=-115.96 | PolicyLoss=0.0000 | ValueLoss=5308.7204 | Entropy=1.2187 | LR=0.000190
# Update 240/600 | AvgEvalReward(20)=-155.41 | PolicyLoss=0.0015 | ValueLoss=1803.7701 | Entropy=1.2399 | LR=0.000180
# Update 260/600 | AvgEvalReward(20)=-148.83 | PolicyLoss=-0.0001 | ValueLoss=1124.6609 | Entropy=1.1818 | LR=0.000170
# Update 280/600 | AvgEvalReward(20)=-113.27 | PolicyLoss=-0.0006 | ValueLoss=1573.8970 | Entropy=1.1797 | LR=0.000160
# Update 300/600 | AvgEvalReward(20)=-116.81 | PolicyLoss=0.0003 | ValueLoss=661.3509 | Entropy=1.1682 | LR=0.000150
# Update 320/600 | AvgEvalReward(20)=-123.04 | PolicyLoss=-0.0000 | ValueLoss=3996.1935 | Entropy=1.1763 | LR=0.000140
# Update 340/600 | AvgEvalReward(20)=-172.26 | PolicyLoss=-0.0008 | ValueLoss=2875.0795 | Entropy=1.2104 | LR=0.000130
# Update 360/600 | AvgEvalReward(20)=-123.09 | PolicyLoss=-0.0006 | ValueLoss=1970.8966 | Entropy=1.1809 | LR=0.000120
# Update 380/600 | AvgEvalReward(20)=-106.79 | PolicyLoss=-0.0033 | ValueLoss=1560.5207 | Entropy=1.1677 | LR=0.000110
# Update 400/600 | AvgEvalReward(20)=-106.48 | PolicyLoss=-0.0000 | ValueLoss=449.0738 | Entropy=1.1727 | LR=0.000100
# Update 420/600 | AvgEvalReward(20)=-90.81 | PolicyLoss=0.0001 | ValueLoss=695.4562 | Entropy=1.1719 | LR=0.000090
# Update 440/600 | AvgEvalReward(20)=-74.84 | PolicyLoss=-0.0043 | ValueLoss=1497.3880 | Entropy=1.1596 | LR=0.000080
# Update 460/600 | AvgEvalReward(20)=-88.32 | PolicyLoss=-0.0002 | ValueLoss=1915.4017 | Entropy=1.1825 | LR=0.000070
# Update 480/600 | AvgEvalReward(20)=-71.54 | PolicyLoss=-0.0006 | ValueLoss=1393.0209 | Entropy=1.1509 | LR=0.000060
# Update 500/600 | AvgEvalReward(20)=-81.72 | PolicyLoss=0.0007 | ValueLoss=1252.4114 | Entropy=1.2084 | LR=0.000050
# Update 520/600 | AvgEvalReward(20)=-75.67 | PolicyLoss=-0.0005 | ValueLoss=542.0013 | Entropy=1.2182 | LR=0.000040
# Update 540/600 | AvgEvalReward(20)=-73.54 | PolicyLoss=-0.0001 | ValueLoss=2319.6789 | Entropy=1.2079 | LR=0.000030
# Update 560/600 | AvgEvalReward(20)=-75.60 | PolicyLoss=-0.0000 | ValueLoss=1349.9511 | Entropy=1.1807 | LR=0.000020
# Update 580/600 | AvgEvalReward(20)=-83.27 | PolicyLoss=-0.0002 | ValueLoss=1929.0875 | Entropy=1.1808 | LR=0.000010
# Update 600/600 | AvgEvalReward(20)=-76.95 | PolicyLoss=-0.0000 | ValueLoss=935.7189 | Entropy=1.1734 | LR=0.000000
# Plot saved: /Users/dennisjohansson/Skola/Programering/VT4/TDDE78/tdde78lab/labs/lab2_policy_gradient/experiments/plots/ppo_effect_of_gae_lambda_on_lunarlander-v3.png
# lambda=0.0: 32.3 ± 29.2
# lambda=0.95: 94.6 ± 47.9
# lambda=1.0: -82.5 ± 20.0

# %% [markdown]
# ---
#
# ## Summary
#
# **TODO:** Write a brief summary of your findings (double-click to edit).
#
# 1. **B.1 — Baseline ablation:** Does the value baseline help REINFORCE on CartPole? Describe the difference in convergence speed and variance between the two variants.
#
#     The value baseline helped REINFORCE mainly by reducing variance and making training more stable. In our run, the version without a baseline reached higher rewards earlier, but it also showed larger fluctuations. The baseline variant generally had smoother learning curves and more consistent behavior across training, even if it did not converge faster.
#
#
# 2. **B.2 — GAE lambda:** Which λ value performed best on LunarLander-v3? Describe the bias-variance trade-off you observed — what happens at the extremes (λ = 0 and λ = 1) and why?
#
#     λ= 0.95 performed best. This value gave the best trade-off between bias and variance. At λ = 0, GAE is close to one-step TD, which has low variance but high bias, so learning can become less accurate. At λ = 1, GAE becomes closer to Monte Carlo estimation, which has very low bias but high variance, making learning noisier and less stable. The intermediate value λ = 0.95 balanced these effects and gave the strongest performance.

# %% [markdown]
# ---
#
# **Lab designed by Amath Sow:** amath.sow@liu.se
#
# **TDDE78 — Deep Reinforcement Learning, Linköping University, Spring 2026**
