# %% [markdown]
# # Lab 1: Value-Based Deep Reinforcement Learning
#
# ## TDDE78 — Deep Reinforcement Learning
# ### Linköping University, Spring 2026
#
# ---
#
# In this lab you will implement **Deep Q-Networks (DQN)** and two key variants:
# - **Double DQN** — reduces overestimation bias
# - **Dueling DQN** — separates state value from action advantage
#
# The lab is divided into:
# - **Part A** — Implementation (fill in the TODO sections)
# - **Part B** — Experiments (run systematic evaluations and analyze results)
#
# **Instructions:** Complete all cells marked with `# TODO`. Do not modify the provided helper code unless explicitly asked.

# %% [markdown]
# ## Setup
#
# Run the cell below to import all necessary libraries and verify your environment.

# %%
import os
import numpy as np
import random
import torch
import torch.nn as nn
import torch.optim as optim
import torch.nn.functional as F
import gymnasium as gym
import matplotlib.pyplot as plt
from collections import deque
from IPython.display import Video, display
import warnings
warnings.filterwarnings('ignore')

# Import lab utilities
from replay_buffer import ReplayBuffer
from networks import DQNNetwork, DuelingDQNNetwork

# Check device
device = torch.device("cuda" if torch.cuda.is_available() else "cpu")
print(f"Using device: {device}")

# Resolve experiments directory relative to this notebook's location
_here = globals().get('__vsc_ipynb_file__', os.path.abspath(''))
_nb_dir = os.path.dirname(_here) if os.path.isfile(_here) else _here
EXPERIMENTS_DIR = os.path.normpath(os.path.join(_nb_dir, '..', 'experiments'))
print(f"Experiments directory: {EXPERIMENTS_DIR}")

# For reproducibility
def set_seed(seed=42):
    random.seed(seed)
    np.random.seed(seed)
    torch.manual_seed(seed)
    if torch.cuda.is_available():
        torch.cuda.manual_seed(seed)

set_seed(42)
print("Setup complete!")
# Out:
# Using device: cpu
# Experiments directory: c:\Users\SEJEVIB1\Desktop\tdde78lab\labs\lab1_value_based\experiments
# Setup complete!

# %% [markdown]
# ---
#
# # Part A — Implementation
#
# ---

# %% [markdown]
# ## A.1 — Explore the Environment
#
# Before implementing DQN, let's understand the environment we'll be working with.
#
# **CartPole-v1:** A pole is attached to a cart moving along a frictionless track. The goal is to keep the pole balanced by applying forces to the left or right.

# %%
# Explore the CartPole environment
env = gym.make('CartPole-v1')

print(f"Observation space: {env.observation_space}")
print(f"  Shape: {env.observation_space.shape}")
print(f"  Low:  {env.observation_space.low}")
print(f"  High: {env.observation_space.high}")
print()
print(f"Action space: {env.action_space}")
print(f"  Number of actions: {env.action_space.n}")
print(f"  Actions: 0 = push left, 1 = push right")

# Run a random episode
obs, info = env.reset(seed=42)
total_reward = 0
for step in range(200):
    action = env.action_space.sample()  # Random action
    obs, reward, terminated, truncated, info = env.step(action)
    total_reward += reward
    if terminated or truncated:
        break

print(f"\nRandom agent — Episode length: {step+1}, Total reward: {total_reward}")
env.close()
# Out:
# Observation space: Box([-4.8               -inf -0.41887903        -inf], [4.8               inf 0.41887903        inf], (4,), float32)
#   Shape: (4,)
#   Low:  [-4.8               -inf -0.41887903        -inf]
#   High: [4.8               inf 0.41887903        inf]
#
# Action space: Discrete(2)
#   Number of actions: 2
#   Actions: 0 = push left, 1 = push right
#
# Random agent — Episode length: 29, Total reward: 29.0

# %% [markdown]
# ## A.2 — Replay Buffer
#
# Open `replay_buffer.py` and implement the `push()` and `sample()` methods.
#
# **Why experience replay?**
# - Consecutive transitions are highly correlated (the agent visits similar states in sequence)
# - Training on correlated data leads to unstable learning
# - Random sampling from a buffer breaks these correlations
# - Transitions can be reused multiple times, improving sample efficiency
#
# After implementing, run the test cell below to verify.

# %%
# Test your ReplayBuffer implementation
from replay_buffer import ReplayBuffer

# Create a small buffer
test_buffer = ReplayBuffer(capacity=100, seed=42)

# Add some fake transitions
for i in range(50):
    state = np.array([i, i+1, i+2, i+3], dtype=np.float32)
    action = i % 2
    reward = float(i)
    next_state = np.array([i+1, i+2, i+3, i+4], dtype=np.float32)
    done = (i == 49)
    test_buffer.push(state, action, reward, next_state, done)

assert len(test_buffer) == 50, f"Expected 50 transitions, got {len(test_buffer)}"

# Sample a batch
states, actions, rewards, next_states, dones = test_buffer.sample(batch_size=16)

assert states.shape == (16, 4), f"States shape should be (16, 4), got {states.shape}"
assert actions.shape == (16,), f"Actions shape should be (16,), got {actions.shape}"
assert rewards.shape == (16,), f"Rewards shape should be (16,), got {rewards.shape}"
assert next_states.shape == (16, 4), f"Next states shape should be (16, 4), got {next_states.shape}"
assert dones.shape == (16,), f"Dones shape should be (16,), got {dones.shape}"
assert states.dtype == np.float32, f"States dtype should be float32, got {states.dtype}"
assert actions.dtype == np.int64, f"Actions dtype should be int64, got {actions.dtype}"

print("All ReplayBuffer tests passed!")
print(f"Sample states shape: {states.shape}")
print(f"Sample actions: {actions[:5]}")
# Out:
# All ReplayBuffer tests passed!
# Sample states shape: (16, 4)
# Sample actions: [0 1 1 1 1]

# %% [markdown]
# ## A.3 — DQN Network
#
# Open `networks.py` and implement the `DQNNetwork` class.
#
# The network is a simple MLP:
# ```
# State (4) → Linear(128) → ReLU → Linear(128) → ReLU → Linear(action_dim)
# ```
#
# The output is a vector of Q-values, one for each action.

# %%
# Test your DQNNetwork implementation
from networks import DQNNetwork

test_net = DQNNetwork(state_dim=4, action_dim=2).to(device)

# Test forward pass
test_state = torch.randn(8, 4).to(device)  # batch of 8 states
q_values = test_net(test_state)

assert q_values.shape == (8, 2), f"Output shape should be (8, 2), got {q_values.shape}"

# Count parameters
n_params = sum(p.numel() for p in test_net.parameters())
print(f"DQNNetwork — output shape: {q_values.shape}, parameters: {n_params:,}")
print(f"Q-values for first state: {q_values[0].detach().cpu().numpy()}")
print("DQNNetwork test passed!")
# Out:
# DQNNetwork — output shape: torch.Size([8, 2]), parameters: 10,934
# Q-values for first state: [-0.02283452 -0.07539523]
# DQNNetwork test passed!

# %% [markdown]
# ## A.4 — Dueling DQN Network
#
# Now implement the `DuelingDQNNetwork` in `networks.py`.
#
# ```
# State (4) → Linear(128) → ReLU → [shared features]
#                                     ├── Linear(128) → ReLU → Linear(1)           → V(s)
#                                     └── Linear(128) → ReLU → Linear(action_dim)  → A(s,a)
#
# Q(s,a) = V(s) + A(s,a) - mean(A(s,:))
# ```

# %%
# Test your DuelingDQNNetwork implementation
from networks import DuelingDQNNetwork

test_dueling = DuelingDQNNetwork(state_dim=4, action_dim=2).to(device)

# Test forward pass
test_state = torch.randn(8, 4).to(device)
q_values = test_dueling(test_state)

assert q_values.shape == (8, 2), f"Output shape should be (8, 2), got {q_values.shape}"

n_params = sum(p.numel() for p in test_dueling.parameters())
print(f"DuelingDQNNetwork — output shape: {q_values.shape}, parameters: {n_params:,}")
print(f"Q-values for first state: {q_values[0].detach().cpu().numpy()}")
print("DuelingDQNNetwork test passed!")
# Out:
# DuelingDQNNetwork — output shape: torch.Size([8, 2]), parameters: 34,051
# Q-values for first state: [-0.22718501  0.10075587]
# DuelingDQNNetwork test passed!

# %% [markdown]
# ## A.5 — DQN Agent
#
# Now implement the complete DQN agent. This is the core of the lab.
#
# The agent needs to:
# 1. **Select actions** using epsilon-greedy exploration
# 2. **Store transitions** in the replay buffer
# 3. **Train** by sampling mini-batches and computing the TD loss
# 4. **Update the target network** periodically
#
# Fill in all the TODO sections in the cell below.

# %%
import replay_buffer
import networks

class DQNAgent:
    """
    DQN Agent with support for Double DQN.

    Args:
        state_dim (int): Dimension of state space.
        action_dim (int): Number of actions.
        lr (float): Learning rate.
        gamma (float): Discount factor.
        epsilon_start (float): Initial exploration rate.
        epsilon_end (float): Final exploration rate.
        epsilon_decay (int): Number of steps over which epsilon decays linearly.
        buffer_size (int): Replay buffer capacity.
        batch_size (int): Mini-batch size for training.
        target_network_frequency (int): Steps between target network hard updates.
        max_grad_norm (float): Gradient clipping threshold.
        use_double_dqn (bool): Whether to use Double DQN target computation.
        use_dueling (bool): Whether to use Dueling DQN architecture.
        seed (int): Random seed.
    """

    def __init__(
        self,
        state_dim: int,
        action_dim: int,
        lr: float = 2.5e-4,
        gamma: float = 0.99,
        epsilon_start: float = 1.0,
        epsilon_end: float = 0.05,
        epsilon_decay: int = 50000,
        buffer_size: int = 10000,
        batch_size: int = 128,
        target_network_frequency: int = 500,
        max_grad_norm: float = 10.0,
        use_double_dqn: bool = False,
        use_dueling: bool = False,
        seed: int = 42,
    ):
        self.action_dim = action_dim
        self.gamma = gamma
        self.epsilon_start = epsilon_start
        self.epsilon_end = epsilon_end
        self.epsilon_decay = epsilon_decay
        self.batch_size = batch_size
        self.target_network_frequency = target_network_frequency
        self.max_grad_norm = max_grad_norm
        self.use_double_dqn = use_double_dqn
        self.steps_done = 0

        # =====================================================================
        # TODO: Initialize the following:
        #
        # 1. self.replay_buffer — a ReplayBuffer with the given capacity and seed
        # 2. self.q_network — the online Q-network (DQN or Dueling, based on use_dueling)
        # 3. self.target_network — a copy of the Q-network (same architecture)
        # 4. Copy the weights from q_network to target_network
        #    Hint: self.target_network.load_state_dict(self.q_network.state_dict())
        # 5. Set target_network to eval mode: self.target_network.eval()
        # 6. self.optimizer — Adam optimizer for q_network with learning rate lr
        # =====================================================================
        self.replay_buffer = replay_buffer.ReplayBuffer(buffer_size, seed)
        if use_dueling:
            self.q_network = networks.DuelingDQNNetwork(state_dim, action_dim).to(device)
            self.target_network = networks.DuelingDQNNetwork(state_dim, action_dim).to(device)
        else:
            self.q_network = networks.DQNNetwork(state_dim, action_dim).to(device)
            self.target_network = networks.DQNNetwork(state_dim, action_dim).to(device)
        self.target_network.load_state_dict(self.q_network.state_dict())
        self.target_network.eval()
        self.optimizer = torch.optim.Adam(self.q_network.parameters(), lr=lr)
        
        # raise NotImplementedError("Initialize DQNAgent components")

    def get_epsilon(self):
        """Compute current epsilon using linear decay."""
        # =====================================================================
        # TODO: Implement linear epsilon decay.
        #
        # Epsilon should linearly decrease from epsilon_start to epsilon_end
        # over epsilon_decay steps, then stay at epsilon_end.
        #
        # Formula: eps = max(epsilon_end, epsilon_start - steps_done * (epsilon_start - epsilon_end) / epsilon_decay)
        # =====================================================================
        eps = max(self.epsilon_end, self.epsilon_start - self.steps_done * (self.epsilon_start - self.epsilon_end) / self.epsilon_decay)
        return eps
        # raise NotImplementedError("Implement epsilon decay")

    def select_action(self, state):
        """
        Select an action using epsilon-greedy policy.

        Args:
            state: numpy array of shape (state_dim,)

        Returns:
            int: selected action
        """
        # =====================================================================
        # TODO: Implement epsilon-greedy action selection.
        #
        # 1. Increment self.steps_done
        # 2. Get current epsilon via self.get_epsilon()
        # 3. With probability epsilon, return a random action
        # 4. Otherwise, convert state to tensor, pass through q_network,
        #    and return the action with the highest Q-value
        #
        # Remember to:
        #   - Use torch.no_grad() when computing Q-values for action selection
        #   - Move tensor to the correct device
        # =====================================================================
        self.steps_done += 1
        eps = self.get_epsilon()

        if torch.rand(1).item() < eps:
            return torch.randint(0, self.action_dim, (1,)).item()

        state_tensor = torch.FloatTensor(state).unsqueeze(0).to(device)
        with torch.no_grad():
            q_values = self.q_network(state_tensor)
            action = q_values.argmax(dim=1).item()

        return action
        # raise NotImplementedError("Implement epsilon-greedy action selection")

    def compute_loss(self, batch):
        """
        Compute the DQN loss (or Double DQN loss).

        Args:
            batch: tuple of (states, actions, rewards, next_states, dones) as numpy arrays

        Returns:
            torch.Tensor: scalar loss value
        """
        states, actions, rewards, next_states, dones = batch

        # Convert to tensors
        states = torch.FloatTensor(states).to(device)
        actions = torch.LongTensor(actions).to(device)
        rewards = torch.FloatTensor(rewards).to(device)
        next_states = torch.FloatTensor(next_states).to(device)
        dones = torch.FloatTensor(dones).to(device)

        # =====================================================================
        # TODO: Compute the DQN loss.
        #
        # Step 1: Compute current Q-values
        #   - Pass states through self.q_network
        #   - Select the Q-values corresponding to the taken actions
        #   - Hint: Use .gather(1, actions.unsqueeze(1)).squeeze(1)
        #
        # Step 2: Compute target Q-values (no gradient!)
        #   with torch.no_grad():
        #
        #   If self.use_double_dqn is True (Double DQN):
        #     - Use q_network to SELECT the best action for next_states:
        #       best_actions = q_network(next_states).argmax(dim=1)
        #     - Use target_network to EVALUATE those actions:
        #       next_q = target_network(next_states).gather(1, best_actions.unsqueeze(1)).squeeze(1)
        #
        #   If self.use_double_dqn is False (Standard DQN):
        #     - Use target_network to both select and evaluate:
        #       next_q = target_network(next_states).max(dim=1)[0]
        #
        #   Target: y = rewards + gamma * next_q * (1 - dones)
        #
        # Step 3: Compute MSE loss between current Q-values and targets
        #   loss = F.mse_loss(current_q, target_q)
        # =====================================================================
        current_q = self.q_network(states).gather(1, actions.unsqueeze(1)).squeeze(1)
        
        with torch.no_grad():
            if self.use_double_dqn:
                best_actions = self.q_network(next_states).argmax(dim=1)
                next_q = self.target_network(next_states).gather(1, best_actions.unsqueeze(1)).squeeze(1)
            else:
                next_q = self.target_network(next_states).max(dim=1)[0]
            target_q = rewards + self.gamma * next_q * (1 - dones)
        
        loss = torch.nn.functional.mse_loss(current_q, target_q)
        return loss
        
        # raise NotImplementedError("Implement DQN loss computation")

    def train_step(self, global_step: int):
        """
        Perform one training step: sample batch, compute loss, update weights.

        Args:
            global_step (int): Current total environment step count.
                               Used to decide when to update the target network.

        Returns:
            float: loss value (or None if buffer doesn't have enough samples)
        """
        # =====================================================================
        # TODO: Implement one training step.
        #
        # 1. Check if replay buffer has enough samples (>= batch_size)
        #    If not, return None
        # 2. Sample a batch from the replay buffer
        # 3. Compute the loss using self.compute_loss()
        # 4. Backpropagate:
        #    optimizer.zero_grad()
        #    loss.backward()
        #    torch.nn.utils.clip_grad_norm_(self.q_network.parameters(), self.max_grad_norm)
        #    optimizer.step()
        # 5. Hard target network update every target_network_frequency steps:
        #    if global_step % self.target_network_frequency == 0:
        #        self.target_network.load_state_dict(self.q_network.state_dict())
        # 6. Return the loss value as a float: loss.item()
        # =====================================================================
        if len(self.replay_buffer) < self.batch_size:
            return None

        batch = self.replay_buffer.sample(self.batch_size)
        loss = self.compute_loss(batch)

        self.optimizer.zero_grad()
        loss.backward()
        torch.nn.utils.clip_grad_norm_(self.q_network.parameters(), self.max_grad_norm)
        self.optimizer.step()

        if global_step % self.target_network_frequency == 0:
            self.target_network.load_state_dict(self.q_network.state_dict())

        return loss.item()
        # raise NotImplementedError("Implement training step")

print("DQNAgent class defined!")
# Out:
# DQNAgent class defined!

# %% [markdown]
# ## A.6 — Training Loop
#
# Now let's put everything together and train the DQN agent.

# %%
def train_dqn(
    env_name: str = "CartPole-v1",
    num_episodes: int = 500,
    learning_starts: int = 1000,
    train_frequency: int = 10,
    use_double_dqn: bool = False,
    use_dueling: bool = False,
    seed: int = 42,
    solve_threshold: float = None,
    **agent_kwargs,
):
    """
    Train a DQN agent and return training metrics.

    Args:
        env_name: Gymnasium environment name.
        num_episodes: Number of training episodes.
        learning_starts: Number of environment steps before training begins.
                         Fills the replay buffer with random experience first.
        train_frequency: Train every this many environment steps (CleanRL style).
        use_double_dqn: Whether to use Double DQN.
        use_dueling: Whether to use Dueling DQN.
        seed: Random seed.
        solve_threshold: Stop early when avg reward (last 100 eps) >= this value.
        **agent_kwargs: Additional arguments for DQNAgent.

    Returns:
        dict with keys: 'episode_rewards', 'episode_lengths', 'losses', 'epsilons'
    """
    set_seed(seed)

    # Create environment
    env = gym.make(env_name)
    state_dim = env.observation_space.shape[0]
    action_dim = env.action_space.n

    # Create agent
    agent = DQNAgent(
        state_dim=state_dim,
        action_dim=action_dim,
        use_double_dqn=use_double_dqn,
        use_dueling=use_dueling,
        seed=seed,
        **agent_kwargs,
    )

    # Tracking
    episode_rewards = []
    episode_lengths = []
    losses = []
    epsilons = []
    global_step = 0  # Total environment steps across all episodes

    # =====================================================================
    # TODO: Implement the training loop.
    #
    # For each episode:
    #   1. Reset the environment: obs, info = env.reset(seed=seed+episode)
    #   2. Initialize episode_reward = 0, episode_loss = []
    #   3. For each step in the episode (up to some max, e.g. 10000):
    #      a. Select action: action = agent.select_action(obs)
    #      b. Step environment: next_obs, reward, terminated, truncated, info = env.step(action)
    #      c. done = terminated or truncated
    #      d. Store transition: agent.replay_buffer.push(obs, action, reward, next_obs, float(done))
    #      e. Increment global_step
    #      f. CleanRL style — only train after learning_starts steps,
    #         and only every train_frequency steps:
    #           if global_step > learning_starts and global_step % train_frequency == 0:
    #               loss = agent.train_step(global_step)
    #               if loss is not None:
    #                   episode_loss.append(loss)
    #      g. obs = next_obs
    #      h. episode_reward += reward
    #      i. if done: break
    #   4. Append episode_reward to episode_rewards
    #   5. Append step+1 to episode_lengths
    #   6. Extend losses with episode_loss
    #   7. Append agent.get_epsilon() to epsilons
    #   8. Every 50 episodes, print progress:
    #      avg_reward = np.mean(episode_rewards[-50:])
    #      recent_losses = [l for l in losses[-500:] if l is not None]
    #      avg_loss = np.mean(recent_losses) if recent_losses else 0.0
    #      print(f"Episode {episode+1}/{num_episodes} | Avg Reward (50): {avg_reward:.1f} | ...")
    # =====================================================================
    for episode in range(num_episodes):
        obs, info = env.reset(seed=seed + episode)
        episode_reward = 0
        episode_loss = []
        for step in range(10000):
            action = agent.select_action(obs)
            next_obs, reward, terminated, truncated, info = env.step(action)
            done = terminated or truncated
            agent.replay_buffer.push(obs, action, reward, next_obs, float(done))
            global_step += 1
            if global_step > learning_starts and global_step % train_frequency == 0:
                loss = agent.train_step(global_step)
                if loss is not None:
                    episode_loss.append(loss)
            obs = next_obs
            episode_reward += reward
            if done:
                break
        episode_rewards.append(episode_reward)
        episode_lengths.append(step + 1)
        losses.extend(episode_loss)
        epsilons.append(agent.get_epsilon())
        if (episode + 1) % 50 == 0:
            avg_reward = np.mean(episode_rewards[-50:])
            recent_losses = [l for l in losses[-500:] if l is not None]
            avg_loss = np.mean(recent_losses) if recent_losses else 0.0
            print(f"Episode {episode+1}/{num_episodes} | Avg Reward (50): {avg_reward:.1f} | Avg Loss (500): {avg_loss:.4f} | Epsilon: {epsilons[-1]:.3f}")
    # raise NotImplementedError("Implement training loop")

    env.close()

    return {
        'episode_rewards': episode_rewards,
        'episode_lengths': episode_lengths,
        'losses': losses,
        'epsilons': epsilons,
        'agent': agent,
    }

print("Training function defined!")
# Out:
# Training function defined!

# %% [markdown]
# ## A.7 — Plotting Utilities
#
# Helper functions for visualizing training results.

# %%
def _save_plot(fig, title):
    """Save figure to experiments/plots/ using the plot title as filename."""
    try:
        plots_dir = os.path.join(EXPERIMENTS_DIR, "plots")
        os.makedirs(plots_dir, exist_ok=True)
        filename = title.lower().replace(" ", "_").replace("/", "_").replace("—", "").replace(":", "").strip("_") + ".png"
        filepath = os.path.join(plots_dir, filename)
        fig.savefig(filepath, dpi=150, bbox_inches="tight")
        print(f"Plot saved: {filepath}")
    except Exception as e:
        print(f"Could not save plot: {e}")


def plot_training_results(results, title="DQN Training", window=50):
    """Plot training curves: rewards, losses, and epsilon. Saves to experiments/plots/."""
    fig, axes = plt.subplots(1, 3, figsize=(18, 5))

    rewards = results['episode_rewards']
    axes[0].plot(rewards, alpha=0.3, color='blue', label='Raw')
    if len(rewards) >= window:
        moving_avg = np.convolve(rewards, np.ones(window)/window, mode='valid')
        axes[0].plot(range(window-1, len(rewards)), moving_avg, color='blue', label=f'{window}-ep avg')
    axes[0].set_xlabel('Episode')
    axes[0].set_ylabel('Reward')
    axes[0].set_title(f'{title} — Episode Rewards')
    axes[0].legend()
    axes[0].grid(True, alpha=0.3)

    valid_losses = [l for l in results['losses'] if l is not None]
    if valid_losses:
        axes[1].plot(valid_losses, alpha=0.5, color='red')
        axes[1].set_xlabel('Training Step')
        axes[1].set_ylabel('Loss')
        axes[1].set_title(f'{title} — Training Loss')
        axes[1].grid(True, alpha=0.3)

    axes[2].plot(results['epsilons'], color='green')
    axes[2].set_xlabel('Episode')
    axes[2].set_ylabel('Epsilon')
    axes[2].set_title(f'{title} — Exploration Rate')
    axes[2].grid(True, alpha=0.3)

    plt.tight_layout()
    _save_plot(fig, title)
    plt.show()


def plot_comparison(all_results, title="Method Comparison", window=50):
    """Plot reward comparison across multiple methods/seeds. Saves to experiments/plots/."""
    fig, ax = plt.subplots(1, 1, figsize=(10, 6))
    colors = ['blue', 'red', 'green', 'orange', 'purple']

    for idx, (name, results_list) in enumerate(all_results.items()):
        color = colors[idx % len(colors)]
        min_len = min(len(r['episode_rewards']) for r in results_list)
        all_rewards = np.array([r['episode_rewards'][:min_len] for r in results_list])

        if min_len >= window:
            smoothed = np.array([
                np.convolve(row, np.ones(window)/window, mode='valid')
                for row in all_rewards
            ])
            mean = smoothed.mean(axis=0)
            std = smoothed.std(axis=0)
            x = range(window-1, min_len)
        else:
            mean = all_rewards.mean(axis=0)
            std = all_rewards.std(axis=0)
            x = range(min_len)

        ax.plot(x, mean, color=color, label=name)
        ax.fill_between(x, mean - std, mean + std, color=color, alpha=0.15)

    ax.set_xlabel('Episode')
    ax.set_ylabel('Reward')
    ax.set_title(title)
    ax.legend()
    ax.grid(True, alpha=0.3)
    plt.tight_layout()
    _save_plot(fig, title)
    plt.show()

print("Plotting utilities defined!")
# Out:
# Plotting utilities defined!

# %% [markdown]
# ## A.8 — Train DQN on CartPole
#
# Let's verify your implementation works! Train a basic DQN agent on CartPole-v1.
#
#     "**Expected:** The agent should reach average reward ≥ 475 (95% of max 500) within ~300 episodes. CartPole-v1 has max_episode_steps=500, so the maximum reward is 500 (1 point per step). The 475 threshold is the standard benchmark for "solving" CartPole."

# %%
# Train DQN on CartPole
set_seed(42)
results_dqn = train_dqn(
    env_name="CartPole-v1",
    num_episodes=2000,
    solve_threshold=475,
    use_double_dqn=False,
    use_dueling=False,
    seed=42,
)

plot_training_results(results_dqn, title="DQN on CartPole-v1")

# Check if solved
last_100 = results_dqn['episode_rewards'][-100:]
avg_reward = np.mean(last_100)
print(f"\nAverage reward (last 100 episodes): {avg_reward:.1f}")
if avg_reward >= 475:
    print("CartPole SOLVED! (>=475/500 average reward)")
else:
    print("Not yet solved — check your implementation.")
# Out:
# Episode 50/2000 | Avg Reward (50): 22.7 | Avg Loss (500): 0.9957 | Epsilon: 0.978
# Episode 100/2000 | Avg Reward (50): 20.2 | Avg Loss (500): 0.6251 | Epsilon: 0.959
# Episode 150/2000 | Avg Reward (50): 17.6 | Avg Loss (500): 0.6196 | Epsilon: 0.943
# Episode 200/2000 | Avg Reward (50): 21.1 | Avg Loss (500): 0.8427 | Epsilon: 0.922
# Episode 250/2000 | Avg Reward (50): 20.9 | Avg Loss (500): 1.0579 | Epsilon: 0.903
# Episode 300/2000 | Avg Reward (50): 18.8 | Avg Loss (500): 1.1812 | Epsilon: 0.885
# Episode 350/2000 | Avg Reward (50): 24.8 | Avg Loss (500): 1.5364 | Epsilon: 0.861
# Episode 400/2000 | Avg Reward (50): 28.2 | Avg Loss (500): 1.9314 | Epsilon: 0.835
# Episode 450/2000 | Avg Reward (50): 33.4 | Avg Loss (500): 2.5708 | Epsilon: 0.803
# Episode 500/2000 | Avg Reward (50): 34.6 | Avg Loss (500): 3.4001 | Epsilon: 0.770
# Episode 550/2000 | Avg Reward (50): 40.8 | Avg Loss (500): 4.6531 | Epsilon: 0.731
# Episode 600/2000 | Avg Reward (50): 51.1 | Avg Loss (500): 5.8748 | Epsilon: 0.683
# Episode 650/2000 | Avg Reward (50): 74.4 | Avg Loss (500): 7.4515 | Epsilon: 0.612
# Episode 700/2000 | Avg Reward (50): 90.5 | Avg Loss (500): 8.5372 | Epsilon: 0.526
# Episode 750/2000 | Avg Reward (50): 169.2 | Avg Loss (500): 8.7678 | Epsilon: 0.365
# Episode 800/2000 | Avg Reward (50): 293.9 | Avg Loss (500): 3.4826 | Epsilon: 0.086
# Episode 850/2000 | Avg Reward (50): 277.5 | Avg Loss (500): 0.7778 | Epsilon: 0.050
# Episode 900/2000 | Avg Reward (50): 261.7 | Avg Loss (500): 0.0917 | Epsilon: 0.050
# Episode 950/2000 | Avg Reward (50): 245.0 | Avg Loss (500): 0.0335 | Epsilon: 0.050
# Episode 1000/2000 | Avg Reward (50): 233.3 | Avg Loss (500): 0.0347 | Epsilon: 0.050
# Episode 1050/2000 | Avg Reward (50): 223.0 | Avg Loss (500): 0.3610 | Epsilon: 0.050
# Episode 1100/2000 | Avg Reward (50): 210.9 | Avg Loss (500): 0.0294 | Epsilon: 0.050
# Episode 1150/2000 | Avg Reward (50): 259.2 | Avg Loss (500): 0.0286 | Epsilon: 0.050
# Episode 1200/2000 | Avg Reward (50): 394.4 | Avg Loss (500): 4.7242 | Epsilon: 0.050
# Episode 1250/2000 | Avg Reward (50): 448.4 | Avg Loss (500): 4.4214 | Epsilon: 0.050
# Episode 1300/2000 | Avg Reward (50): 481.0 | Avg Loss (500): 7.1410 | Epsilon: 0.050
# Episode 1350/2000 | Avg Reward (50): 492.7 | Avg Loss (500): 9.6645 | Epsilon: 0.050
# Episode 1400/2000 | Avg Reward (50): 497.3 | Avg Loss (500): 16.2995 | Epsilon: 0.050
# Episode 1450/2000 | Avg Reward (50): 494.7 | Avg Loss (500): 12.7869 | Epsilon: 0.050
# Episode 1500/2000 | Avg Reward (50): 496.6 | Avg Loss (500): 17.3744 | Epsilon: 0.050
# Episode 1550/2000 | Avg Reward (50): 496.9 | Avg Loss (500): 18.1203 | Epsilon: 0.050
# Episode 1600/2000 | Avg Reward (50): 500.0 | Avg Loss (500): 18.1342 | Epsilon: 0.050
# Episode 1650/2000 | Avg Reward (50): 500.0 | Avg Loss (500): 16.4886 | Epsilon: 0.050
# Episode 1700/2000 | Avg Reward (50): 498.7 | Avg Loss (500): 15.9882 | Epsilon: 0.050
# Episode 1750/2000 | Avg Reward (50): 500.0 | Avg Loss (500): 17.1340 | Epsilon: 0.050
# Episode 1800/2000 | Avg Reward (50): 486.9 | Avg Loss (500): 10.7109 | Epsilon: 0.050
# Episode 1850/2000 | Avg Reward (50): 500.0 | Avg Loss (500): 14.6839 | Epsilon: 0.050
# Episode 1900/2000 | Avg Reward (50): 500.0 | Avg Loss (500): 18.3581 | Epsilon: 0.050
# Episode 1950/2000 | Avg Reward (50): 500.0 | Avg Loss (500): 14.0772 | Epsilon: 0.050
# Episode 2000/2000 | Avg Reward (50): 500.0 | Avg Loss (500): 13.9022 | Epsilon: 0.050
# Plot saved: c:\Users\Jensw\Desktop\tdde78lab\labs\lab1_value_based\experiments\plots\dqn_on_cartpole-v1.png
# Average reward (last 100 episodes): 500.0
# CartPole SOLVED! (>=475/500 average reward)

# %% [markdown]
# ## A.9 — Visualize the Learned Policy
#
# Let's watch the trained agent play! We record a video of the agent's greedy policy (no exploration) and also visualize Q-value statistics.

# %%
def record_agent_video(agent, env_name="CartPole-v1", video_dir=None, num_episodes=3, seed=0):
    """
    Record video(s) of the trained agent playing with greedy policy.
    Videos are saved to experiments/videos/ and can be displayed inline.
    """
    if video_dir is None:
        video_dir = os.path.join(EXPERIMENTS_DIR, 'videos')
    os.makedirs(video_dir, exist_ok=True)

    env = gym.make(env_name, render_mode="rgb_array")
    env = gym.wrappers.RecordVideo(
        env,
        video_folder=video_dir,
        episode_trigger=lambda ep: True,
        name_prefix=f"dqn_{env_name}"
    )

    for ep in range(num_episodes):
        obs, info = env.reset(seed=seed + ep)
        episode_reward = 0

        for step in range(10000):
            with torch.no_grad():
                state_tensor = torch.FloatTensor(obs).unsqueeze(0).to(device)
                action = agent.q_network(state_tensor).argmax(dim=1).item()

            obs, reward, terminated, truncated, info = env.step(action)
            episode_reward += reward
            if terminated or truncated:
                break

        print(f"Episode {ep+1}: reward = {episode_reward:.0f}, length = {step+1}")

    env.close()

    video_files = sorted([f for f in os.listdir(video_dir) if f.endswith('.mp4')])
    if video_files:
        video_path = os.path.join(video_dir, video_files[-1])
        print(f"\nVideo saved to: {video_path}")
        return video_path
    return None


def evaluate_and_plot(agent, env_name="CartPole-v1", num_episodes=20, seed=0):
    """Evaluate the trained agent and plot Q-value analysis."""
    env = gym.make(env_name)
    rewards, all_q_values = [], []

    for ep in range(num_episodes):
        obs, info = env.reset(seed=seed + ep)
        episode_reward = 0
        for step in range(10000):
            with torch.no_grad():
                state_tensor = torch.FloatTensor(obs).unsqueeze(0).to(device)
                q_values = agent.q_network(state_tensor)
                all_q_values.append(q_values.cpu().numpy().flatten())
                action = q_values.argmax(dim=1).item()
            obs, reward, terminated, truncated, info = env.step(action)
            episode_reward += reward
            if terminated or truncated:
                break
        rewards.append(episode_reward)

    env.close()
    q_values = np.array(all_q_values)

    fig, axes = plt.subplots(1, 3, figsize=(18, 5))
    axes[0].bar(range(len(rewards)), rewards, color='steelblue', alpha=0.8)
    axes[0].axhline(y=np.mean(rewards), color='red', linestyle='--', label=f'Mean: {np.mean(rewards):.1f}')
    axes[0].set_xlabel('Episode'); axes[0].set_ylabel('Reward')
    axes[0].set_title(f'Evaluation (Greedy Policy) — {num_episodes} episodes')
    axes[0].legend(); axes[0].grid(True, alpha=0.3)

    for a in range(q_values.shape[1]):
        axes[1].hist(q_values[:, a], bins=50, alpha=0.6, label=f'Action {a}')
    axes[1].set_xlabel('Q-value'); axes[1].set_ylabel('Count')
    axes[1].set_title('Q-value Distribution by Action')
    axes[1].legend(); axes[1].grid(True, alpha=0.3)

    q_diff = q_values[:, 1] - q_values[:, 0]
    axes[2].hist(q_diff, bins=50, color='purple', alpha=0.7)
    axes[2].axvline(x=0, color='red', linestyle='--', label='No preference')
    axes[2].set_xlabel('Q(right) - Q(left)'); axes[2].set_ylabel('Count')
    axes[2].set_title('Action Preference')
    axes[2].legend(); axes[2].grid(True, alpha=0.3)

    plt.tight_layout()
    plt.show()
    print(f"Evaluation: {np.mean(rewards):.1f} ± {np.std(rewards):.1f} "
          f"(min={min(rewards):.0f}, max={max(rewards):.0f})")

print("Visualization functions defined!")
# Out:
# Visualization functions defined!

# %%
# Record a video of the trained agent playing
video_path = record_agent_video(results_dqn['agent'], env_name="CartPole-v1", num_episodes=3)

# Display the video inline in the notebook
if video_path:
    display(Video(video_path, embed=True, width=480))
# Out:
# Episode 1: reward = 500, length = 500
# Episode 2: reward = 500, length = 500
# Episode 3: reward = 500, length = 500
#
# Video saved to: c:\Users\Jensw\Desktop\tdde78lab\labs\lab1_value_based\experiments\videos\dqn_CartPole-v1-episode-2.mp4
# <video controls  width="480" >
#  <source src="data:video/mp4;base64,..." type="video/mp4">
#  Your browser does not support the video tag.
#  </video>

# %% [markdown]
# ---
#
# # Part B — Experiments
#
# ---
#
# Now that your implementation works, run systematic experiments to understand the algorithms.
#
# **Important:** For all experiments, run at least **3 different seeds** and report mean ± std.

# %% [markdown]
# ## B.1 — DQN vs Double DQN vs Dueling DQN on CartPole
#
# Compare the three variants on CartPole-v1. Run each with seeds [42, 123, 456].

# %%
seeds = [42, 123, 456]

print("Training DQN variants on CartPole-v1...")
print("=" * 60)

all_results = {
    'DQN':        [train_dqn(env_name="CartPole-v1", num_episodes=2000, seed=s, use_double_dqn=False, use_dueling=False) for s in seeds],
    'Double DQN': [train_dqn(env_name="CartPole-v1", num_episodes=2000, seed=s, use_double_dqn=True, use_dueling=False) for s in seeds],
    'Dueling DQN':[train_dqn(env_name="CartPole-v1", num_episodes=2000, seed=s, use_double_dqn=False, use_dueling=True) for s in seeds],
}

print("\n" + "=" * 60)
print("Final Performance (last 100 episodes):")
print("=" * 60)

for name, results_list in all_results.items():
    final_rewards = [np.mean(r['episode_rewards'][-100:]) for r in results_list]
    print(f"{name}: {np.mean(final_rewards):.1f} ± {np.std(final_rewards):.1f}")

plot_comparison(all_results, title="DQN Variants on CartPole-v1")
# Out:
# Training DQN variants on CartPole-v1...
# ============================================================
# Episode 50/2000 | Avg Reward (50): 22.7 | Avg Loss (500): 0.9957 | Epsilon: 0.978
# Episode 100/2000 | Avg Reward (50): 20.2 | Avg Loss (500): 0.6251 | Epsilon: 0.959
# Episode 150/2000 | Avg Reward (50): 17.6 | Avg Loss (500): 0.6196 | Epsilon: 0.943
# Episode 200/2000 | Avg Reward (50): 21.1 | Avg Loss (500): 0.8427 | Epsilon: 0.922
# Episode 250/2000 | Avg Reward (50): 20.9 | Avg Loss (500): 1.0579 | Epsilon: 0.903
# Episode 300/2000 | Avg Reward (50): 18.8 | Avg Loss (500): 1.1812 | Epsilon: 0.885
# Episode 350/2000 | Avg Reward (50): 24.8 | Avg Loss (500): 1.5364 | Epsilon: 0.861
# Episode 400/2000 | Avg Reward (50): 28.2 | Avg Loss (500): 1.9314 | Epsilon: 0.835
# Episode 450/2000 | Avg Reward (50): 33.4 | Avg Loss (500): 2.5708 | Epsilon: 0.803
# Episode 500/2000 | Avg Reward (50): 34.6 | Avg Loss (500): 3.4001 | Epsilon: 0.770
# Episode 550/2000 | Avg Reward (50): 40.8 | Avg Loss (500): 4.6531 | Epsilon: 0.731
# Episode 600/2000 | Avg Reward (50): 51.1 | Avg Loss (500): 5.8748 | Epsilon: 0.683
# Episode 650/2000 | Avg Reward (50): 74.4 | Avg Loss (500): 7.4515 | Epsilon: 0.612
# Episode 700/2000 | Avg Reward (50): 90.5 | Avg Loss (500): 8.5372 | Epsilon: 0.526
# Episode 750/2000 | Avg Reward (50): 169.2 | Avg Loss (500): 8.7678 | Epsilon: 0.365
# Episode 800/2000 | Avg Reward (50): 293.9 | Avg Loss (500): 3.4826 | Epsilon: 0.086
# Episode 850/2000 | Avg Reward (50): 277.5 | Avg Loss (500): 0.7778 | Epsilon: 0.050
# Episode 900/2000 | Avg Reward (50): 261.7 | Avg Loss (500): 0.0917 | Epsilon: 0.050
# Episode 950/2000 | Avg Reward (50): 245.0 | Avg Loss (500): 0.0335 | Epsilon: 0.050
# Episode 1000/2000 | Avg Reward (50): 233.3 | Avg Loss (500): 0.0347 | Epsilon: 0.050
# Episode 1050/2000 | Avg Reward (50): 223.0 | Avg Loss (500): 0.3610 | Epsilon: 0.050
# Episode 1100/2000 | Avg Reward (50): 210.9 | Avg Loss (500): 0.0294 | Epsilon: 0.050
# Episode 1150/2000 | Avg Reward (50): 259.2 | Avg Loss (500): 0.0286 | Epsilon: 0.050
# Episode 1200/2000 | Avg Reward (50): 394.4 | Avg Loss (500): 4.7242 | Epsilon: 0.050
# Episode 1250/2000 | Avg Reward (50): 448.4 | Avg Loss (500): 4.4214 | Epsilon: 0.050
# Episode 1300/2000 | Avg Reward (50): 481.0 | Avg Loss (500): 7.1410 | Epsilon: 0.050
# Episode 1350/2000 | Avg Reward (50): 492.7 | Avg Loss (500): 9.6645 | Epsilon: 0.050
# Episode 1400/2000 | Avg Reward (50): 497.3 | Avg Loss (500): 16.2995 | Epsilon: 0.050
# Episode 1450/2000 | Avg Reward (50): 494.7 | Avg Loss (500): 12.7869 | Epsilon: 0.050
# Episode 1500/2000 | Avg Reward (50): 496.6 | Avg Loss (500): 17.3744 | Epsilon: 0.050
# Episode 1550/2000 | Avg Reward (50): 496.9 | Avg Loss (500): 18.1203 | Epsilon: 0.050
# Episode 1600/2000 | Avg Reward (50): 500.0 | Avg Loss (500): 18.1342 | Epsilon: 0.050
# Episode 1650/2000 | Avg Reward (50): 500.0 | Avg Loss (500): 16.4886 | Epsilon: 0.050
# Episode 1700/2000 | Avg Reward (50): 498.7 | Avg Loss (500): 15.9882 | Epsilon: 0.050
# Episode 1750/2000 | Avg Reward (50): 500.0 | Avg Loss (500): 17.1340 | Epsilon: 0.050
# Episode 1800/2000 | Avg Reward (50): 486.9 | Avg Loss (500): 10.7109 | Epsilon: 0.050
# Episode 1850/2000 | Avg Reward (50): 500.0 | Avg Loss (500): 14.6839 | Epsilon: 0.050
# Episode 1900/2000 | Avg Reward (50): 500.0 | Avg Loss (500): 18.3581 | Epsilon: 0.050
# Episode 1950/2000 | Avg Reward (50): 500.0 | Avg Loss (500): 14.0772 | Epsilon: 0.050
# Episode 2000/2000 | Avg Reward (50): 500.0 | Avg Loss (500): 13.9022 | Epsilon: 0.050
# Episode 50/2000 | Avg Reward (50): 21.6 | Avg Loss (500): 1.2322 | Epsilon: 0.979
# Episode 100/2000 | Avg Reward (50): 23.4 | Avg Loss (500): 0.6962 | Epsilon: 0.957
# Episode 150/2000 | Avg Reward (50): 22.1 | Avg Loss (500): 0.7499 | Epsilon: 0.936
# Episode 200/2000 | Avg Reward (50): 19.1 | Avg Loss (500): 1.0087 | Epsilon: 0.918
# Episode 250/2000 | Avg Reward (50): 20.0 | Avg Loss (500): 1.2398 | Epsilon: 0.899
# Episode 300/2000 | Avg Reward (50): 25.7 | Avg Loss (500): 1.5097 | Epsilon: 0.875
# Episode 350/2000 | Avg Reward (50): 36.0 | Avg Loss (500): 2.1607 | Epsilon: 0.840
# Episode 400/2000 | Avg Reward (50): 29.8 | Avg Loss (500): 2.6010 | Epsilon: 0.812
# Episode 450/2000 | Avg Reward (50): 37.5 | Avg Loss (500): 3.5613 | Epsilon: 0.777
# Episode 500/2000 | Avg Reward (50): 33.3 | Avg Loss (500): 4.8156 | Epsilon: 0.745
# Episode 550/2000 | Avg Reward (50): 36.2 | Avg Loss (500): 6.2121 | Epsilon: 0.710
# Episode 600/2000 | Avg Reward (50): 51.0 | Avg Loss (500): 8.2110 | Epsilon: 0.662
# Episode 650/2000 | Avg Reward (50): 78.7 | Avg Loss (500): 10.0237 | Epsilon: 0.587
# Episode 700/2000 | Avg Reward (50): 108.1 | Avg Loss (500): 10.4227 | Epsilon: 0.485
# Episode 750/2000 | Avg Reward (50): 236.7 | Avg Loss (500): 9.2998 | Epsilon: 0.260
# Episode 800/2000 | Avg Reward (50): 208.0 | Avg Loss (500): 6.3755 | Epsilon: 0.062
# Episode 850/2000 | Avg Reward (50): 236.7 | Avg Loss (500): 1.8639 | Epsilon: 0.050
# Episode 900/2000 | Avg Reward (50): 297.2 | Avg Loss (500): 3.2805 | Epsilon: 0.050
# Episode 950/2000 | Avg Reward (50): 286.9 | Avg Loss (500): 0.7357 | Epsilon: 0.050
# Episode 1000/2000 | Avg Reward (50): 218.8 | Avg Loss (500): 0.4721 | Epsilon: 0.050
# Episode 1050/2000 | Avg Reward (50): 198.9 | Avg Loss (500): 0.1303 | Epsilon: 0.050
# Episode 1100/2000 | Avg Reward (50): 297.2 | Avg Loss (500): 2.5016 | Epsilon: 0.050
# Episode 1150/2000 | Avg Reward (50): 343.3 | Avg Loss (500): 3.1877 | Epsilon: 0.050
# Episode 1200/2000 | Avg Reward (50): 387.5 | Avg Loss (500): 0.5816 | Epsilon: 0.050
# Episode 1250/2000 | Avg Reward (50): 444.4 | Avg Loss (500): 6.1099 | Epsilon: 0.050
# Episode 1300/2000 | Avg Reward (50): 473.4 | Avg Loss (500): 10.4186 | Epsilon: 0.050
# Episode 1350/2000 | Avg Reward (50): 493.2 | Avg Loss (500): 10.3542 | Epsilon: 0.050
# Episode 1400/2000 | Avg Reward (50): 493.6 | Avg Loss (500): 12.3970 | Epsilon: 0.050
# Episode 1450/2000 | Avg Reward (50): 498.1 | Avg Loss (500): 19.2904 | Epsilon: 0.050
# Episode 1500/2000 | Avg Reward (50): 500.0 | Avg Loss (500): 18.9416 | Epsilon: 0.050
# Episode 1550/2000 | Avg Reward (50): 500.0 | Avg Loss (500): 18.5201 | Epsilon: 0.050
# Episode 1600/2000 | Avg Reward (50): 500.0 | Avg Loss (500): 18.0124 | Epsilon: 0.050
# Episode 1650/2000 | Avg Reward (50): 499.9 | Avg Loss (500): 17.8590 | Epsilon: 0.050
# Episode 1700/2000 | Avg Reward (50): 500.0 | Avg Loss (500): 17.4662 | Epsilon: 0.050
# Episode 1750/2000 | Avg Reward (50): 500.0 | Avg Loss (500): 19.5099 | Epsilon: 0.050
# Episode 1800/2000 | Avg Reward (50): 500.0 | Avg Loss (500): 20.5981 | Epsilon: 0.050
# Episode 1850/2000 | Avg Reward (50): 500.0 | Avg Loss (500): 17.4856 | Epsilon: 0.050
# Episode 1900/2000 | Avg Reward (50): 500.0 | Avg Loss (500): 22.2375 | Epsilon: 0.050
# Episode 1950/2000 | Avg Reward (50): 500.0 | Avg Loss (500): 21.2458 | Epsilon: 0.050
# Episode 2000/2000 | Avg Reward (50): 500.0 | Avg Loss (500): 20.5468 | Epsilon: 0.050
# Episode 50/2000 | Avg Reward (50): 24.8 | Avg Loss (500): 1.0324 | Epsilon: 0.976
# Episode 100/2000 | Avg Reward (50): 21.9 | Avg Loss (500): 0.7288 | Epsilon: 0.956
# Episode 150/2000 | Avg Reward (50): 22.3 | Avg Loss (500): 0.8296 | Epsilon: 0.934
# Episode 200/2000 | Avg Reward (50): 21.3 | Avg Loss (500): 1.1136 | Epsilon: 0.914
# Episode 250/2000 | Avg Reward (50): 22.3 | Avg Loss (500): 1.4340 | Epsilon: 0.893
# Episode 300/2000 | Avg Reward (50): 21.5 | Avg Loss (500): 1.7592 | Epsilon: 0.873
# Episode 350/2000 | Avg Reward (50): 22.7 | Avg Loss (500):
| Epsilon: 0.050
# Episode 1800/2000 | Avg Reward (50): 420.7 | Avg Loss (500): 15.3151 | Epsilon: 0.050
# Episode 1850/2000 | Avg Reward (50): 483.9 | Avg Loss (500): 14.5136 | Epsilon: 0.050
# Episode 1900/2000 | Avg Reward (50): 498.4 | Avg Loss (500): 19.7611 | Epsilon: 0.050
# Episode 1950/2000 | Avg Reward (50): 500.0 | Avg Loss (500): 21.0841 | Epsilon: 0.050
# Episode 2000/2000 | Avg Reward (50): 500.0 | Avg Loss (500): 20.6602 | Epsilon: 0.050
#
# ============================================================
# Final Performance (last 100 episodes):
# ============================================================
# DQN: 499.3 ± 1.0
# Double DQN: 500.0 ± 0.0
# Dueling DQN: 467.8 ± 42.9
# Plot saved: c:\Users\Jensw\Desktop\tdde78lab\labs\lab1_value_based\experiments\plots\dqn_variants_on_cartpole-v1.png

# %% [markdown]
# ## B.2 — DQN on LunarLander-v3
#
# Scale up to a harder environment. LunarLander has a larger state space and requires more careful learning.

# %%
seeds = [42, 123, 456]

print("Training DQN on LunarLander-v3...")
print("=" * 60)

# Train DQN on LunarLander with 3 seeds
results_lunar_dqn = [train_dqn(env_name="LunarLander-v3", num_episodes=2000, seed=s, use_double_dqn=False, use_dueling=False) for s in seeds]

print("\n" + "=" * 60)
print("Final Performance (last 100 episodes):")
print("=" * 60)

final_rewards = [np.mean(r['episode_rewards'][-100:]) for r in results_lunar_dqn]
print(f"DQN on LunarLander: {np.mean(final_rewards):.1f} ± {np.std(final_rewards):.1f}")

# Optionally, train Double DQN and Dueling DQN as well
print("\nTraining Double DQN on LunarLander-v3...")
results_lunar_double = [train_dqn(env_name="LunarLander-v3", num_episodes=2000, seed=s, use_double_dqn=True, use_dueling=False) for s in seeds]

print("Training Dueling DQN on LunarLander-v3...")
results_lunar_dueling = [train_dqn(env_name="LunarLander-v3", num_episodes=2000, seed=s, use_double_dqn=False, use_dueling=True) for s in seeds]

all_results_lunar = {
    'DQN': results_lunar_dqn,
    'Double DQN': results_lunar_double,
    'Dueling DQN': results_lunar_dueling,
}

print("\n" + "=" * 60)
print("Final Performance Comparison (last 100 episodes):")
print("=" * 60)

for name, results_list in all_results_lunar.items():
    final_rewards = [np.mean(r['episode_rewards'][-100:]) for r in results_list]
    print(f"{name}: {np.mean(final_rewards):.1f} ± {np.std(final_rewards):.1f}")

plot_comparison(all_results_lunar, title="DQN Variants on LunarLander-v3")
# Out:
# Training DQN on LunarLander-v3...
# ============================================================
# Episode 50/2000 | Avg Reward (50): -177.3 | Avg Loss (500): 104.6642 | Epsilon: 0.894
# Episode 100/2000 | Avg Reward (50): -142.7 | Avg Loss (500): 85.3466 | Epsilon: 0.796
# Episode 150/2000 | Avg Reward (50): -139.6 | Avg Loss (500): 64.6666 | Epsilon: 0.677
# Episode 200/2000 | Avg Reward (50): -119.6 | Avg Loss (500): 43.1080 | Epsilon: 0.535
# Episode 250/2000 | Avg Reward (50): -84.7 | Avg Loss (500): 4.2048 | Epsilon: 0.050
# Episode 300/2000 | Avg Reward (50): 15.4 | Avg Loss (500): 14.3826 | Epsilon: 0.050
# Episode 350/2000 | Avg Reward (50): 51.8 | Avg Loss (500): 13.4607 | Epsilon: 0.050
# Episode 400/2000 | Avg Reward (50): 35.2 | Avg Loss (500): 6.9147 | Epsilon: 0.050
# Episode 450/2000 | Avg Reward (50): -27.0 | Avg Loss (500): 5.7480 | Epsilon: 0.050
# Episode 500/2000 | Avg Reward (50): -28.4 | Avg Loss (500): 2.5160 | Epsilon: 0.050
# Episode 550/2000 | Avg Reward (50): 67.0 | Avg Loss (500): 15.2556 | Epsilon: 0.050
# Episode 600/2000 | Avg Reward (50): 112.5 | Avg Loss (500): 11.1491 | Epsilon: 0.050
# Episode 650/2000 | Avg Reward (50): 45.5 | Avg Loss (500): 10.2452 | Epsilon: 0.050
# Episode 700/2000 | Avg Reward (50):
| Epsilon: 0.050
# Episode 2000/2000 | Avg Reward (50): 246.8 | Avg Loss (500): 17.9601 | Epsilon: 0.050
#
# ============================================================
# Final Performance Comparison (last 100 episodes):
# ============================================================
# DQN: 212.2 ± 37.2
# Double DQN: 213.2 ± 20.6
# Dueling DQN: 223.2 ± 13.3
# Plot saved: c:\Users\Jensw\Desktop\tdde78lab\labs\lab1_value_based\experiments\plots\dqn_variants_on_lunarlander-v3.png

# %% [markdown]
# ## B.3 — Ablation: Replay Buffer Size
#
# Investigate how the replay buffer size affects learning stability and performance.
#
# Test buffer sizes: **1,000**, **10,000**, **100,000**

# %%
buffer_sizes = [1000, 10000, 100000]

print("Running buffer size ablation on CartPole-v1...")
print("=" * 60)

all_results_buffer = {}

for buffer_size in buffer_sizes:
    print(f"\nTraining with buffer_size={buffer_size}...")
    results = [
        train_dqn(
            env_name="CartPole-v1",
            num_episodes=2000,
            seed=s,
            buffer_size=buffer_size,
            use_double_dqn=False,
            use_dueling=False
        )
        for s in seeds
    ]
    all_results_buffer[f"Buffer {buffer_size}"] = results

print("\n" + "=" * 60)
print("Final Performance (last 100 episodes):")
print("=" * 60)

for name, results_list in all_results_buffer.items():
    final_rewards = [np.mean(r['episode_rewards'][-100:]) for r in results_list]
    print(f"{name}: {np.mean(final_rewards):.1f} ± {np.std(final_rewards):.1f}")

plot_comparison(all_results_buffer, title="Buffer Size Ablation on CartPole-v1")
# Out:
# Running buffer size ablation on CartPole-v1...
# ============================================================
#
# Training with buffer_size=1000...
# Episode 50/2000 | Avg Reward (50): 22.7 | Avg Loss (500): 0.9942 | Epsilon: 0.978
# Episode 100/2000 | Avg Reward (50): 20.2 | Avg Loss (500): 0.6337 | Epsilon: 0.959
# Episode 150/2000 | Avg Reward (50): 17.6 | Avg Loss (500): 0.6345 | Epsilon: 0.943
# Episode 200/2000 | Avg Reward (50): 20.4 | Avg Loss (500): 0.8415 | Epsilon: 0.923
# Episode 250/2000 | Avg Reward (50): 20.0 | Avg Loss (500): 1.0821 | Epsilon: 0.904
# Episode 300/2000 | Avg Reward (50): 22.4 | Avg Loss (500): 1.2815 | Epsilon: 0.883
# Episode 350/2000 | Avg Reward (50): 24.1 | Avg Loss (500): 1.6257 | Epsilon: 0.860
# Episode 400/2000 | Avg Reward (50): 31.5 | Avg Loss (500): 2.0684 | Epsilon: 0.830
# Episode 450/2000 | Avg Reward (50): 33.8 | Avg Loss (500): 2.5133 | Epsilon: 0.798
# Episode 500/2000 | Avg Reward (50): 34.6 | Avg Loss (500): 3.1699 | Epsilon: 0.765
# Episode 550/2000 | Avg Reward (50): 47.1 | Avg Loss (500): 4.1539 | Epsilon: 0.720
# Episode 600/2000 | Avg Reward (50): 69.7 | Avg Loss (500): 4.3808 | Epsilon: 0.654
# Episode 650/2000 | Avg Reward (50): 69.3 | Avg Loss (500): 5.9447 | Epsilon: 0.588
# Episode 700/2000 | Avg Reward (50): 107.1 | Avg Loss (500): 6.6323 | Epsilon: 0.487
# Episode 750/2000 | Avg Reward (50): 264.6 | Avg Loss (500): 2.8587 | Epsilon: 0.235
# Episode 800/2000 | Avg Reward (50): 304.1 | Avg Loss (500): 3.2362 | Epsilon: 0.050
# Episode 850/2000 | Avg Reward (50): 314.3 | Avg Loss (500): 2.3474 | Epsilon: 0.050
# Episode 900/2000 | Avg Reward (50): 337.5 | Avg Loss (500): 0.8066 | Epsilon: 0.050
# Episode 950/2000 | Avg Reward (50): 272.3 | Avg Loss (500): 0.2242 | Epsilon: 0.050
# Episode 1000/2000 | Avg Reward (50): 384.8 | Avg Loss (500): 0.7736 | Epsilon: 0.050
# Episode 1050/2000 | Avg Reward (50): 392.2 | Avg Loss (500): 6.7613 | Epsilon: 0.050
# Episode 1100/2000 | Avg Reward (50):
2000 | Avg Reward (50): 21.9 | Avg Loss (500): 1.5898 | Epsilon: 0.894
# Episode 300/2000 | Avg Reward (50): 24.1 | Avg Loss (500): 1.9661 | Epsilon: 0.871
# Episode 350/2000 | Avg Reward (50): 26.0 | Avg Loss (500): 2.4624 | Epsilon: 0.847
# Episode 400/2000 | Avg Reward (50): 27.7 | Avg Loss (500): 2.8820 | Epsilon: 0.820
# Episode 450/2000 | Avg Reward (50): 26.1 | Avg Loss (500): 3.3205 | Epsilon: 0.796
# Episode 500/2000 | Avg Reward (50): 27.8 | Avg Loss (500): 4.1734 | Epsilon: 0.769
# Episode 550/2000 | Avg Reward (50): 33.0 | Avg Loss (500): 5.4885 | Epsilon: 0.738
# Episode 600/2000 | Avg Reward (50): 43.5 | Avg Loss (500): 6.2848 | Epsilon: 0.697
# Episode 650/2000 | Avg Reward (50): 52.7 | Avg Loss (500): 6.3660 | Epsilon: 0.647
# Episode 700/2000 | Avg Reward (50): 77.1 | Avg Loss (500): 5.2469 | Epsilon: 0.573
# Episode 750/2000 | Avg Reward (50): 140.1 | Avg Loss (500): 5.8804 | Epsilon: 0.440
# Episode 800/2000 | Avg Reward (50): 249.7 | Avg Loss (500): 3.5019 | Epsilon: 0.203
# Episode 850/2000 | Avg Reward (50): 232.3 | Avg Loss (500): 1.7308 | Epsilon: 0.050
# Episode 900/2000 | Avg Reward (50): 320.9 | Avg Loss (500): 6.3947 | Epsilon: 0.050
# Episode 950/2000 | Avg Reward (50): 203.4 | Avg Loss (500): 3.1750 | Epsilon: 0.050
# Episode 1000/2000 | Avg Reward (50): 155.9 | Avg Loss (500): 0.0958 | Epsilon: 0.050
# Episode 1050/2000 | Avg Reward (50): 263.8 | Avg Loss (500): 2.8661 | Epsilon: 0.050
# Episode 1100/2000 | Avg Reward (50): 416.0 | Avg Loss (500): 7.1439 | Epsilon: 0.050
# Episode 1150/2000 | Avg Reward (50): 310.5 | Avg Loss (500): 3.1828 | Epsilon: 0.050
# Episode 1200/2000 | Avg Reward (50): 433.9 | Avg Loss (500): 9.0697 | Epsilon: 0.050
# Episode 1250/2000 | Avg Reward (50): 487.6 | Avg Loss (500): 8.6259 | Epsilon: 0.050
# Episode 1300/2000 | Avg Reward (50): 489.8 | Avg Loss (500): 11.0491 | Epsilon: 0.050
# Episode 1350/2000 | Avg Reward (50): 492.0 | Avg Loss (500): 14.6849 | Epsilon: 0.050
# Episode 1400/2000 | Avg Reward (50): 499.2 | Avg Loss (500): 8.5674 | Epsilon: 0.050
# Episode 1450/2000 | Avg Reward (50): 500.0 | Avg Loss (500): 16.7139 | Epsilon: 0.050
# Episode 1500/2000 | Avg Reward (50): 497.4 | Avg Loss (500): 18.0910 | Epsilon: 0.050
# Episode 1550/2000 | Avg Reward (50): 500.0 | Avg Loss (500): 17.3672 | Epsilon: 0.050
# Episode 1600/2000 | Avg Reward (50): 500.0 | Avg Loss (500): 21.1890 | Epsilon: 0.050
# Episode 1650/2000 | Avg Reward (50): 500.0 | Avg Loss (500): 22.1026 | Epsilon: 0.050
# Episode 1700/2000 | Avg Reward (50): 500.0 | Avg Loss (500): 15.7114 | Epsilon: 0.050
# Episode 1750/2000 | Avg Reward (50): 500.0 | Avg Loss (500): 17.4690 | Epsilon: 0.050
# Episode 1800/2000 | Avg Reward (50): 500.0 | Avg Loss (500): 18.4610 | Epsilon: 0.050
# Episode 1850/2000 | Avg Reward (50): 500.0 | Avg Loss (500): 20.0160 | Epsilon: 0.050
# Episode 1900/2000 | Avg Reward (50): 500.0 | Avg Loss (500): 20.2484 | Epsilon: 0.050
# Episode 1950/2000 | Avg Reward (50): 500.0 | Avg Loss (500): 18.5592 | Epsilon: 0.050
# Episode 2000/2000 | Avg Reward (50): 500.0 | Avg Loss (500): 23.1752 | Epsilon: 0.050
#
# Training with buffer_size=10000...
# Episode 50/2000 | Avg Reward (50): 22.7 | Avg Loss (500): 0.9957 | Epsilon: 0.978
# Episode 100/2000 | Avg Reward (50): 20.2 | Avg Loss (500): 0.6251 | Epsilon: 0.959
# Episode 150/2000 | Avg Reward (50): 17.6 | Avg Loss (500): 0.6196 | Epsilon: 0.943
# Episode 200/2000 | Avg Reward (50): 21.1 | Avg Loss (500): 0.8427 | Epsilon: 0.922
# Episode 250/2000 | Avg Reward (50): 20.9 | Avg Loss (500): 1.0579 | Epsilon: 0.903
# Episode 300/2000 | Avg Reward (50): 18.8 | Avg Loss (500): 1.1812 | Epsilon: 0.885
# Episode 350/2000 | Avg Reward (50): 24.8 | Avg Loss (500): 1.5364 | Epsilon: 0.861
# Episode 400/2000 | Avg Reward (50): 28.2 | Avg Loss (500): 1.9314 | Epsilon: 0.835
# Episode 450/2000 | Avg Reward (50): 33.4 | Avg Loss (500): 2.5708 | Epsilon: 0.803
# Episode 500/2000 | Avg Reward (50): 34.6 | Avg Loss (500): 3.4001 | Epsilon: 0.770
# Episode 550/2000 | Avg Reward (50): 40.8 | Avg Loss (500): 4.6531 | Epsilon: 0.731
# Episode 600/2000 | Avg Reward (50): 51.1 | Avg Loss (500): 5.8748 | Epsilon: 0.683
# Episode 650/2000 | Avg Reward (50): 74.4 | Avg Loss (500): 7.4515 | Epsilon: 0.612
# Episode 700/2000 | Avg Reward (50): 90.5 | Avg Loss (500): 8.5372 | Epsilon: 0.526
# Episode 750/2000 | Avg Reward (50): 169.2 | Avg Loss (500): 8.7678 | Epsilon: 0.365
# Episode 800/2000 | Avg Reward (50): 293.9 | Avg Loss (500): 3.4826 | Epsilon: 0.086
# Episode 850/2000 | Avg Reward (50): 277.5 | Avg Loss (500): 0.7778 | Epsilon: 0.050
# Episode 900/2000 | Avg Reward (50): 261.7 | Avg Loss (500): 0.0917 | Epsilon: 0.050
# Episode 950/2000 | Avg Reward (50): 245.0 | Avg Loss (500): 0.0335 | Epsilon: 0.050
# Episode 1000/2000 | Avg Reward (50): 233.3 | Avg Loss (500): 0.0347 | Epsilon: 0.050
# Episode 1050/2000 | Avg Reward (50): 223.0 | Avg Loss (500): 0.3610 | Epsilon: 0.050
# Episode 1100/2000 | Avg Reward (50): 210.9 | Avg Loss (500): 0.0294 | Epsilon: 0.050
# Episode 1150/2000 | Avg Reward (50): 259.2 | Avg Loss (500): 0.0286 | Epsilon: 0.050
# Episode 1200/2000 | Avg Reward (50): 394.4 | Avg Loss (500): 4.7242 | Epsilon: 0.050
# Episode 1250/2000 | Avg Reward (50): 448.4 | Avg Loss (500): 4.4214 | Epsilon: 0.050
# Episode 1300/2000 | Avg Reward (50): 481.0 | Avg Loss (500): 7.1410 | Epsilon: 0.050
# Episode 1350/2000 | Avg Reward (50): 492.7 | Avg Loss (500): 9.6645 | Epsilon: 0.050
# Episode 1400/2000 | Avg Reward (50): 497.3 | Avg Loss (500): 16.2995 | Epsilon: 0.050
# Episode 1450/2000 | Avg Reward (50): 494.7 | Avg Loss (500): 12.7869 | Epsilon: 0.050
# Episode 1500/2000 | Avg Reward (50): 496.6 | Avg Loss (500): 17.3744 | Epsilon: 0.050
# Episode 1550/2000 | Avg Reward (50): 496.9 | Avg Loss (500): 18.1203 | Epsilon: 0.050
# Episode 1600/2000 | Avg Reward (50): 500.0 | Avg Loss (500): 18.1342 | Epsilon: 0.050
# Episode 1650/2000 | Avg Reward (50): 500.0 | Avg Loss (500): 16.4886 | Epsilon: 0.050
# Episode 1700/2000 | Avg Reward (50): 498.7 | Avg Loss (500): 15.9882 | Epsilon: 0.050
# Episode 1750/2000 | Avg Reward (50): 500.0 | Avg Loss (500): 17.1340 | Epsilon: 0.050
# Episode 1800/2000 | Avg Reward (50): 486.9 | Avg Loss (500): 10.7109 | Epsilon: 0.050
# Episode 1850/2000 | Avg Reward (50): 500.0 | Avg Loss (500): 14.6839 | Epsilon: 0.050
# Episode 1900/2000 | Avg Reward (50): 500.0 | Avg Loss (500): 18.3581 | Epsilon: 0.050
# Episode 1950/2000 | Avg Reward (50): 500.0 | Avg Loss (500): 14.0772 | Epsilon: 0.050
# Episode 2000/2000 | Avg Reward (50): 500.0 | Avg Loss (500): 13.9022 | Epsilon: 0.050
# Episode 50/2000 | Avg Reward (50): 21.6 | Avg Loss (500): 1.2322 | Epsilon: 0.979
# Episode 100/2000 | Avg Reward (50): 23.4 | Avg Loss (500): 0.6962 | Epsilon: 0.957
# Episode 150/2000 | Avg Reward (50): 22.1 | Avg Loss (500): 0.7499 | Epsilon: 0.936
# Episode 200/2000 | Avg Reward (50): 19.1 | Avg Loss (500): 1.0087 | Epsilon: 0.918
# Episode 250/2000 | Avg Reward (50): 20.0 | Avg Loss (500): 1.2398 | Epsilon: 0.899
# Episode 300/2000 | Avg Reward (50): 25.7 | Avg Loss (500): 1.5097 | Epsilon: 0.875
# Episode 350/2000 | Avg Reward (50): 36.0 | Avg Loss (500): 2.1607 | Epsilon: 0.840
# Episode 400/2000 | Avg Reward (50): 29.8 | Avg Loss (500): 2.6010 | Epsilon: 0.812
# Episode 450/2000 | Avg Reward (50): 37.5 | Avg Loss (500): 3.5613 | Epsilon: 0.777
# Episode 500/2000 | Avg Reward (50): 33.3 | Avg Loss (500): 4.8156 | Epsilon: 0.745
# Episode 550/2000 | Avg Reward (50): 36.2 | Avg Loss (500): 6.2121 | Epsilon: 0.710
# Episode 600/2000 | Avg Reward (50): 51.0 | Avg Loss (500): 8.2110 | Epsilon: 0.662
# Episode 650/2000 | Avg Reward (50): 78.7 | Avg Loss (500): 10.0237 | Epsilon: 0.587
# Episode 700/2000 | Avg Reward (50): 108.1 | Avg Loss (500): 10.4227 | Epsilon: 0.485
# Episode 750/2000 | Avg Reward (50): 236.7 | Avg Loss (500): 9.2998 | Epsilon: 0.260
# Episode 800/2000 | Avg Reward (50): 208.0 | Avg Loss (500): 6.3755 | Epsilon: 0.062
# Episode 850/2000 | Avg Reward (50): 236.7 | Avg Loss (500): 1.8639 | Epsilon: 0.050
# Episode 900/2000 | Avg Reward (50): 297.2 | Avg Loss (500): 3.2805 | Epsilon: 0.050
# Episode 950/2000 | Avg Reward (50): 286.9 | Avg Loss (500): 0.7357 | Epsilon: 0.050
# Episode 1000/2000 | Avg Reward (50): 218.8 | Avg Loss (500): 0.4721 | Epsilon: 0.050
# Episode 1050/2000 | Avg Reward (50): 198.9 | Avg Loss (500): 0.1303 | Epsilon: 0.050
# Episode 1100/2000 | Avg Reward (50): 297.2 | Avg Loss (500): 2.5016 | Epsilon: 0.050
# Episode 1150/2000 | Avg Reward (50): 343.3 | Avg Loss (500): 3.1877 | Epsilon: 0.050
# Episode 1200/2000 | Avg Reward (50): 387.5 | Avg Loss (500): 0.5816 | Epsilon: 0.050
# Episode 1250/2000 | Avg Reward (50): 444.4 | Avg Loss (500): 6.1099 | Epsilon: 0.050
# Episode 1300/2000 | Avg Reward (50): 473.4 | Avg Loss (500): 10.4186 | Epsilon: 0.050
# Episode 1350/2000 | Avg Reward (50): 493.2 | Avg Loss (500): 10.3542 | Epsilon: 0.050
# Episode 1400/2000 | Avg Reward (50): 493.6 | Avg Loss (500): 12.3970 | Epsilon: 0.050
# Episode 1450/2000 | Avg Reward (50): 498.1 | Avg Loss (500): 19.2904 | Epsilon: 0.050
# Episode 1500/2000 | Avg Reward (50): 500.0 | Avg Loss (500): 18.9416 | Epsilon: 0.050
# Episode 1550/2000 | Avg Reward (50): 500.0 | Avg Loss (500): 18.5201 | Epsilon: 0.050
# Episode 1600/2000 | Avg Reward (50): 500.0 | Avg Loss (500): 18.0124 | Epsilon: 0.050
# Episode 1650/2000 | Avg Reward (50): 499.9 | Avg Loss (500): 17.8590 | Epsilon: 0.050
# Episode 1700/2000 | Avg Reward (50): 500.0 | Avg Loss (500): 17.4662 | Epsilon: 0.050
# Episode 1750/2000 | Avg Reward (50): 500.0 | Avg Loss (500): 19.5099 | Epsilon: 0.050
# Episode 1800/2000 | Avg Reward (50): 500.0 | Avg Loss (500): 20.5981 | Epsilon: 0.050
# Episode 1850/2000 | Avg Reward (50): 500.0 | Avg Loss (500): 17.4856 | Epsilon: 0.050
# Episode 1900/2000 | Avg Reward (50): 500.0 | Avg Loss (500): 22.2375 | Epsilon: 0.050
# Episode 1950/2000 | Avg Reward (50): 500.0 | Avg Loss (500): 21.2458 | Epsilon: 0.050
# Episode 2000/2000 | Avg Reward (50): 500.0 | Avg Loss (500): 20.5468 | Epsilon: 0.050
# Episode 50/2000 | Avg Reward (50): 24.8 | Avg Loss (500): 1.0324 | Epsilon: 0.976
# Episode 100/2000 | Avg Reward (50): 21.9 | Avg Loss (500): 0.7288 | Epsilon: 0.956
# Episode 150/2000 | Avg Reward (50): 22.3 | Avg Loss (500): 0.8296 | Epsilon: 0.934
# Episode 200/2000 | Avg Reward (50): 21.3 | Avg Loss (500): 1.1136 | Epsilon: 0.914
# Episode 250/2000 | Avg Reward (50): 22.3 | Avg Loss (500): 1.4340 | Epsilon: 0.893
# Episode 300/2000 | Avg Reward (50): 21.5 | Avg Loss (500): 1.7592 | Epsilon: 0.873
# Episode 350/2000 | Avg Reward (50): 22.7 | Avg Loss (500): 2.1684 | Epsilon: 0.851
# Episode 400/2000 | Avg Reward (50): 31.1 | Avg Loss (500): 2.6368 | Epsilon: 0.822
# Episode 450/2000 | Avg Reward (50): 33.6 | Avg Loss (500): 3.2002 | Epsilon: 0.790
# Episode 500/2000 | Avg Reward (50): 33.1 | Avg Loss (500): 3.9860 | Epsilon: 0.758
# Episode 550/2000 | Avg Reward (50): 39.6 | Avg Loss (500): 5.4394 | Epsilon: 0.721
# Episode 600/2000 | Avg Reward (50): 44.0 | Avg Loss (500): 7.1693 | Epsilon: 0.679
# Episode 650/2000 | Avg Reward (50): 53.1 | Avg Loss (500): 9.0647 | Epsilon: 0.628
# Episode 700/2000 | Avg Reward (50): 94.3 | Avg Loss (500): 10.8670 | Epsilon: 0.539
# Episode 750/2000 | Avg Reward (50): 162.3 | Avg Loss (500): 8.6984 | Epsilon: 0.384
# Episode 800/2000 | Avg Reward (50): 323.0 | Avg Loss (500): 2.4573 | Epsilon: 0.078
# Episode 850/2000 | Avg Reward (50): 336.6 | Avg Loss (500): 1.4622 | Epsilon: 0.050
# Episode 900/2000 | Avg Reward (50): 354.9 | Avg Loss (500): 1.8106 | Epsilon: 0.050
# Episode 950/2000 | Avg Reward (50): 455.5 | Avg Loss (500): 8.5640 | Epsilon: 0.050
# Episode 1000/2000 | Avg Reward (50): 469.9 | Avg Loss (500): 7.5482 | Epsilon: 0.050
# Episode 1050/2000 | Avg Reward (50): 495.8 | Avg Loss (500): 18.1989 | Epsilon: 0.050
# Episode 1100/2000 | Avg Reward (50): 497.5 | Avg Loss (500): 19.2522 | Epsilon: 0.050
# Episode 1150/2000 | Avg Reward (50): 497.5 | Avg Loss (500): 20.7320 | Epsilon: 0.050
# Episode 1200/2000 | Avg Reward (50): 500.0 | Avg Loss (500): 18.1310 | Epsilon: 0.050
# Episode 1250/2000 | Avg Reward (50): 500.0 | Avg Loss (500): 18.1470 | Epsilon: 0.050
# Episode 1300/2000 | Avg Reward (50): 500.0 | Avg Loss (500): 19.9778 | Epsilon: 0.050
# Episode 1350/2000 | Avg Reward (50): 500.0 | Avg Loss (500): 21.1272 | Epsilon: 0.050
# Episode 1400/2000 | Avg Reward (50): 500.0 | Avg Loss (500): 15.4607 | Epsilon: 0.050
# Episode 1450/2000 | Avg Reward (50): 500.0 | Avg Loss (500): 16.1956 | Epsilon: 0.050
# Episode 1500/2000 | Avg Reward (50): 500.0 | Avg Loss (500): 18.5081 | Epsilon: 0.050
# Episode 1550/2000 | Avg Reward (50): 500.0 | Avg Loss (500): 17.1872 | Epsilon: 0.050
# Episode 1600/2000 | Avg Reward (50): 500.0 | Avg Loss (500): 18.3920 | Epsilon: 0.050
# Episode 1650/2000 | Avg Reward (50): 500.0 | Avg Loss (500): 16.7681 | Epsilon: 0.050
# Episode 1700/2000 | Avg Reward (50): 500.0 | Avg Loss (500): 19.6066 | Epsilon: 0.050
# Episode 1750/2000 | Avg Reward (50): 500.0 | Avg Loss (500): 22.1302 | Epsilon: 0.050
# Episode 1800/2000 | Avg Reward (50): 500.0 | Avg Loss (500): 16.1761 | Epsilon: 0.050
# Episode 1850/2000 | Avg Reward (50): 500.0 | Avg Loss (500): 21.6952 | Epsilon: 0.050
# Episode 1900/2000 | Avg Reward (50): 500.0 | Avg Loss (500): 20.4047 | Epsilon: 0.050
# Episode 1950/2000 | Avg Reward (50): 500.0 | Avg Loss (500): 16.9805 | Epsilon: 0.050
# Episode 2000/2000 | Avg Reward (50): 496.0 | Avg Loss (500): 14.8242 | Epsilon: 0.050
#
# Training with buffer_size=100000...
# Episode 50/2000 | Avg Reward (50): 22.7 | Avg Loss (500): 0.9957 | Epsilon: 0.978
# Episode 100/2000 | Avg Reward (50): 20.2 | Avg Loss (500): 0.6251 | Epsilon: 0.959
# Episode 150/2000 | Avg Reward (50): 17.6 | Avg Loss (500): 0.6196 | Epsilon: 0.943
# Episode 200/2000 | Avg Reward (50): 21.1 | Avg Loss (500): 0.8427 | Epsilon: 0.922
# Episode 250/2000 | Avg Reward (50): 20.9 | Avg Loss (500): 1.0579 | Epsilon: 0.903
# Episode 300/2000 | Avg Reward (50): 18.8 | Avg Loss (500): 1.1812 | Epsilon: 0.885
# Episode 350/2000 | Avg Reward (50): 24.8 | Avg Loss (500): 1.5364 | Epsilon: 0.861
# Episode 400/2000 | Avg Reward (50): 28.2 | Avg Loss (500): 1.9314 | Epsilon: 0.835
# Episode 450/2000 | Avg Reward (50): 33.4 | Avg Loss (500): 2.5623 | Epsilon: 0.803
# Episode 500/2000 | Avg Reward (50): 38.9 | Avg Loss (500): 3.4692 | Epsilon: 0.766
# Episode 550/2000 | Avg Reward (50): 42.5 | Avg Loss (500): 4.5974 | Epsilon: 0.725
# Episode 600/2000 | Avg Reward (50): 55.0 | Avg Loss (500): 6.1322 | Epsilon: 0.673
# Episode 650/2000 | Avg Reward (50): 65.0 | Avg Loss (500): 7.7703 | Epsilon: 0.611
# Episode 700/2000 | Avg Reward (50): 80.9 | Avg Loss (500): 9.4985 | Epsilon: 0.535
# Episode 750/2000 | Avg Reward (50): 146.6 | Avg Loss (500): 13.6865 | Epsilon: 0.395
# Episode 800/2000 | Avg Reward (50): 233.0 | Avg Loss (500): 18.8416 | Epsilon: 0.174
# Episode 850/2000 | Avg Reward (50): 253.5 | Avg Loss (500): 22.4140 | Epsilon: 0.050
# Episode 900/2000 | Avg Reward (50): 241.5 | Avg Loss (500): 26.2938 | Epsilon: 0.050
# Episode 950/2000 | Avg Reward (50): 218.2 | Avg Loss (500): 25.5511 | Epsilon: 0.050
# Episode 1000/2000 | Avg Reward (50): 229.6 | Avg Loss (500): 28.1575 | Epsilon: 0.050
# Episode 1050/2000 | Avg Reward (50): 242.2 | Avg Loss (500): 36.3521 | Epsilon: 0.050
# Episode 1100/2000 | Avg Reward (50): 247.1 | Avg Loss (500): 32.5108 | Epsilon: 0.050
# Episode 1150/2000 | Avg Reward (50): 238.0 | Avg Loss (500): 41.1958 | Epsilon: 0.050
# Episode 1200/2000 | Avg Reward (50): 231.4 | Avg Loss (500): 35.3535 | Epsilon: 0.050
# Episode 1250/2000 | Avg Reward (50): 250.6 | Avg Loss (500): 16.7286 | Epsilon: 0.050
# Episode 1300/2000 | Avg Reward (50): 241.1 | Avg Loss (500): 1.5466 | Epsilon: 0.050
# Episode 1350/2000 | Avg Reward (50): 247.2 | Avg Loss (500): 0.5898 | Epsilon: 0.050
# Episode 1400/2000 | Avg Reward (50): 234.8 | Avg Loss (500): 1.9432 | Epsilon: 0.050
# Episode 1450/2000 | Avg Reward (50): 239.9 | Avg Loss (500): 10.9370 | Epsilon: 0.050
# Episode 1500/2000 | Avg Reward (50): 239.9 | Avg Loss (500): 19.2297 | Epsilon: 0.050
# Episode 1550/2000 | Avg Reward (50): 254.8 | Avg Loss (500): 24.0386 | Epsilon: 0.050
# Episode 1600/2000 | Avg Reward (50): 242.5 | Avg Loss (500): 21.1260 | Epsilon: 0.050
# Episode 1650/2000 | Avg Reward (50): 244.8 | Avg Loss (500): 30.4189 | Epsilon: 0.050
# Episode 1700/2000 | Avg Reward (50): 254.5 | Avg Loss (500): 36.4828 | Epsilon: 0.050
# Episode 1750/2000 | Avg Reward (50): 258.6 | Avg Loss (500): 57.7595 | Epsilon: 0.050
# Episode 1800/2000 | Avg Reward (50): 187.5 | Avg Loss (500): 130.5367 | Epsilon: 0.050
# Episode 1850/2000 | Avg Reward (50): 69.5 | Avg Loss (500): 230.6221 | Epsilon: 0.050
# Episode 1900/2000 | Avg Reward (50): 30.9 | Avg Loss (500): 212.5427 | Epsilon: 0.050
# Episode 1950/2000 | Avg Reward (50): 19.0 | Avg Loss (500): 207.4713 | Epsilon: 0.050
# Episode 2000/2000 | Avg Reward (50): 13.4 | Avg Loss (500): 209.5087 | Epsilon: 0.050
# Episode 50/2000 | Avg Reward (50): 21.6 | Avg Loss (500): 1.2322 | Epsilon: 0.979
# Episode 100/2000 | Avg Reward (50): 23.4 | Avg Loss (500): 0.6962 | Epsilon: 0.957
# Episode 150/2000 | Avg Reward (50): 22.1 | Avg Loss (500): 0.7499 | Epsilon: 0.936
# Episode 200/2000 | Avg Reward (50): 19.1 | Avg Loss (500): 1.0087 | Epsilon: 0.918
# Episode 250/2000 | Avg Reward (50): 20.0 | Avg Loss (500): 1.2398 | Epsilon: 0.899
# Episode 300/2000 | Avg Reward (50): 25.7 | Avg Loss (500): 1.5097 | Epsilon: 0.875
# Episode 350/2000 | Avg Reward (50): 36.0 | Avg Loss (500): 2.1607 | Epsilon: 0.840
# Episode 400/2000 | Avg Reward (50): 29.8 | Avg Loss (500): 2.6010 | Epsilon: 0.812
# Episode 450/2000 | Avg Reward (50): 38.1 | Avg Loss (500): 3.5418 | Epsilon: 0.776
# Episode 500/2000 | Avg Reward (50): 32.7 | Avg Loss (500): 4.6381 | Epsilon: 0.745
# Episode 550/2000 | Avg Reward (50): 41.5 | Avg Loss (500): 6.1242 | Epsilon: 0.705
# Episode 600/2000 | Avg Reward (50): 48.2 | Avg Loss (500): 7.8938 | Epsilon: 0.660
# Episode 650/2000 | Avg Reward (50): 63.8 | Avg Loss (500): 10.0494 | Epsilon: 0.599
# Episode 700/2000 | Avg Reward (50): 116.9 | Avg Loss (500): 12.3041 | Epsilon: 0.488
# Episode 750/2000 | Avg Reward (50): 209.1 | Avg Loss (500): 20.3275 | Epsilon: 0.289
# Episode 800/2000 | Avg Reward (50): 310.0 | Avg Loss (500): 23.7396 | Epsilon: 0.050
# Episode 850/2000 | Avg Reward (50):
| Epsilon: 0.050
# Episode 1500/2000 | Avg Reward (50): 279.2 | Avg Loss (500): 1.1192 | Epsilon: 0.050
# Episode 1550/2000 | Avg Reward (50): 274.8 | Avg Loss (500): 0.2537 | Epsilon: 0.050
# Episode 1600/2000 | Avg Reward (50): 358.7 | Avg Loss (500): 0.3239 | Epsilon: 0.050
# Episode 1650/2000 | Avg Reward (50): 471.0 | Avg Loss (500): 3.3593 | Epsilon: 0.050
# Episode 1700/2000 | Avg Reward (50): 500.0 | Avg Loss (500): 9.5243 | Epsilon: 0.050
# Episode 1750/2000 | Avg Reward (50): 344.6 | Avg Loss (500): 30.1653 | Epsilon: 0.050
# Episode 1800/2000 | Avg Reward (50): 500.0 | Avg Loss (500): 112.6794 | Epsilon: 0.050
# Episode 1850/2000 | Avg Reward (50): 383.0 | Avg Loss (500): 95.4598 | Epsilon: 0.050
# Episode 1900/2000 | Avg Reward (50): 209.5 | Avg Loss (500): 108.0413 | Epsilon: 0.050
# Episode 1950/2000 | Avg Reward (50): 129.8 | Avg Loss (500): 208.5524 | Epsilon: 0.050
# Episode 2000/2000 | Avg Reward (50): 112.2 | Avg Loss (500): 262.9043 | Epsilon: 0.050
#
# ============================================================
# Final Performance (last 100 episodes):
# ============================================================
# Buffer 1000: 498.4 ± 2.3
# Buffer 10000: 499.3 ± 1.0
# Buffer 100000: 135.4 ± 103.8
# Plot saved: c:\Users\Jensw\Desktop\tdde78lab\labs\lab1_value_based\experiments\plots\buffer_size_ablation_on_cartpole-v1.png

# %% [markdown]
# ## B.4 — Ablation: Target Network Update Frequency
#
# Investigate the effect of how often the target network is synchronized.
#
# Test update frequencies: **1** (every step), **10**, **100**, **1000** steps

# %%
target_update_freqs = [1, 10, 100, 1000]

print("Running target update frequency ablation on CartPole-v1...")
print("=" * 60)

all_results_target_freq = {}

for target_freq in target_update_freqs:
    print(f"\nTraining with target_network_frequency={target_freq}...")
    results = [
        train_dqn(
            env_name="CartPole-v1",
            num_episodes=2000,
            seed=s,
            target_network_frequency=target_freq,
            use_double_dqn=False,
            use_dueling=False
        )
        for s in seeds
    ]
    all_results_target_freq[f"Update Freq {target_freq}"] = results

print("\n" + "=" * 60)
print("Final Performance (last 100 episodes):")
print("=" * 60)

for name, results_list in all_results_target_freq.items():
    final_rewards = [np.mean(r['episode_rewards'][-100:]) for r in results_list]
    print(f"{name}: {np.mean(final_rewards):.1f} ± {np.std(final_rewards):.1f}")

plot_comparison(all_results_target_freq, title="Target Update Frequency Ablation on CartPole-v1")
# Out:
# Running target update frequency ablation on CartPole-v1...
# ============================================================
#
# Training with target_network_frequency=1...
# Episode 50/2000 | Avg Reward (50): 22.7 | Avg Loss (500): 1.1035 | Epsilon: 0.978
# Episode 100/2000 | Avg Reward (50): 20.2 | Avg Loss (500): 1.1591 | Epsilon: 0.959
# Episode 150/2000 | Avg Reward (50): 19.3 | Avg Loss (500): 2.0672 | Epsilon: 0.941
# Episode 200/2000 | Avg Reward (50): 19.3 | Avg Loss (500): 3.9889 | Epsilon: 0.923
# Episode 250/2000 | Avg Reward (50): 19.9 | Avg Loss (500): 6.2023 | Epsilon: 0.904
# Episode 300/2000 | Avg Reward (50): 22.9 | Avg Loss (500): 8.0578 | Epsilon: 0.882
# Episode 350/2000 | Avg Reward (50): 19.2 | Avg Loss (500): 10.5329 | Epsilon: 0.864
# Episode 400/2000 | Avg Reward (50): 29.3 | Avg Loss (500): 12.4210 | Epsilon: 0.836
# Episode 450/2000 | Avg Reward (50): 35.5 | Avg Loss (500): 14.8108 | Epsilon: 0.802
# Episode 500/2000 | Avg Reward (50): 38.7 | Avg Loss (500): 20.9345 | Epsilon: 0.765
# Episode 550/2000 | Avg Reward (50): 39.3 | Avg Loss (500): 33.0070 | Epsilon: 0.728
# Episode 600/2000 | Avg Reward (50): 45.0 | Avg Loss (500): 47.0151 | Epsilon: 0.685
# Episode 650/2000 | Avg Reward (50): 52.7 | Avg Loss (500): 60.5304 | Epsilon: 0.635
# Episode 700/2000 | Avg Reward (50): 66.1 | Avg Loss (500): 68.1253 | Epsilon: 0.572
# Episode 750/2000 | Avg Reward (50): 135.8 | Avg Loss (500): 62.8160 | Epsilon: 0.443
# Episode 800/2000 | Avg Reward (50): 208.7 | Avg Loss (500): 48.4992 | Epsilon: 0.245
# Episode 850/2000 | Avg Reward (50): 164.1 | Avg Loss (500): 36.0316 | Epsilon: 0.089
# Episode 900/2000 | Avg Reward (50): 229.1 | Avg Loss (500): 0.3079 | Epsilon: 0.050
# Episode 950/2000 | Avg Reward (50): 281.0 | Avg Loss (500): 15.5841 | Epsilon: 0.050
# Episode 1000/2000 | Avg Reward (50): 23.2 | Avg Loss (500): 56.5174 | Epsilon: 0.050
# Episode 1050/2000 | Avg Reward (50): 13.3 | Avg Loss (500): 84.1874 | Epsilon: 0.050
# Episode 1100/2000 | Avg Reward (50): 9.9 | Avg Loss (500): 133.1643 | Epsilon: 0.050
# Episode 1150/2000 | Avg Reward (50): 31.7 | Avg Loss (500): 235.7475 | Epsilon: 0.050
# Episode 1200/2000 | Avg Reward (50): 271.9 | Avg Loss (500): 16.6461 | Epsilon: 0.050
# Episode 1250/2000 | Avg Reward (50): 403.3 | Avg Loss (500): 5.0143 | Epsilon: 0.050
# Episode 1300/2000 | Avg Reward (50): 460.7 | Avg Loss (500): 10.0455 | Epsilon: 0.050
# Episode 1350/2000 | Avg Reward (50): 490.7 | Avg Loss (500): 11.7458 | Epsilon: 0.050
# Episode 1400/2000 | Avg Reward (50): 497.5 | Avg Loss (500): 13.2206 | Epsilon: 0.050
# Episode 1450/2000 | Avg Reward (50): 499.6 | Avg Loss (500): 16.0477 | Epsilon: 0.050
# Episode 1500/2000 | Avg Reward (50): 499.9 | Avg Loss (500): 18.7219 | Epsilon: 0.050
# Episode 1550/2000 | Avg Reward (50): 500.0 | Avg Loss (500): 17.3509 | Epsilon: 0.050
# Episode 1600/2000 | Avg Reward (50): 500.0 | Avg Loss (500): 16.9294 | Epsilon: 0.050
# Episode 1650/2000 | Avg Reward (50): 500.0 | Avg Loss (500): 19.0494 | Epsilon: 0.050
# Episode 1700/2000 | Avg Reward (50): 497.4 | Avg Loss (500): 21.0393 | Epsilon: 0.050
# Episode 1750/2000 | Avg Reward (50): 484.4 | Avg Loss (500): 11.3597 | Epsilon: 0.050
# Episode 1800/2000 | Avg Reward (50): 500.0 | Avg Loss (500): 17.8323 | Epsilon: 0.050
# Episode 1850/2000 | Avg Reward (50): 500.0 | Avg Loss (500): 21.3529 | Epsilon: 0.050
# Episode 1900/2000 | Avg Reward (50): 500.0 | Avg Loss (500): 21.3177 | Epsilon: 0.050
# Episode 1950/2000 | Avg Reward (50): 500.0 | Avg Loss (500): 17.8673 | Epsilon: 0.050
# Episode 2000/2000 | Avg Reward (50): 500.0 | Avg Loss (500): 21.6738 | Epsilon: 0.050
# Episode 50/2000 | Avg Reward (50): 21.6 | Avg Loss (500): 1.2967 | Epsilon: 0.979
# Episode 100/2000 | Avg Reward (50): 23.4 | Avg Loss (500): 1.4442 | Epsilon: 0.957
# Episode 150/2000 | Avg Reward (50): 23.4 | Avg Loss (500): 3.3936 | Epsilon: 0.935
# Episode 200/2000 | Avg Reward (50): 22.9 | Avg Loss (500): 6.7095 | Epsilon: 0.913
# Episode 250/2000 | Avg Reward (50): 18.0 | Avg Loss (500): 9.9308 | Epsilon: 0.896
# Episode 300/2000 | Avg Reward (50): 23.0 | Avg Loss (500): 14.9260 | Epsilon: 0.874
# Episode 350/2000 | Avg Reward (50): 18.7 | Avg Loss (500): 18.0563 | Epsilon: 0.857
# Episode 400/2000 | Avg Reward (50): 29.5 | Avg Loss (500): 19.6473 | Epsilon: 0.829
# Episode 450/2000 | Avg Reward (50): 27.9 | Avg Loss (500): 19.5282 | Epsilon: 0.802
# Episode 500/2000 | Avg Reward (50): 33.3 | Avg Loss (500): 22.1335 | Epsilon: 0.770
# Episode 550/2000 | Avg Reward (50): 32.7 | Avg Loss (500): 30.3330 | Epsilon: 0.739
# Episode 600/2000 | Avg Reward (50): 33.8 | Avg Loss (500): 41.3521 | Epsilon: 0.707
# Episode 650/2000 | Avg Reward (50): 44.5 | Avg Loss (500): 55.9040 | Epsilon: 0.665
# Episode 700/2000 | Avg Reward (50): 42.9 | Avg Loss (500): 68.7870 | Epsilon: 0.624
# Episode 750/2000 | Avg Reward (50): 67.5 | Avg Loss (500): 75.5150 | Epsilon: 0.560
# Episode 800/2000 | Avg Reward (50): 92.0 | Avg Loss (500): 74.1721 | Epsilon: 0.473
# Episode 850/2000 | Avg Reward (50): 214.1 | Avg Loss (500): 47.4292 | Epsilon: 0.269
# Episode 900/2000 | Avg Reward (50): 193.7 | Avg Loss (500): 10.7366 | Epsilon: 0.085
# Episode 950/2000 | Avg Reward (50): 226.1 | Avg Loss (500): 61.4218 | Epsilon: 0.050
# Episode 1000/2000 | Avg Reward (50): 83.4 | Avg Loss (500): 88.1586 | Epsilon: 0.050
# Episode 1050/2000 | Avg Reward (50): 12.3 | Avg Loss (500): 121.9183 | Epsilon: 0.050
# Episode 1100/2000 | Avg Reward (50): 12.0 | Avg Loss (500): 178.4483 | Epsilon: 0.050
# Episode 1150/2000 | Avg Reward (50): 42.8 | Avg Loss (500): 319.8682 | Epsilon: 0.050
# Episode 1200/2000 | Avg Reward (50): 10.4 | Avg Loss (500): 358.3415 | Epsilon: 0.050
# Episode 1250/2000 | Avg Reward (50): 31.5 | Avg Loss (500): 430.7088 | Epsilon: 0.050
# Episode 1300/2000 | Avg Reward (50): 190.6 | Avg Loss (500): 167.9382 | Epsilon: 0.050
# Episode 1350/2000 | Avg Reward (50): 83.4 | Avg Loss (500): 185.4135 | Epsilon: 0.050
# Episode 1400/2000 | Avg Reward (50): 133.9 | Avg Loss (500): 5.6414 | Epsilon: 0.050
# Episode 1450/2000 | Avg Reward (50): 184.2 | Avg Loss (500): 0.8537 | Epsilon: 0.050
# Episode 1500/2000 | Avg Reward (50): 435.1 | Avg Loss (500): 23.5891 | Epsilon: 0.050
# Episode 1550/2000 | Avg Reward (50): 497.4 | Avg Loss (500): 17.5204 | Epsilon: 0.050
# Episode 1600/2000 | Avg Reward (50): 499.3 | Avg Loss (500): 16.1607 | Epsilon: 0.050
# Episode 1650/2000 | Avg Reward (50): 499.0 | Avg Loss (500): 15.4393 | Epsilon: 0.050
# Episode 1700/2000 | Avg Reward (50): 500.0 | Avg Loss (500): 14.8388 | Epsilon: 0.050
# Episode 1750/2000 | Avg Reward (50): 500.0 | Avg Loss (500): 15.2735 | Epsilon: 0.050
# Episode 1800/2000 | Avg Reward (50): 500.0 | Avg Loss (500): 17.6525 | Epsilon: 0.050
# Episode 1850/2000 | Avg Reward (50): 462.9 | Avg Loss (500): 30.7399 | Epsilon: 0.050
# Episode 1900/2000 | Avg Reward (50): 18.7 | Avg Loss (500): 58.1459 | Epsilon: 0.050
# Episode 1950/2000 | Avg Reward (50): 9.7 | Avg Loss (500): 75.4291 | Epsilon: 0.050
# Episode 2000/2000 | Avg Reward (50): 212.7 | Avg Loss (500): 31.3337 | Epsilon: 0.050
# Episode 50/2000 | Avg Reward (50): 24.8 | Avg Loss (500): 1.2415 | Epsilon: 0.976
# Episode 100/2000 | Avg Reward (50): 21.9 | Avg Loss (500): 1.6317 | Epsilon: 0.956
# Episode 150/2000 | Avg Reward (50): 23.6 | Avg Loss (500): 3.6265 | Epsilon: 0.933
# Episode 200/2000 | Avg Reward (50): 20.7 | Avg Loss (500): 6.7268 | Epsilon: 0.914
# Episode 250/2000 | Avg Reward (50): 22.5 | Avg Loss (500): 10.3108 | Epsilon: 0.892
# Episode 300/2000 | Avg Reward (50): 21.8 | Avg Loss (500): 15.1926 | Epsilon: 0.872
# Episode 350/2000 | Avg Reward (50): 18.7 | Avg Loss (500): 19.5634 | Epsilon: 0.854
# Episode 400/2000 | Avg Reward (50): 19.6 | Avg Loss (500): 21.7182 | Epsilon: 0.835
# Episode 450/2000 | Avg Reward (50): 26.8 | Avg Loss (500): 21.1001 | Epsilon: 0.810
# Episode 500/2000 | Avg Reward (50): 29.1 | Avg Loss (500): 19.6073 | Epsilon: 0.782
# Episode 550/2000 | Avg Reward (50): 30.3 | Avg Loss (500): 20.6282 | Epsilon: 0.753
# Episode 600/2000 | Avg Reward (50): 41.3 | Avg Loss (500): 29.3686 | Epsilon: 0.714
# Episode 650/2000 | Avg Reward (50): 45.2 | Avg Loss (500): 42.4345 | Epsilon: 0.671
# Episode 700/2000 | Avg Reward (50): 44.8 | Avg Loss (500): 57.1875 | Epsilon: 0.628
# Episode 750/2000 | Avg Reward (50): 46.8 | Avg Loss (500): 66.5944 | Epsilon: 0.584
# Episode 800/2000 | Avg Reward (50): 59.9 | Avg Loss (500): 70.6338 | Epsilon: 0.527
# Episode 850/2000 | Avg Reward (50): 83.4 | Avg Loss (500): 63.6437 | Epsilon: 0.448
# Episode 900/2000 | Avg Reward (50): 200.4 | Avg Loss (500): 29.9539 | Epsilon: 0.257
# Episode 950/2000 | Avg Reward (50): 226.4 | Avg Loss (500): 5.0254 | Epsilon: 0.050
# Episode 1000/2000 | Avg Reward (50): 119.7 | Avg Loss (500): 15.7278 | Epsilon: 0.050
# Episode 1050/2000 | Avg Reward (50): 54.6 | Avg Loss (500): 72.8481 | Epsilon: 0.050
# Episode 1100/2000 | Avg Reward (50): 10.6 | Avg Loss (500): 94.9428 | Epsilon: 0.050
# Episode 1150/2000 | Avg Reward (50): 41.6 | Avg Loss (500): 182.7520 | Epsilon: 0.050
# Episode 1200/2000 | Avg Reward (50): 126.8 | Avg Loss (500): 69.5440 | Epsilon: 0.050
# Episode 1250/2000 | Avg Reward (50): 11.4 | Avg Loss (500): 75.6427 | Epsilon: 0.050
# Episode 1300/2000 | Avg Reward (50): 12.3 | Avg Loss (500): 93.7255 | Epsilon: 0.050
# Episode 1350/2000 | Avg Reward (50): 81.9 | Avg Loss (500): 158.5548 | Epsilon: 0.050
# Episode 1400/2000 | Avg Reward (50): 13.2 | Avg Loss (500): 195.2918 | Epsilon: 0.050
# Episode 1450/2000 | Avg Reward (50): 13.7 | Avg Loss (500): 257.6416 | Epsilon: 0.050
# Episode 1500/2000 | Avg Reward (50): 245.1 | Avg Loss (500): 29.7788 | Epsilon: 0.050
# Episode 1550/2000 | Avg Reward (50): 326.4 | Avg Loss (500): 0.5982 | Epsilon: 0.050
# Episode 1600/2000 | Avg Reward (50): 290.1 | Avg Loss (500): 0.3546 | Epsilon: 0.050
# Episode 1650/2000 | Avg Reward (50): 332.6 | Avg Loss (500): 1.8662 | Epsilon: 0.050
# Episode 1700/2000 | Avg Reward (50): 386.2 | Avg Loss (500): 3.2668 | Epsilon: 0.050
# Episode 1750/2000 | Avg Reward (50): 426.9 | Avg Loss (500): 20.2343 | Epsilon: 0.050
# Episode 1800/2000 | Avg Reward (50): 410.1 | Avg Loss (500): 4.6584 | Epsilon: 0.050
# Episode 1850/2000 | Avg Reward (50): 170.9 | Avg Loss (500): 67.6495 | Epsilon: 0.050
# Episode 1900/2000 | Avg Reward (50): 26.1 | Avg Loss (500): 133.0962 | Epsilon: 0.050
# Episode 1950/2000 | Avg Reward (50): 222.6 | Avg Loss (500): 77.4686 | Epsilon: 0.050
# Episode 2000/2000 | Avg Reward (50): 229.6 | Avg Loss (500): 91.0301 | Epsilon: 0.050
#
# Training with target_network_frequency=10...
# Episode 50/2000 | Avg Reward (50): 22.7 | Avg Loss (500): 1.1035 | Epsilon: 0.978
# Episode 100/2000 | Avg Reward (50): 20.2 | Avg Loss (500): 1.1591 | Epsilon: 0.959
# Episode 150/2000 | Avg Reward (50): 19.3 | Avg Loss (500): 2.0672 | Epsilon: 0.941
# Episode 200/2000 | Avg Reward (50): 19.3 | Avg Loss (500): 3.9889 | Epsilon: 0.923
# Episode 250/2000 | Avg Reward (50): 19.9 | Avg Loss (500): 6.2023 | Epsilon: 0.904
# Episode 300/2000 | Avg Reward (50): 22.9 | Avg Loss (500): 8.0578 | Epsilon: 0.882
# Episode 350/2000 | Avg Reward (50): 19.2 | Avg Loss (500): 10.5329 | Epsilon: 0.864
# Episode 400/2000 | Avg Reward (50): 29.3 | Avg Loss (500): 12.4210 | Epsilon: 0.836
# Episode 450/2000 | Avg Reward (50): 35.5 | Avg Loss (500): 14.8108 | Epsilon: 0.802
# Episode 500/2000 | Avg Reward (50): 38.7 | Avg Loss (500): 20.9345 | Epsilon: 0.765
# Episode 550/2000 | Avg Reward (50): 39.3 | Avg Loss (500): 33.0070 | Epsilon: 0.728
# Episode 600/2000 | Avg Reward (50): 45.0 | Avg Loss (500): 47.0151 | Epsilon: 0.685
# Episode 650/2000 | Avg Reward (50): 52.7 | Avg Loss (500): 60.5304 | Epsilon: 0.635
# Episode 700/2000 | Avg Reward (50): 66.1 | Avg Loss (500): 68.1253 | Epsilon: 0.572
# Episode 750/2000 | Avg Reward (50): 135.8 | Avg Loss (500): 62.8160 | Epsilon: 0.443
# Episode 800/2000 | Avg Reward (50): 208.7 | Avg Loss (500): 48.4992 | Epsilon: 0.245
# Episode 850/2000 | Avg Reward (50): 164.1 | Avg Loss (500): 36.0316 | Epsilon: 0.089
# Episode 900/2000 | Avg Reward (50): 229.1 | Avg Loss (500): 0.3079 | Epsilon: 0.050
# Episode 950/2000 | Avg Reward (50): 281.0 | Avg Loss (500): 15.5841 | Epsilon: 0.050
# Episode 1000/2000 | Avg Reward (50): 23.2 | Avg Loss (500): 56.5174 | Epsilon: 0.050
# Episode 1050/2000 | Avg Reward (50): 13.3 | Avg Loss (500): 84.1874 | Epsilon: 0.050
# Episode 1100/2000 | Avg Reward (50): 9.9 | Avg Loss (500): 133.1643 | Epsilon: 0.050
# Episode 1150/2000 | Avg Reward (50): 31.7 | Avg Loss (500): 235.7475 | Epsilon: 0.050
# Episode 1200/2000 | Avg Reward (50): 271.9 | Avg Loss (500): 16.6461 | Epsilon: 0.050
# Episode 1250/2000 | Avg Reward (50): 403.3 | Avg Loss (500): 5.0143 | Epsilon: 0.050
# Episode 1300/2000 | Avg Reward (50): 460.7 | Avg Loss (500): 10.0455 | Epsilon: 0.050
# Episode 1350/2000 | Avg Reward (50): 490.7 | Avg Loss (500): 11.7458 | Epsilon: 0.050
# Episode 1400/2000 | Avg Reward (50): 497.5 | Avg Loss (500): 13.2206 | Epsilon: 0.050
# Episode 1450/2000 | Avg Reward (50): 499.6 | Avg Loss (500): 16.0477 | Epsilon: 0.050
# Episode 1500/2000 | Avg Reward (50): 499.9 | Avg Loss (500): 18.7219 | Epsilon: 0.050
# Episode 1550/2000 | Avg Reward (50): 500.0 | Avg Loss (500): 17.3509 | Epsilon: 0.050
# Episode 1600/2000 | Avg Reward (50): 500.0 | Avg Loss (500): 16.9294 | Epsilon: 0.050
# Episode 1650/2000 | Avg Reward (50): 500.0 | Avg Loss (500): 19.0494 | Epsilon: 0.050
# Episode 1700/2000 | Avg Reward (50): 497.4 | Avg Loss (500): 21.0393 | Epsilon: 0.050
# Episode 1750/2000 | Avg Reward (50): 484.4 | Avg Loss (500): 11.3597 | Epsilon: 0.050
# Episode 1800/2000 | Avg Reward (50): 500.0 | Avg Loss (500): 17.8323 | Epsilon: 0.050
# Episode 1850/2000 | Avg Reward (50): 500.0 | Avg Loss (500): 21.3529 | Epsilon: 0.050
# Episode 1900/2000 | Avg Reward (50): 500.0 | Avg Loss (500): 21.3177 | Epsilon: 0.050
# Episode 1950/2000 | Avg Reward (50): 500.0 | Avg Loss (500): 17.8673 | Epsilon: 0.050
# Episode 2000/2000 | Avg Reward (50): 500.0 | Avg Loss (500): 21.6738 | Epsilon: 0.050
# Episode 50/2000 | Avg Reward (50): 21.6 | Avg Loss (500): 1.2967 | Epsilon: 0.979
# Episode 100/2000 | Avg Reward (50): 23.4 | Avg Loss (500): 1.4442 | Epsilon: 0.957
# Episode 150/2000 | Avg Reward (50): 23.4 | Avg Loss (500): 3.3936 | Epsilon: 0.935
# Episode 200/2000 | Avg Reward (50): 22.9 | Avg Loss (500): 6.7095 | Epsilon: 0.913
# Episode 250/2000 | Avg Reward (50): 18.0 | Avg Loss (500): 9.9308 | Epsilon: 0.896
# Episode 300/2000 | Avg Reward (50): 23.0 | Avg Loss (500): 14.9260 | Epsilon: 0.874
# Episode 350/2000 | Avg Reward (50): 18.7 | Avg Loss (500): 18.0563 | Epsilon: 0.857
# Episode 400/2000 | Avg Reward (50): 29.5 | Avg Loss (500): 19.6473 | Epsilon: 0.829
# Episode 450/2000 | Avg Reward (50): 27.9 | Avg Loss (500): 19.5282 | Epsilon: 0.802
# Episode 500/2000 | Avg Reward (50): 33.3 | Avg Loss (500): 22.1335 | Epsilon: 0.770
# Episode 550/2000 | Avg Reward (50): 32.7 | Avg Loss (500): 30.3330 | Epsilon: 0.739
# Episode 600/2000 | Avg Reward (50): 33.8 | Avg Loss (500): 41.3521 | Epsilon: 0.707
# Episode 650/2000 | Avg Reward (50): 44.5 | Avg Loss (500): 55.9040 | Epsilon: 0.665
# Episode 700/2000 | Avg Reward (50): 42.9 | Avg Loss (500): 68.7870 | Epsilon: 0.624
# Episode 750/2000 | Avg Reward (50): 67.5 | Avg Loss (500): 75.5150 | Epsilon: 0.560
# Episode 800/2000 | Avg Reward (50): 92.0 | Avg Loss (500): 74.1721 | Epsilon: 0.473
# Episode 850/2000 | Avg Reward (50): 214.1 | Avg Loss (500): 47.4292 | Epsilon: 0.269
# Episode 900/2000 | Avg Reward (50): 193.7 | Avg Loss (500): 10.7366 | Epsilon: 0.085
# Episode 950/2000 | Avg Reward (50): 226.1 | Avg Loss (500): 61.4218 | Epsilon: 0.050
# Episode 1000/2000 | Avg Reward (50): 83.4 | Avg Loss (500): 88.1586 | Epsilon: 0.050
# Episode 1050/2000 | Avg Reward (50): 12.3 | Avg Loss (500): 121.9183 | Epsilon: 0.050
# Episode 1100/2000 | Avg Reward (50): 12.0 | Avg Loss (500): 178.4483 | Epsilon: 0.050
# Episode 1150/2000 | Avg Reward (50): 42.8 | Avg Loss (500): 319.8682 | Epsilon: 0.050
# Episode 1200/2000 | Avg Reward (50): 10.4 | Avg Loss (500): 358.3415 | Epsilon: 0.050
# Episode 1250/2000 | Avg Reward (50): 31.5 | Avg Loss (500): 430.7088 | Epsilon: 0.050
# Episode 1300/2000 | Avg Reward (50): 190.6 | Avg Loss (500): 167.9382 | Epsilon: 0.050
# Episode 1350/2000 | Avg Reward (50): 83.4 | Avg Loss (500): 185.4135 | Epsilon: 0.050
# Episode 1400/2000 | Avg Reward (50): 133.9 | Avg Loss (500): 5.6414 | Epsilon: 0.050
# Episode 1450/2000 | Avg Reward (50): 184.2 | Avg Loss (500): 0.8537 | Epsilon: 0.050
# Episode 1500/2000 | Avg Reward (50): 435.1 | Avg Loss (500): 23.5891 | Epsilon: 0.050
# Episode 1550/2000 | Avg Reward (50): 497.4 | Avg Loss (500): 17.5204 | Epsilon: 0.050
# Episode 1600/2000 | Avg Reward (50): 499.3 | Avg Loss (500): 16.1607 | Epsilon: 0.050
# Episode 1650/2000 | Avg Reward (50): 499.0 | Avg Loss (500): 15.4393 | Epsilon: 0.050
# Episode 1700/2000 | Avg Reward (50): 500.0 | Avg Loss (500): 14.8388 | Epsilon: 0.050
# Episode 1750/2000 | Avg Reward (50): 500.0 | Avg Loss (500): 15.2735 | Epsilon: 0.050
# Episode 1800/2000 | Avg Reward (50): 500.0 | Avg Loss (500): 17.6525 | Epsilon: 0.050
# Episode 1850/2000 | Avg Reward (50): 462.9 | Avg Loss (500): 30.7399 | Epsilon: 0.050
# Episode 1900/2000 | Avg Reward (50): 18.7 | Avg Loss (500): 58.1459 | Epsilon: 0.050
# Episode 1950/2000 | Avg Reward (50): 9.7 | Avg Loss (500): 75.4291 | Epsilon: 0.050
# Episode 2000/2000 | Avg Reward (50): 212.7 | Avg Loss (500): 31.3337 | Epsilon: 0.050
# Episode 50/2000 | Avg Reward (50): 24.8 | Avg Loss (500): 1.2415 | Epsilon: 0.976
# Episode 100/2000 | Avg Reward (50): 21.9 | Avg Loss (500): 1.6317 | Epsilon: 0.956
# Episode 150/2000 | Avg Reward (50): 23.6 | Avg Loss (500): 3.6265 | Epsilon: 0.933
# Episode 200/2000 | Avg Reward (50): 20.7 | Avg Loss (500): 6.7268 | Epsilon: 0.914
# Episode 250/2000 | Avg Reward (50): 22.5 | Avg Loss (500): 10.3108 | Epsilon: 0.892
# Episode 300/2000 | Avg Reward (50): 21.8 | Avg Loss (500): 15.1926 | Epsilon: 0.872
# Episode 350/2000 | Avg Reward (50): 18.7 | Avg Loss (500): 19.5634 | Epsilon: 0.854
# Episode 400/2000 | Avg Reward (50): 19.6 | Avg Loss (500): 21.7182 | Epsilon: 0.835
# Episode 450/2000 | Avg Reward (50): 26.8 | Avg Loss (500): 21.1001 | Epsilon: 0.810
# Episode 500/2000 | Avg Reward (50): 29.1 | Avg Loss (500): 19.6073 | Epsilon: 0.782
# Episode 550/2000 | Avg Reward (50): 30.3 | Avg Loss (500): 20.6282 | Epsilon: 0.753
# Episode 600/2000 | Avg Reward (50): 41.3 | Avg Loss (500): 29.3686 | Epsilon: 0.714
# Episode 650/2000 | Avg Reward (50): 45.2 | Avg Loss (500): 42.4345 | Epsilon: 0.671
# Episode 700/2000 | Avg Reward (50): 44.8 | Avg Loss (500): 57.1875 | Epsilon: 0.628
# Episode 750/2000 | Avg Reward (50): 46.8 | Avg Loss (500): 66.5944 | Epsilon: 0.584
# Episode 800/2000 | Avg Reward (50): 59.9 | Avg Loss (500): 70.6338 | Epsilon: 0.527
# Episode 850/2000 | Avg Reward (50): 83.4 | Avg Loss (500): 63.6437 | Epsilon: 0.448
# Episode 900/2000 | Avg Reward (50): 200.4 | Avg Loss (500): 29.9539 | Epsilon: 0.257
# Episode 950/2000 | Avg Reward (50): 226.4 | Avg Loss (500): 5.0254 | Epsilon: 0.050
# Episode 1000/2000 | Avg Reward (50): 119.7 | Avg Loss (500): 15.7278 | Epsilon: 0.050
# Episode 1050/2000 | Avg Reward (50): 54.6 | Avg Loss (500): 72.8481 | Epsilon: 0.050
# Episode 1100/2000 | Avg Reward (50): 10.6 | Avg Loss (500): 94.9428 | Epsilon: 0.050
# Episode 1150/2000 | Avg Reward (50): 41.6 | Avg Loss (500): 182.7520 | Epsilon: 0.050
# Episode 1200/2000 | Avg Reward (50): 126.8 | Avg Loss (500): 69.5440 | Epsilon: 0.050
# Episode 1250/2000 | Avg Reward (50): 11.4 | Avg Loss (500): 75.6427 | Epsilon: 0.050
# Episode 1300/2000 | Avg Reward (50): 12.3 | Avg Loss (500): 93.7255 | Epsilon: 0.050
# Episode 1350/2000 | Avg Reward (50): 81.9 | Avg Loss (500): 158.5548 | Epsilon: 0.050
# Episode 1400/2000 | Avg Reward (50): 13.2 | Avg Loss (500): 195.2918 | Epsilon: 0.050
# Episode 1450/2000 | Avg Reward (50): 13.7 | Avg Loss (500): 257.6416 | Epsilon: 0.050
# Episode 1500/2000 | Avg Reward (50): 245.1 | Avg Loss (500): 29.7788 | Epsilon: 0.050
# Episode 1550/2000 | Avg Reward (50): 326.4 | Avg Loss (500): 0.5982 | Epsilon: 0.050
# Episode 1600/2000 | Avg Reward (50): 290.1 | Avg Loss (500): 0.3546 | Epsilon: 0.050
# Episode 1650/2000 | Avg Reward (50): 332.6 | Avg Loss (500): 1.8662 | Epsilon: 0.050
# Episode 1700/2000 | Avg Reward (50): 386.2 | Avg Loss (500): 3.2668 | Epsilon: 0.050
# Episode 1750/2000 | Avg Reward (50): 426.9 | Avg Loss (500): 20.2343 | Epsilon: 0.050
# Episode 1800/2000 | Avg Reward (50): 410.1 | Avg Loss (500): 4.6584 | Epsilon: 0.050
# Episode 1850/2000 | Avg Reward (50): 170.9 | Avg Loss (500): 67.6495 | Epsilon: 0.050
# Episode 1900/2000 | Avg Reward (50): 26.1 | Avg Loss (500): 133.0962 | Epsilon: 0.050
# Episode 1950/2000 | Avg Reward (50): 222.6 | Avg Loss (500): 77.4686 | Epsilon: 0.050
# Episode 2000/2000 | Avg Reward (50): 229.6 | Avg Loss (500): 91.0301 | Epsilon: 0.050
#
# Training with target_network_frequency=100...
# Episode 50/2000 | Avg Reward (50): 22.7 | Avg Loss (500): 1.0359 | Epsilon: 0.978
# Episode 100/2000 | Avg Reward (50): 20.2 | Avg Loss (500): 0.9967 | Epsilon: 0.959
# Episode 150/2000 | Avg Reward (50): 19.4 | Avg Loss (500): 1.5985 | Epsilon: 0.941
# Episode 200/2000 | Avg Reward (50): 18.7 | Avg Loss (500): 2.9732 | Epsilon: 0.923
# Episode 250/2000 | Avg Reward (50): 18.8 | Avg Loss (500): 4.6670 | Epsilon: 0.905
# Episode 300/2000 | Avg Reward (50): 23.7 | Avg Loss (500): 6.1867 | Epsilon: 0.883
# Episode 350/2000 | Avg Reward (50): 24.4 | Avg Loss (500): 8.3957 | Epsilon: 0.860
# Episode 400/2000 | Avg Reward (50): 24.5 | Avg Loss (500): 9.9989 | Epsilon: 0.836
# Episode 450/2000 | Avg Reward (50): 29.4 | Avg Loss (500): 11.6871 | Epsilon: 0.808
# Episode 500/2000 | Avg Reward (50): 32.2 | Avg Loss (500): 15.3850 | Epsilon: 0.778
# Episode 550/2000 | Avg Reward (50): 45.8 | Avg Loss (500): 24.0093 | Epsilon: 0.734
# Episode 600/2000 | Avg Reward (50): 38.7 | Avg Loss (500): 33.0606 | Epsilon: 0.698
# Episode 650/2000 | Avg Reward (50): 55.7 | Avg Loss (500): 42.7053 | Epsilon: 0.645
# Episode 700/2000 | Avg Reward (50): 76.2 | Avg Loss (500): 49.1631 | Epsilon: 0.572
# Episode 750/2000 | Avg Reward (50): 135.7 | Avg Loss (500): 52.3056 | Epsilon: 0.443
# Episode 800/2000 | Avg Reward (50): 222.8 | Avg Loss (500): 52.5412 | Epsilon: 0.232
# Episode 850/2000 | Avg Reward (50): 190.3 | Avg Loss (500): 3.8176 | Epsilon: 0.051
# Episode 900/2000 | Avg Reward (50): 235.5 | Avg Loss (500): 2.2200 | Epsilon: 0.050
# Episode 950/2000 | Avg Reward (50): 281.2 | Avg Loss (500): 10.8035 | Epsilon: 0.050
# Episode 1000/2000 | Avg Reward (50): 284.2 | Avg Loss (500): 0.7477 | Epsilon: 0.050
# Episode 1050/2000 | Avg Reward (50): 292.1 | Avg Loss (500): 0.1209 | Epsilon: 0.050
# Episode 1100/2000 | Avg Reward (50): 309.8 | Avg Loss (500): 1.0377 | Epsilon: 0.050
# Episode 1150/2000 | Avg Reward (50): 347.9 | Avg Loss (500): 1.9774 | Epsilon: 0.050
# Episode 1200/2000 | Avg Reward (50): 451.2 | Avg Loss (500): 8.1549 | Epsilon: 0.050
# Episode 1250/2000 | Avg Reward (50): 497.5 | Avg Loss (500): 18.1038 | Epsilon: 0.050
# Episode 1300/2000 | Avg Reward (50): 500.0 | Avg Loss (500): 17.2319 | Epsilon: 0.050
# Episode 1350/2000 | Avg Reward (50): 500.0 | Avg Loss (500): 19.6811 | Epsilon: 0.050
# Episode 1400/2000 | Avg Reward (50): 500.0 | Avg Loss (500): 18.3990 | Epsilon: 0.050
# Episode 1450/2000 | Avg Reward (50): 500.0 | Avg Loss (500): 17.8436 | Epsilon: 0.050
# Episode 1500/2000 | Avg Reward (50): 500.0 | Avg Loss (500): 18.0611 | Epsilon: 0.050
# Episode 1550/2000 | Avg Reward (50): 500.0 | Avg Loss (500): 19.8111 | Epsilon: 0.050
# Episode 1600/2000 | Avg Reward (50): 500.0 | Avg Loss (500): 20.0822 | Epsilon: 0.050
# Episode 1650/2000 | Avg Reward (50): 500.0 | Avg Loss (500): 17.9397 | Epsilon: 0.050
# Episode 1700/2000 | Avg Reward (50): 498.5 | Avg Loss (500): 18.3814 | Epsilon: 0.050
# Episode 1750/2000 | Avg Reward (50): 500.0 | Avg Loss (500): 18.7107 | Epsilon: 0.050
# Episode 1800/2000 | Avg Reward (50): 500.0 | Avg Loss (500): 19.1360 | Epsilon: 0.050
# Episode 1850/2000 | Avg Reward (50): 500.0 | Avg Loss (500): 20.5698 | Epsilon: 0.050
# Episode 1900/2000 | Avg Reward (50): 500.0 | Avg Loss (500): 16.1915 | Epsilon: 0.050
# Episode 1950/2000 | Avg Reward (50): 500.0 | Avg Loss (500): 16.9357 | Epsilon: 0.050
# Episode 2000/2000 | Avg Reward (50): 500.0 | Avg Loss (500): 20.3886 | Epsilon: 0.050
# Episode 50/2000 | Avg Reward (50): 21.6 | Avg Loss (500): 1.2322 | Epsilon: 0.979
# Episode 100/2000 | Avg Reward (50): 23.4 | Avg Loss (500): 1.1980 | Epsilon: 0.957
# Episode 150/2000 | Avg Reward (50): 23.4 | Avg Loss (500): 2.5446 | Epsilon: 0.935
# Episode 200/2000 | Avg Reward (50): 22.9 | Avg Loss (500): 4.8604 | Epsilon: 0.913
# Episode 250/2000 | Avg Reward (50): 20.1 | Avg Loss (500): 7.1194 | Epsilon: 0.894
# Episode 300/2000 | Avg Reward (50): 20.9 | Avg Loss (500): 9.6910 | Epsilon: 0.874
# Episode 350/2000 | Avg Reward (50): 27.5 | Avg Loss (500): 12.4000 | Epsilon: 0.848
# Episode 400/2000 | Avg Reward (50): 29.7 | Avg Loss (500): 13.5812 | Epsilon: 0.820
# Episode 450/2000 | Avg Reward (50): 36.8 | Avg Loss (500): 15.1040 | Epsilon: 0.785
# Episode 500/2000 | Avg Reward (50): 32.1 | Avg Loss (500): 20.6985 | Epsilon: 0.755
# Episode 550/2000 | Avg Reward (50): 34.3 | Avg Loss (500): 28.1616 | Epsilon: 0.722
# Episode 600/2000 | Avg Reward (50): 38.8 | Avg Loss (500): 37.2685 | Epsilon: 0.685
# Episode 650/2000 | Avg Reward (50): 44.4 | Avg Loss (500): 45.0184 | Epsilon: 0.643
# Episode 700/2000 | Avg Reward (50): 48.0 | Avg Loss (500): 52.1877 | Epsilon: 0.597
# Episode 750/2000 | Avg Reward (50): 89.1 | Avg Loss (500): 55.4858 | Epsilon: 0.513
# Episode 800/2000 | Avg Reward (50): 182.4 | Avg Loss (500): 44.6553 | Epsilon: 0.339
# Episode 850/2000 | Avg Reward (50): 227.2 | Avg Loss (500): 3.6716 | Epsilon: 0.124
# Episode 900/2000 | Avg Reward (50): 266.5 | Avg Loss (500): 1.2071 | Epsilon: 0.050
# Episode 950/2000 | Avg Reward (50): 209.5 | Avg Loss (500): 0.5695 | Epsilon: 0.050
# Episode 1000/2000 | Avg Reward (50): 244.5 | Avg Loss (500): 0.0784 | Epsilon: 0.050
# Episode 1050/2000 | Avg Reward (50): 430.0 | Avg Loss (500): 9.9326 | Epsilon: 0.050
# Episode 1100/2000 | Avg Reward (50): 485.1 | Avg Loss (500): 11.6654 | Epsilon: 0.050
# Episode 1150/2000 | Avg Reward (50): 495.9 | Avg Loss (500): 17.3167 | Epsilon: 0.050
# Episode 1200/2000 | Avg Reward (50): 500.0 | Avg Loss (500): 21
| Epsilon: 0.050
# Episode 1700/2000 | Avg Reward (50): 496.9 | Avg Loss (500): 10.8136 | Epsilon: 0.050
# Episode 1750/2000 | Avg Reward (50): 500.0 | Avg Loss (500): 10.2645 | Epsilon: 0.050
# Episode 1800/2000 | Avg Reward (50): 500.0 | Avg Loss (500): 14.6562 | Epsilon: 0.050
# Episode 1850/2000 | Avg Reward (50): 500.0 | Avg Loss (500): 16.3235 | Epsilon: 0.050
# Episode 1900/2000 | Avg Reward (50): 499.8 | Avg Loss (500): 16.0216 | Epsilon: 0.050
# Episode 1950/2000 | Avg Reward (50): 468.7 | Avg Loss (500): 4.1095 | Epsilon: 0.050
# Episode 2000/2000 | Avg Reward (50): 499.6 | Avg Loss (500): 13.9027 | Epsilon: 0.050
#
# Training with target_network_frequency=1000...
# Episode 50/2000 | Avg Reward (50): 22.7 | Avg Loss (500): 0.9957 | Epsilon: 0.978
# Episode 100/2000 | Avg Reward (50): 20.2 | Avg Loss (500): 0.4655 | Epsilon: 0.959
# Episode 150/2000 | Avg Reward (50): 17.6 | Avg Loss (500): 0.3491 | Epsilon: 0.943
# Episode 200/2000 | Avg Reward (50): 21.6 | Avg Loss (500): 0.3718 | Epsilon: 0.922
# Episode 250/2000 | Avg Reward (50): 18.7 | Avg Loss (500): 0.3891 | Epsilon: 0.904
# Episode 300/2000 | Avg Reward (50): 20.1 | Avg Loss (500): 0.4205 | Epsilon: 0.885
# Episode 350/2000 | Avg Reward (50): 25.2 | Avg Loss (500): 0.4794 | Epsilon: 0.861
# Episode 400/2000 | Avg Reward (50): 28.1 | Avg Loss (500): 0.6124 | Epsilon: 0.835
# Episode 450/2000 | Avg Reward (50): 34.8 | Avg Loss (500): 0.8047 | Epsilon: 0.802
# Episode 500/2000 | Avg Reward (50): 33.1 | Avg Loss (500): 1.0049 | Epsilon: 0.770
# Episode 550/2000 | Avg Reward (50): 41.0 | Avg Loss (500): 1.2582 | Epsilon: 0.731
# Episode 600/2000 | Avg Reward (50): 55.7 | Avg Loss (500): 1.6518 | Epsilon: 0.678
# Episode 650/2000 | Avg Reward (50): 78.8 | Avg Loss (500): 2.0523 | Epsilon: 0.603
# Episode 700/2000 | Avg Reward (50): 87.7 | Avg Loss (500): 2.4561 | Epsilon: 0.520
# Episode 750/2000 | Avg Reward (50): 159.2 | Avg Loss (500): 2.6517 | Epsilon: 0.369
# Episode 800/2000 | Avg Reward (50): 229.0 | Avg Loss (500): 2.0458 | Epsilon: 0.151
# Episode 850/2000 | Avg Reward (50): 231.1 | Avg Loss (500): 1.2133 | Epsilon: 0.050
# Episode 900/2000 | Avg Reward (50): 239.4 | Avg Loss (500): 0.4143 | Epsilon: 0.050
# Episode 950/2000 | Avg Reward (50): 228.4 | Avg Loss (500): 0.0860 | Epsilon: 0.050
# Episode 1000/2000 | Avg Reward (50): 213.7 | Avg Loss (500): 0.0192 | Epsilon: 0.050
# Episode 1050/2000 | Avg Reward (50): 211.5 | Avg Loss (500): 0.0288 | Epsilon: 0.050
# Episode 1100/2000 | Avg Reward (50): 223.3 | Avg Loss (500): 0.0352 | Epsilon: 0.050
# Episode 1150/2000 | Avg Reward (50): 294.3 | Avg Loss (500): 2.4375 | Epsilon: 0.050
# Episode 1200/2000 | Avg Reward (50): 288.8 | Avg Loss (500): 2.1161 | Epsilon: 0.050
# Episode 1250/2000 | Avg Reward (50): 265.9 | Avg Loss (500): 1.5084 | Epsilon: 0.050
# Episode 1300/2000 | Avg Reward (50): 244.3 | Avg Loss (500): 0.2168 | Epsilon: 0.050
# Episode 1350/2000 | Avg Reward (50): 259.1 | Avg Loss (500): 1.5226 | Epsilon: 0.050
# Episode 1400/2000 | Avg Reward (50): 282.5 | Avg Loss (500): 3.6562 | Epsilon: 0.050
# Episode 1450/2000 | Avg Reward (50): 347.0 | Avg Loss (500): 0.4292 | Epsilon: 0.050
# Episode 1500/2000 | Avg Reward (50): 270.3 | Avg Loss (500): 0.5017 | Epsilon: 0.050
# Episode 1550/2000 | Avg Reward (50): 242.3 | Avg Loss (500): 0.2432 | Epsilon: 0.050
# Episode 1600/2000 | Avg Reward (50): 285.1 | Avg Loss (500): 0.0265 | Epsilon: 0.050
# Episode 1650/2000 | Avg Reward (50): 454.6 | Avg Loss (500): 9.9887 | Epsilon: 0.050
# Episode 1700/2000 | Avg Reward (50): 494.7 | Avg Loss (500): 12.3247 | Epsilon: 0.050
# Episode 1750/2000 | Avg Reward (50): 498.5 | Avg Loss (500): 14.4207 | Epsilon: 0.050
# Episode 1800/2000 | Avg Reward (50): 490.6 | Avg Loss (500): 11.9438 | Epsilon: 0.050
# Episode 1850/2000 | Avg Reward (50): 476.3 | Avg Loss (500): 4.3098 | Epsilon: 0.050
# Episode 1900/2000 | Avg Reward (50): 471.0 | Avg Loss (500): 10.6722 | Epsilon: 0.050
# Episode 1950/2000 | Avg Reward (50): 486.9 | Avg Loss (500): 17.2023 | Epsilon: 0.050
# Episode 2000/2000 | Avg Reward (50): 500.0 | Avg Loss (500): 19.3262 | Epsilon: 0.050
# Episode 50/2000 | Avg Reward (50): 21.6 | Avg Loss (500): 1.2322 | Epsilon: 0.979
# Episode 100/2000 | Avg Reward (50): 22.5 | Avg Loss (500): 0.5319 | Epsilon: 0.958
# Episode 150/2000 | Avg Reward (50): 20.4 | Avg Loss (500): 0.4204 | Epsilon: 0.939
# Episode 200/2000 | Avg Reward (50): 22.7 | Avg Loss (500): 0.4220 | Epsilon: 0.917
# Episode 250/2000 | Avg Reward (50): 21.7 | Avg Loss (500): 0.4558 | Epsilon: 0.897
# Episode 300/2000 | Avg Reward (50): 25.2 | Avg Loss (500): 0.4621 | Epsilon: 0.873
# Episode 350/2000 | Avg Reward (50): 25.8 | Avg Loss (500): 0.5988 | Epsilon: 0.848
# Episode 400/2000 | Avg Reward (50): 33.9 | Avg Loss (500): 0.8048 | Epsilon: 0.816
# Episode 450/2000 | Avg Reward (50): 37.8 | Avg Loss (500): 1.0594 | Epsilon: 0.780
# Episode 500/2000 | Avg Reward (50): 41.9 | Avg Loss (500): 1.4089 | Epsilon: 0.740
# Episode 550/2000 | Avg Reward (50): 45.0 | Avg Loss (500): 1.7604 | Epsilon: 0.697
# Episode 600/2000 | Avg Reward (50): 59.1 | Avg Loss (500): 2.0168 | Epsilon: 0.641
# Episode 650/2000 | Avg Reward (50): 89.1 | Avg Loss (500): 2.4611 | Epsilon: 0.557
# Episode 700/2000 | Avg Reward (50): 156.9 | Avg Loss (500): 2.5692 | Epsilon: 0.408
# Episode 750/2000 | Avg Reward (50): 282.1 | Avg Loss (500): 1.5997 | Epsilon: 0.140
# Episode 800/2000 | Avg Reward (50): 283.9 | Avg Loss (500): 1.0142 | Epsilon: 0.050
# Episode 850/2000 | Avg Reward (50): 204.4 | Avg Loss (500): 0.3897 | Epsilon: 0.050
# Episode 900/2000 | Avg Reward (50): 183.5 | Avg Loss (500): 0.1368 | Epsilon: 0.050
# Episode 950/2000 | Avg Reward (50): 184.4 | Avg Loss (500): 0.0869 | Epsilon: 0.050
# Episode 1000/2000 | Avg Reward (50): 177.6 | Avg Loss (500): 0.0810 | Epsilon: 0.050
# Episode 1050/2000 | Avg Reward (50): 171.7 | Avg Loss (500): 0.0291 | Epsilon: 0.050
# Episode 1100/2000 | Avg Reward (50): 166.3 | Avg Loss (500): 0.8122 | Epsilon: 0.050
# Episode 1150/2000 | Avg Reward (50): 198.1 | Avg Loss (500): 0.1367 | Epsilon: 0.050
# Episode 1200/2000 | Avg Reward (50): 237.6 | Avg Loss (500): 0.0146 | Epsilon: 0.050
# Episode 1250/2000 | Avg Reward (50): 316.3 | Avg Loss (500): 3.4840 | Epsilon: 0.050
# Episode 1300/2000 | Avg Reward (50): 329.2 | Avg Loss (500): 8.6298 | Epsilon: 0.050
# Episode 1350/2000 | Avg Reward (50): 317.8 | Avg Loss (500): 1.1478 | Epsilon: 0.050
# Episode 1400/2000 | Avg Reward (50): 318.2 | Avg Loss (500): 11.4552 | Epsilon: 0.050
# Episode 1450/2000 | Avg Reward (50): 370.8 | Avg Loss (500): 3.8313 | Epsilon: 0.050
# Episode 1500/2000 | Avg Reward (50): 436.1 | Avg Loss (500): 6.9832 | Epsilon: 0.050
# Episode 1550/2000 | Avg Reward (50): 491.7 | Avg Loss (500): 12.3890 | Epsilon: 0.050
# Episode 1600/2000 | Avg Reward (50): 499.0 | Avg Loss (500): 10.4972 | Epsilon: 0.050
# Episode 1650/2000 | Avg Reward (50): 500.0 | Avg Loss (500): 12.9208 | Epsilon: 0.050
# Episode 1700/2000 | Avg Reward (50): 500.0 | Avg Loss (500): 12.2006 | Epsilon: 0.050
# Episode 1750/2000 | Avg Reward (50): 499.5 | Avg Loss (500): 11.6180 | Epsilon: 0.050
# Episode 1800/2000 | Avg Reward (50): 498.2 | Avg Loss (500): 11.3030 | Epsilon: 0.050
# Episode 1850/2000 | Avg Reward (50): 498.5 | Avg Loss (500): 8.9470 | Epsilon: 0.050
# Episode 1900/2000 | Avg Reward (50): 500.0 | Avg Loss (500): 11.1406 | Epsilon: 0.050
# Episode 1950/2000 | Avg Reward (50): 500.0 | Avg Loss (500): 13.6063 | Epsilon: 0.050
# Episode 2000/2000 | Avg Reward (50): 464.2 | Avg Loss (500): 7.5812 | Epsilon: 0.050
# Episode 50/2000 | Avg Reward (50): 24.8 | Avg Loss (500): 1.0324 | Epsilon: 0.976
# Episode 100/2000 | Avg Reward (50): 21.9 | Avg Loss (500): 0.5260 | Epsilon: 0.956
# Episode 150/2000 | Avg Reward (50): 21.0 | Avg Loss (500): 0.4380 | Epsilon: 0.936
# Episode 200/2000 | Avg Reward (50): 19.1 | Avg Loss (500): 0.4460 | Epsilon: 0.918
# Episode 250/2000 | Avg Reward (50): 18.9 | Avg Loss (500): 0.4839 | Epsilon: 0.900
# Episode 300/2000 | Avg Reward (50): 21.7 | Avg Loss (500): 0.4917 | Epsilon: 0.879
# Episode 350/2000 | Avg Reward (50): 26.7 | Avg Loss (500): 0.5970 | Epsilon: 0.854
# Episode 400/2000 | Avg Reward (50): 27.9 | Avg Loss (500): 0.7592 | Epsilon: 0.827
# Episode 450/2000 | Avg Reward (50): 28.6 | Avg Loss (500): 0.9547 | Epsilon: 0.800
# Episode 500/2000 | Avg Reward (50): 29.5 | Avg Loss (500): 1.2223 | Epsilon: 0.772
# Episode 550/2000 | Avg Reward (50): 36.3 | Avg Loss (500): 1.5673 | Epsilon: 0.737
# Episode 600/2000 | Avg Reward (50): 46.4 | Avg Loss (500): 2.0164 | Epsilon: 0.693
# Episode 650/2000 | Avg Reward (50): 51.2 | Avg Loss (500): 2.3906 | Epsilon: 0.645
# Episode 700/2000 | Avg Reward (50): 82.5 | Avg Loss (500): 2.4052 | Epsilon: 0.566
# Episode 750/2000 | Avg Reward (50): 135.7 | Avg Loss (500): 2.3210 | Epsilon: 0.437
# Episode 800/2000 | Avg Reward (50): 285.6 | Avg Loss (500): 1.2630 | Epsilon: 0.166
# Episode 850/2000 | Avg Reward (50): 283.9 | Avg Loss (500): 0.8229 | Epsilon: 0.050
# Episode 900/2000 | Avg Reward (50): 250.4 | Avg Loss (500): 0.1475 | Epsilon: 0.050
# Episode 950/2000 | Avg Reward (50): 250.8 | Avg Loss (500): 0.0962 | Epsilon: 0.050
# Episode 1000/2000 | Avg Reward (50): 251.5 | Avg Loss (500): 0.0195 | Epsilon: 0.050
# Episode 1050/2000 | Avg Reward (50): 261.1 | Avg Loss (500): 0.0202 | Epsilon: 0.050
# Episode 1100/2000 | Avg Reward (50): 278.4 | Avg Loss (500): 0.0185 | Epsilon: 0.050
# Episode 1150/2000 | Avg Reward (50): 325.1 | Avg Loss (500): 0.6828 | Epsilon: 0.050
# Episode 1200/2000 | Avg Reward (50): 332.5 | Avg Loss (500): 0.4475 | Epsilon: 0.050
# Episode 1250/2000 | Avg Reward (50): 361.8 | Avg Loss (500): 0.0090 | Epsilon: 0.050
# Episode 1300/2000 | Avg Reward (50): 377.3 | Avg Loss (500): 0.0077 | Epsilon: 0.050
# Episode 1350/2000 | Avg Reward (50): 445.4 | Avg Loss (500): 0.7613 | Epsilon: 0.050
# Episode 1400/2000 | Avg Reward (50): 460.3 | Avg Loss (500): 7.8935 | Epsilon: 0.050
# Episode 1450/2000 | Avg Reward (50): 467.6 | Avg Loss (500): 8.9894 | Epsilon: 0.050
# Episode 1500/2000 | Avg Reward (50): 477.1 | Avg Loss (500): 8.3144 | Epsilon: 0.050
# Episode 1550/2000 | Avg Reward (50): 500.0 | Avg Loss (500): 3.8121 | Epsilon: 0.050
# Episode 1600/2000 | Avg Reward (50): 468.0 | Avg Loss (500): 8.0064 | Epsilon: 0.050
# Episode 1650/2000 | Avg Reward (50): 392.3 | Avg Loss (500): 5.5286 | Epsilon: 0.050
# Episode 1700/2000 | Avg Reward (50): 460.1 | Avg Loss (500): 11.5961 | Epsilon: 0.050
# Episode 1750/2000 | Avg Reward (50): 456.8 | Avg Loss (500): 16.7270 | Epsilon: 0.050
# Episode 1800/2000 | Avg Reward (50): 495.3 | Avg Loss (500): 14.3487 | Epsilon: 0.050
# Episode 1850/2000 | Avg Reward (50): 497.9 | Avg Loss (500): 19.9557 | Epsilon: 0.050
# Episode 1900/2000 | Avg Reward (50): 500.0 | Avg Loss (500): 17.5417 | Epsilon: 0.050
# Episode 1950/2000 | Avg Reward (50): 497.1 | Avg Loss (500): 12.2160 | Epsilon: 0.050
# Episode 2000/2000 | Avg Reward (50): 500.0 | Avg Loss (500): 21.4972 | Epsilon: 0.050
#
# ============================================================
# Final Performance (last 100 episodes):
# ============================================================
# Update Freq 1: 279.1 ± 163.1
# Update Freq 10: 279.1 ± 163.1
# Update Freq 100: 493.3 ± 6.7
# Update Freq 1000: 491.4 ± 6.9
# Plot saved: c:\Users\Jensw\Desktop\tdde78lab\labs\lab1_value_based\experiments\plots\target_update_frequency_ablation_on_cartpole-v1.png

# %% [markdown]
# ## B.5 — Ablation: Epsilon Decay Schedule
#
# Compare different exploration strategies.
#
# Test epsilon decay lengths: **1,000**, **5,000**, **10,000**, **50,000** steps

# %%
epsilon_decays = [1000, 5000, 10000, 50000]

print("Running epsilon decay ablation on CartPole-v1...")
print("=" * 60)

all_results_epsilon_decay = {}

for epsilon_decay in epsilon_decays:
    print(f"\nTraining with epsilon_decay={epsilon_decay}...")
    results = [
        train_dqn(
            env_name="CartPole-v1",
            num_episodes=2000,
            seed=s,
            epsilon_decay=epsilon_decay,
            use_double_dqn=False,
            use_dueling=False
        )
        for s in seeds
    ]
    all_results_epsilon_decay[f"Epsilon Decay {epsilon_decay}"] = results

print("\n" + "=" * 60)
print("Final Performance (last 100 episodes):")
print("=" * 60)

for name, results_list in all_results_epsilon_decay.items():
    final_rewards = [np.mean(r['episode_rewards'][-100:]) for r in results_list]
    print(f"{name}: {np.mean(final_rewards):.1f} ± {np.std(final_rewards):.1f}")

plot_comparison(all_results_epsilon_decay, title="Epsilon Decay Ablation on CartPole-v1")
# Out:
# Running epsilon decay ablation on CartPole-v1...
# ============================================================
#
# Training with epsilon_decay=1000...
# Episode 50/2000 | Avg Reward (50): 14.7 | Avg Loss (500): 0.0000 | Epsilon: 0.300
# Episode 100/2000 | Avg Reward (50): 10.2 | Avg Loss (500): 0.7521 | Epsilon: 0.050
# Episode 150/2000 | Avg Reward (50): 9.7 | Avg Loss (500): 0.6365 | Epsilon: 0.050
# Episode 200/2000 | Avg Reward (50): 9.7 | Avg Loss (500): 0.6939 | Epsilon: 0.050
# Episode 250/2000 | Avg Reward (50): 9.8 | Avg Loss (500): 0.7753 | Epsilon: 0.050
# Episode 300/2000 | Avg Reward (50): 9.8 | Avg Loss (500): 0.8288 | Epsilon: 0.050
# Episode 350/2000 | Avg Reward (50): 9.6 | Avg Loss (500): 0.8571 | Epsilon: 0.050
# Episode 400/2000 | Avg Reward (50): 9.7 | Avg Loss (500): 0.8586 | Epsilon: 0.050
# Episode 450/2000 | Avg Reward (50): 9.7 | Avg Loss (500): 0.8263 | Epsilon: 0.050
# Episode 500/2000 | Avg Reward (50): 9.6 | Avg Loss (500): 0.7847 | Epsilon: 0.050
# Episode 550/2000 | Avg Reward (50): 10.2 | Avg Loss (500): 0.7987 | Epsilon: 0.050
# Episode 600/2000 | Avg Reward (50): 11.6 | Avg Loss (500): 0.8590 | Epsilon: 0.050
# Episode 650/2000 | Avg Reward (50): 9.6 | Avg Loss (500): 0.9756 | Epsilon: 0.050
# Episode 700/2000 | Avg Reward (50): 9.4 | Avg Loss (500): 1.0819 | Epsilon: 0.050
# Episode 750/2000 | Avg Reward (50): 9.8 | Avg Loss (500): 1.1307 | Epsilon: 0.050
# Episode 800/2000 | Avg Reward (50): 16.3 | Avg Loss (500): 1.1736 | Epsilon: 0.050
# Episode 850/2000 | Avg Reward (50): 57.9 | Avg Loss (500): 1.5505 | Epsilon: 0.050
# Episode 900/2000 | Avg Reward (50): 51.3 | Avg Loss (500): 2.4823 | Epsilon: 0.050
# Episode 950/2000 | Avg Reward (50): 58.6 | Avg Loss (500): 4.1989 | Epsilon: 0.050
# Episode 1000/2000 | Avg Reward (50): 112.2 | Avg Loss (500): 2.6194 | Epsilon: 0.050
# Episode 1050/2000 | Avg Reward (50): 235.7 | Avg Loss (500): 0.3664 | Epsilon: 0.050
# Episode 1100/2000 | Avg Reward (50): 192.6 | Avg Loss (500): 0.7646 | Epsilon: 0.050
# Episode 1150/2000 | Avg Reward (50): 198.6 | Avg Loss (500): 0.2783 | Epsilon: 0.050
# Episode 1200/2000 | Avg Reward (50): 334.3 | Avg Loss (500): 1.8817 | Epsilon: 0.050
# Episode 1250/2000 | Avg Reward (50): 368.1 | Avg Loss (500): 2.9586 | Epsilon: 0.050
# Episode 1300/2000 | Avg Reward (50): 458.4 | Avg Loss (500): 6.8708 | Epsilon: 0.050
# Episode 1350/2000 | Avg Reward (50): 498.6 | Avg Loss (500): 7.7361 | Epsilon: 0.050
# Episode 1400/2000 | Avg Reward (50): 499.2 | Avg Loss (500): 9.0457 | Epsilon: 0.050
# Episode 1450/2000 | Avg Reward (50): 500.0 | Avg Loss (500): 14.8196 | Epsilon: 0.050
# Episode 1500/2000 | Avg Reward (50): 500.0 | Avg Loss (500): 12.0480 | Epsilon: 0.050
# Episode 1550/2000 | Avg Reward (50): 500.0 | Avg Loss (500): 13.0601 | Epsilon: 0.050
# Episode 1600/2000 | Avg Reward (50): 500.0 | Avg Loss (500): 15.5108 | Epsilon: 0.050
# Episode 1650/2000 | Avg Reward (50): 500.0 | Avg Loss (500): 12.0478 | Epsilon: 0.050
# Episode 1700/2000 | Avg Reward (50): 500.0 | Avg Loss (500): 13.3999 | Epsilon: 0.050
# Episode 1750/2000 | Avg Reward (50): 500.0 | Avg Loss (500): 15.2379 | Epsilon: 0.050
# Episode 1800/2000 | Avg Reward (50): 500.0 | Avg Loss (500): 15.7293 | Epsilon: 0.050
# Episode 1850/2000 | Avg Reward (50): 500.0 | Avg Loss (500): 12.1192 | Epsilon: 0.050
# Episode 1900/2000 | Avg Reward (50): 500.0 | Avg Loss (500): 15.4179 | Epsilon: 0.050
# Episode 1950/2000 | Avg Reward (50): 500.0 | Avg Loss (500): 18.0843 | Epsilon: 0.050
# Episode 2000/2000 | Avg Reward (50): 500.0 | Avg Loss (500): 18.0001 | Epsilon: 0.050
# Episode 50/2000 | Avg Reward (50): 16.0 | Avg Loss (500): 0.0000 | Epsilon: 0.239
# Episode 100/2000 | Avg Reward (50): 10.0 | Avg Loss (500): 0.8107 | Epsilon: 0.050
# Episode 150/2000 | Avg Reward (50): 9.6 | Avg Loss (500): 0.7329 | Epsilon: 0.050
# Episode 200/2000 | Avg Reward (50): 9.8 | Avg Loss (500): 0.7799 | Epsilon: 0.050
# Episode 250/2000 | Avg Reward (50): 9.6 | Avg Loss (500): 0.8346 | Epsilon: 0.050
# Episode 300/2000 | Avg Reward (50): 10.0 | Avg Loss (500): 0.9087 | Epsilon: 0.050
# Episode 350/2000 | Avg Reward (50): 9.8 | Avg Loss (500): 0.9450 | Epsilon: 0.050
# Episode 400/2000 | Avg Reward (50): 9.6 | Avg Loss (500): 0.9557 | Epsilon: 0.050
# Episode 450/2000 | Avg Reward (50): 9.4 | Avg Loss (500): 0.9490 | Epsilon: 0.050
# Episode 500/2000 | Avg Reward (50): 10.0 | Avg Loss (500): 0.9160 | Epsilon: 0.050
# Episode 550/2000 | Avg Reward (50): 10.2 | Avg Loss (500): 0.9388 | Epsilon: 0.050
# Episode 600/2000 | Avg Reward (50): 9.7 | Avg Loss (500): 1.0717 | Epsilon: 0.050
# Episode 650/2000 | Avg Reward (50): 9.6 | Avg Loss (500): 1.3074 | Epsilon: 0.050
# Episode 700/2000 | Avg Reward (50): 9.5 | Avg Loss (500): 1.4645 | Epsilon: 0.050
# Episode 750/2000 | Avg Reward (50): 9.7 | Avg Loss (500): 1.5487 | Epsilon: 0.050
# Episode 800/2000 | Avg Reward (50): 24.2 | Avg Loss (500): 1.6712 | Epsilon: 0.050
# Episode 850/2000 | Avg Reward (50): 57.0 | Avg Loss (500): 2.2708 | Epsilon: 0.050
# Episode 900/2000 | Avg Reward (50): 45.8 | Avg Loss (500): 3.3937 | Epsilon: 0.050
# Episode 950/2000 | Avg Reward (50): 67.1 | Avg Loss (500): 5.2428 | Epsilon: 0.050
# Episode 1000/2000 | Avg Reward (50): 197.7 | Avg Loss (500): 1.9297 | Epsilon: 0.050
# Episode 1050/2000 | Avg Reward (50): 151.2 | Avg Loss (500): 0.3848 | Epsilon: 0.050
# Episode 1100/2000 | Avg Reward (50): 137.8 | Avg Loss (500): 0.1904 | Epsilon: 0.050
# Episode 1150/2000 | Avg Reward (50): 180.3 | Avg Loss (500): 0.9309 | Epsilon: 0.050
# Episode 1200/2000 | Avg Reward (50): 278.8 | Avg Loss (500): 2.0911 | Epsilon: 0.050
# Episode 1250/2000 | Avg Reward (50): 444.5 | Avg Loss (500): 9.2336 | Epsilon: 0.050
# Episode 1300/2000 | Avg Reward (50): 496.7 | Avg Loss (500): 10.2564 | Epsilon: 0.050
# Episode 1350/2000 | Avg Reward (50): 499.6 | Avg Loss (500): 11.1188 | Epsilon: 0.050
# Episode 1400/2000 | Avg Reward (50): 499.9 | Avg Loss (500): 11.5981 | Epsilon: 0.050
# Episode 1450/2000 | Avg Reward (50): 498.0 | Avg Loss (500): 16.0486 | Epsilon: 0.050
# Episode 1500/2000 | Avg Reward (50): 495.1 | Avg Loss (500): 21.3190 | Epsilon: 0.050
# Episode 1550/2000 | Avg Reward (50): 500.0 | Avg Loss (500): 15.6146 | Epsilon: 0.050
# Episode 1600/2000 | Avg Reward (50): 500.0 | Avg Loss (500): 18.5311 | Epsilon: 0.050
# Episode 1650/2000 | Avg Reward (50): 500.0 | Avg Loss (500): 21.1124 | Epsilon: 0.050
# Episode 1700/2000 | Avg Reward (50):
| Epsilon: 0.050
# Episode 1050/2000 | Avg Reward (50): 499.1 | Avg Loss (500): 13.6250 | Epsilon: 0.050
# Episode 1100/2000 | Avg Reward (50): 500.0 | Avg Loss (500): 17.2291 | Epsilon: 0.050
# Episode 1150/2000 | Avg Reward (50): 500.0 | Avg Loss (500): 13.8795 | Epsilon: 0.050
# Episode 1200/2000 | Avg Reward (50): 499.2 | Avg Loss (500): 10.0357 | Epsilon: 0.050
# Episode 1250/2000 | Avg Reward (50): 497.5 | Avg Loss (500): 12.1181 | Epsilon: 0.050
# Episode 1300/2000 | Avg Reward (50): 496.9 | Avg Loss (500): 13.2152 | Epsilon: 0.050
# Episode 1350/2000 | Avg Reward (50): 500.0 | Avg Loss (500): 16.2305 | Epsilon: 0.050
# Episode 1400/2000 | Avg Reward (50): 500.0 | Avg Loss (500): 21.6152 | Epsilon: 0.050
# Episode 1450/2000 | Avg Reward (50): 500.0 | Avg Loss (500): 17.7511 | Epsilon: 0.050
# Episode 1500/2000 | Avg Reward (50): 500.0 | Avg Loss (500): 21.2164 | Epsilon: 0.050
# Episode 1550/2000 | Avg Reward (50): 498.0 | Avg Loss (500): 14.2288 | Epsilon: 0.050
# Episode 1600/2000 | Avg Reward (50): 500.0 | Avg Loss (500): 18.1248 | Epsilon: 0.050
# Episode 1650/2000 | Avg Reward (50): 500.0 | Avg Loss (500): 16.7550 | Epsilon: 0.050
# Episode 1700/2000 | Avg Reward (50): 499.7 | Avg Loss (500): 15.6286 | Epsilon: 0.050
# Episode 1750/2000 | Avg Reward (50): 499.2 | Avg Loss (500): 10.8030 | Epsilon: 0.050
# Episode 1800/2000 | Avg Reward (50): 500.0 | Avg Loss (500): 16.4221 | Epsilon: 0.050
# Episode 1850/2000 | Avg Reward (50): 500.0 | Avg Loss (500): 15.7113 | Epsilon: 0.050
# Episode 1900/2000 | Avg Reward (50): 497.3 | Avg Loss (500): 18.0673 | Epsilon: 0.050
# Episode 1950/2000 | Avg Reward (50): 499.7 | Avg Loss (500): 13.9060 | Epsilon: 0.050
# Episode 2000/2000 | Avg Reward (50): 498.2 | Avg Loss (500): 15.8373 | Epsilon: 0.050
# Episode 50/2000 | Avg Reward (50): 22.4 | Avg Loss (500): 1.1914 | Epsilon: 0.787
# Episode 100/2000 | Avg Reward (50): 19.8 | Avg Loss (500): 0.7511 | Epsilon: 0.598
# Episode 150/2000 | Avg Reward (50): 14.6 | Avg Loss (500): 0.7933 | Epsilon: 0.459
# Episode 200/2000 | Avg Reward (50): 12.2 | Avg Loss (500): 0.9059 | Epsilon: 0.344
# Episode 250/2000 | Avg Reward (50): 10.8 | Avg Loss (500): 0.9968 | Epsilon: 0.241
# Episode 300/2000 | Avg Reward (50): 11.8 | Avg Loss (500): 1.0668 | Epsilon: 0.129
# Episode 350/2000 | Avg Reward (50): 10.6 | Avg Loss (500): 1.1624 | Epsilon: 0.050
# Episode 400/2000 | Avg Reward (50): 10.7 | Avg Loss (500): 1.2804 | Epsilon: 0.050
# Episode 450/2000 | Avg Reward (50): 9.9 | Avg Loss (500): 1.3861 | Epsilon: 0.050
# Episode 500/2000 | Avg Reward (50): 11.3 | Avg Loss (500): 1.5702 | Epsilon: 0.050
# Episode 550/2000 | Avg Reward (50): 40.5 | Avg Loss (500): 2.2622 | Epsilon: 0.050
# Episode 600/2000 | Avg Reward (50): 54.2 | Avg Loss (500): 3.2036 | Epsilon: 0.050
# Episode 650/2000 | Avg Reward (50): 61.5 | Avg Loss (500): 4.9118 | Epsilon: 0.050
# Episode 700/2000 | Avg Reward (50): 110.7 | Avg Loss (500): 5.2724 | Epsilon: 0.050
# Episode 750/2000 | Avg Reward (50): 309.8 | Avg Loss (500): 0.6729 | Epsilon: 0.050
# Episode 800/2000 | Avg Reward (50): 304.1 | Avg Loss (500): 0.9049 | Epsilon: 0.050
# Episode 850/2000 | Avg Reward (50): 339.2 | Avg Loss (500): 1.2272 | Epsilon: 0.050
# Episode 900/2000 | Avg Reward (50): 441.9 | Avg Loss (500): 8.7371 | Epsilon: 0.050
# Episode 950/2000 | Avg Reward (50): 440.9 | Avg Loss (500): 3.9956 | Epsilon: 0.050
# Episode 1000/2000 | Avg Reward (50): 438.2 | Avg Loss (500): 11.0192 | Epsilon: 0.050
# Episode 1050/2000 | Avg Reward (50): 486.0 | Avg Loss (500): 15.9248 | Epsilon: 0.050
# Episode 1100/2000 | Avg Reward (50): 499.3 | Avg Loss (500): 16.0080 | Epsilon: 0.050
# Episode 1150/2000 | Avg Reward (50): 499.1 | Avg Loss (500): 16.2433 | Epsilon: 0.050
# Episode 1200/2000 | Avg Reward (50): 495.8 | Avg Loss (500): 18.7912 | Epsilon: 0.050
# Episode 1250/2000 | Avg Reward (50): 500.0 | Avg Loss (500): 17.1621 | Epsilon: 0.050
# Episode 1300/2000 | Avg Reward (50): 500.0 | Avg Loss (500): 18.1094 | Epsilon: 0.050
# Episode 1350/2000 | Avg Reward (50): 500.0 | Avg Loss (500): 17.6754 | Epsilon: 0.050
# Episode 1400/2000 | Avg Reward (50): 500.0 | Avg Loss (500): 18.0112 | Epsilon: 0.050
# Episode 1450/2000 | Avg Reward (50): 497.8 | Avg Loss (500): 16.6119 | Epsilon: 0.050
# Episode 1500/2000 | Avg Reward (50): 500.0 | Avg Loss (500): 17.7270 | Epsilon: 0.050
# Episode 1550/2000 | Avg Reward (50): 500.0 | Avg Loss (500): 18.3098 | Epsilon: 0.050
# Episode 1600/2000 | Avg Reward (50): 500.0 | Avg Loss (500): 19.1079 | Epsilon: 0.050
# Episode 1650/2000 | Avg Reward (50): 500.0 | Avg Loss (500): 17.2066 | Epsilon: 0.050
# Episode 1700/2000 | Avg Reward (50): 500.0 | Avg Loss (500): 20.4025 | Epsilon: 0.050
# Episode 1750/2000 | Avg Reward (50): 500.0 | Avg Loss (500): 19.4602 | Epsilon: 0.050
# Episode 1800/2000 | Avg Reward (50): 480.2 | Avg Loss (500): 17.2127 | Epsilon: 0.050
# Episode 1850/2000 | Avg Reward (50): 500.0 | Avg Loss (500): 21.0514 | Epsilon: 0.050
# Episode 1900/2000 | Avg Reward (50): 500.0 | Avg Loss (500): 21.0941 | Epsilon: 0.050
# Episode 1950/2000 | Avg Reward (50): 500.0 | Avg Loss (500): 16.6209 | Epsilon: 0.050
# Episode 2000/2000 | Avg Reward (50): 488.5 | Avg Loss (500): 20.3614 | Epsilon: 0.050
# Episode 50/2000 | Avg Reward (50): 22.4 | Avg Loss (500): 1.1026 | Epsilon: 0.788
# Episode 100/2000 | Avg Reward (50): 16.3 | Avg Loss (500): 0.7648 | Epsilon: 0.633
# Episode 150/2000 | Avg Reward (50): 15.3 | Avg Loss (500): 0.8184 | Epsilon: 0.487
# Episode 200/2000 | Avg Reward (50): 12.3 | Avg Loss (500): 0.9361 | Epsilon: 0.370
# Episode 250/2000 | Avg Reward (50): 11.1 | Avg Loss (500): 1.0555 | Epsilon: 0.264
# Episode 300/2000 | Avg Reward (50): 10.7 | Avg Loss (500): 1.1461 | Epsilon: 0.162
# Episode 350/2000 | Avg Reward (50): 10.0 | Avg Loss (500): 1.2724 | Epsilon: 0.067
# Episode 400/2000 | Avg Reward (50): 9.6 | Avg Loss (500): 1.4126 | Epsilon: 0.050
# Episode 450/2000 | Avg Reward (50): 9.5 | Avg Loss (500): 1.5076 | Epsilon: 0.050
# Episode 500/2000 | Avg Reward (50): 9.6 | Avg Loss (500): 1.5902 | Epsilon: 0.050
# Episode 550/2000 | Avg Reward (50): 20.3 | Avg Loss (500): 1.8046 | Epsilon: 0.050
# Episode 600/2000 | Avg Reward (50): 57.0 | Avg Loss (500): 2.2263 | Epsilon: 0.050
# Episode 650/2000 | Avg Reward (50): 52.0 | Avg Loss (500): 3.3077 | Epsilon: 0.050
# Episode 700/2000 | Avg Reward (50): 52.3 | Avg Loss (500): 4.9400 | Epsilon: 0.050
# Episode 750/2000 | Avg Reward (50): 54.0 | Avg Loss (500): 6.5734 | Epsilon: 0.050
# Episode 800/2000 | Avg Reward (50): 54.9 | Avg Loss (500): 7.1150 | Epsilon: 0.050
# Episode 850/2000 | Avg Reward (50): 47.7 | Avg Loss (500): 5.9562 | Epsilon: 0.050
# Episode 900/2000 | Avg Reward (50): 56.9 | Avg Loss (500): 3.5728 | Epsilon: 0.050
# Episode 950/2000 | Avg Reward (50): 85.0 | Avg Loss (500): 0.8249 | Epsilon: 0.050
# Episode 1000/2000 | Avg Reward (50): 230.6 | Avg Loss (500): 1.1193 | Epsilon: 0.050
# Episode 1050/2000 | Avg Reward (50): 339.5 | Avg Loss (500): 0.9018 | Epsilon: 0.050
# Episode 1100/2000 | Avg Reward (50): 346.5 | Avg Loss (500): 1.5540 | Epsilon: 0.050
# Episode 1150/2000 | Avg Reward (50): 424.5 | Avg Loss (500): 4.5884 | Epsilon: 0.050
# Episode 1200/2000 | Avg Reward (50): 427.4 | Avg Loss (500): 7.3516 | Epsilon: 0.050
# Episode 1250/2000 | Avg Reward (50): 423.4 | Avg Loss (500): 7.8735 | Epsilon: 0.050
# Episode 1300/2000 | Avg Reward (50): 455.5 | Avg Loss (500): 6.5058 | Epsilon: 0.050
# Episode 1350/2000 | Avg Reward (50): 486.5 | Avg Loss (500): 11.9853 | Epsilon: 0.050
# Episode 1400/2000 | Avg Reward (50): 487.2 | Avg Loss (500): 12.3671 | Epsilon: 0.050
# Episode 1450/2000 | Avg Reward (50): 496.6 | Avg Loss (500): 15.3545 | Epsilon: 0.050
# Episode 1500/2000 | Avg Reward (50): 500.0 | Avg Loss (500): 14.7402 | Epsilon: 0.050
# Episode 1550/2000 | Avg Reward (50): 494.7 | Avg Loss (500): 13.9430 | Epsilon: 0.050
# Episode 1600/2000 | Avg Reward (50): 499.2 | Avg Loss (500): 18.0243 | Epsilon: 0.050
# Episode 1650/2000 | Avg Reward (50): 500.0 | Avg Loss (500): 18.9069 | Epsilon: 0.050
# Episode 1700/2000 | Avg Reward (50): 500.0 | Avg Loss (500): 20.1996 | Epsilon: 0.050
# Episode 1750/2000 | Avg Reward (50): 500.0 | Avg Loss (500): 12.6991 | Epsilon: 0.050
# Episode 1800/2000 | Avg Reward (50): 500.0 | Avg Loss (500): 17.7303 | Epsilon: 0.050
# Episode 1850/2000 | Avg Reward (50): 500.0 | Avg Loss (500): 20.0610 | Epsilon: 0.050
# Episode 1900/2000 | Avg Reward (50): 493.3 | Avg Loss (500): 16.5639 | Epsilon: 0.050
# Episode 1950/2000 | Avg Reward (50): 500.0 | Avg Loss (500): 20.3980 | Epsilon: 0.050
# Episode 2000/2000 | Avg Reward (50): 500.0 | Avg Loss (500): 17.0618 | Epsilon: 0.050
#
# Training with epsilon_decay=10000...
# Episode 50/2000 | Avg Reward (50): 23.8 | Avg Loss (500): 0.9381 | Epsilon: 0.887
# Episode 100/2000 | Avg Reward (50): 21.7 | Avg Loss (500): 0.6257 | Epsilon: 0.784
# Episode 150/2000 | Avg Reward (50): 17.7 | Avg Loss (500): 0.6920 | Epsilon: 0.700
# Episode 200/2000 | Avg Reward (50): 15.5 | Avg Loss (500): 0.7986 | Epsilon: 0.627
# Episode 250/2000 | Avg Reward (50): 14.8 | Avg Loss (500): 0.9280 | Epsilon: 0.556
# Episode 300/2000 | Avg Reward (50): 13.9 | Avg Loss (500): 1.0456 | Epsilon: 0.490
# Episode 350/2000 | Avg Reward (50): 13.6 | Avg Loss (500): 1.1754 | Epsilon: 0.425
# Episode 400/2000 | Avg Reward (50): 42.0 | Avg Loss (500): 1.6648 | Epsilon: 0.226
# Episode 450/2000 | Avg Reward (50): 45.2 | Avg Loss (500): 2.2216 | Epsilon: 0.050
# Episode 500/2000 | Avg Reward (50): 53.9 | Avg Loss (500): 2.9921 | Epsilon: 0.050
# Episode 550/2000 | Avg Reward (50): 155.9 | Avg Loss (500): 1.7391 | Epsilon: 0.050
# Episode 600/2000 | Avg Reward (50): 171.9 | Avg Loss (500): 2.9698 | Epsilon: 0.050
# Episode 650/2000 | Avg Reward (50): 204.9 | Avg Loss (500): 0.4939 | Epsilon: 0.050
# Episode 700/2000 | Avg Reward (50): 234.2 | Avg Loss (500): 0.1937 | Epsilon: 0.050
# Episode 750/2000 | Avg Reward (50): 388.0 | Avg Loss (500): 1.7823 | Epsilon: 0.050
# Episode 800/2000 | Avg Reward (50): 363.1 | Avg Loss (500): 2.4113 | Epsilon: 0.050
# Episode 850/2000 | Avg Reward (50): 491.4 | Avg Loss (500): 9.6360 | Epsilon: 0.050
# Episode 900/2000 | Avg Reward (50): 499.3 | Avg Loss (500): 8.1188 | Epsilon: 0.050
# Episode 950/2000 | Avg Reward (50): 498.4 | Avg Loss (500): 15.4232 | Epsilon: 0.050
# Episode 1000/2000 | Avg Reward (50): 492.1 | Avg Loss (500): 13.4060 | Epsilon: 0.050
# Episode 1050/2000 | Avg Reward (50): 479.3 | Avg Loss (500): 7.9607 | Epsilon: 0.050
# Episode 1100/2000 | Avg Reward (50): 498.4 | Avg Loss (500): 11.8513 | Epsilon: 0.050
# Episode 1150/2000 | Avg Reward (50): 500.0 | Avg Loss (500): 15.2566 | Epsilon: 0.050
# Episode 1200/2000 | Avg Reward (50): 500.0 | Avg Loss (500): 15.1839 | Epsilon: 0.050
# Episode 1250/2000 | Avg Reward (50): 500.0 | Avg Loss (500): 13.2631 | Epsilon: 0.050
# Episode 1300/2000 | Avg Reward (50): 500.0 | Avg Loss (500): 16.6720 | Epsilon: 0.050
# Episode 1350/2000 | Avg Reward (50): 500.0 | Avg Loss (500): 19.4864 | Epsilon: 0.050
# Episode 1400/2000 | Avg Reward (50): 500.0 | Avg Loss (500): 17.3764 | Epsilon: 0.050
# Episode 1450/2000 | Avg Reward (50): 500.0 | Avg Loss (500): 15.0415 | Epsilon: 0.050
# Episode 1500/2000 | Avg Reward (50): 457.1 | Avg Loss (500): 11.0317 | Epsilon: 0.050
# Episode 1550/2000 | Avg Reward (50): 494.4 | Avg Loss (500): 14.3751 | Epsilon: 0.050
# Episode 1600/2000 | Avg Reward (50): 494.7 | Avg Loss (500): 16.1263 | Epsilon: 0.050
# Episode 1650/2000 | Avg Reward (50): 499.0 | Avg Loss (500): 14.3706 | Epsilon: 0.050
# Episode 1700/2000 | Avg Reward (50): 497.9 | Avg Loss (500): 14.2585 | Epsilon: 0.050
# Episode 1750/2000 | Avg Reward (50): 450.6 | Avg Loss (500): 13.2190 | Epsilon: 0.050
# Episode 1800/2000 | Avg Reward (50): 478.1 | Avg Loss (500): 20.0064 | Epsilon: 0.050
# Episode 1850/2000 | Avg Reward (50): 500.0 | Avg Loss (500): 21.8295 | Epsilon: 0.050
# Episode 1900/2000 | Avg Reward (50): 498.5 | Avg Loss (500): 19.1120 | Epsilon: 0.050
# Episode 1950/2000 | Avg Reward (50): 491.7 | Avg Loss (500): 19.3779 | Epsilon: 0.050
# Episode 2000/2000 | Avg Reward (50): 471.8 | Avg Loss (500): 12.8966 | Epsilon: 0.050
# Episode 50/2000 | Avg Reward (50): 25.9 | Avg Loss (500): 1.0323 | Epsilon: 0.877
# Episode 100/2000 | Avg Reward (50): 20.3 | Avg Loss (500): 0.6937 | Epsilon: 0.780
# Episode 150/2000 | Avg Reward (50): 17.2 | Avg Loss (500): 0.7690 | Epsilon: 0.699
# Episode 200/2000 | Avg Reward (50): 14.1 | Avg Loss (500): 0.9126 | Epsilon: 0.632
# Episode 250/2000 | Avg Reward (50): 13.7 | Avg Loss (500): 1.0404 | Epsilon: 0.567
# Episode 300/2000 | Avg Reward (50): 13.8 | Avg Loss (500): 1.1827 | Epsilon: 0.501
# Episode 350/2000 | Avg Reward (50): 13.7 | Avg Loss (500): 1.2776 | Epsilon: 0.436
# Episode 400/2000 | Avg Reward (50): 19.2 | Avg Loss (500): 1.4902 | Epsilon: 0.345
# Episode 450/2000 | Avg Reward (50): 55.8 | Avg Loss (500): 2.2470 | Epsilon: 0.079
# Episode 500/2000 | Avg Reward (50): 57.9 | Avg Loss (500): 3.2843 | Epsilon: 0.050
# Episode 550/2000 | Avg Reward (50): 91.1 | Avg Loss (500): 4.2391 | Epsilon: 0.050
# Episode 600/2000 | Avg Reward (50): 164.8 | Avg Loss (500): 2.5457 | Epsilon: 0.050
# Episode 650/2000 | Avg Reward (50): 153.1 | Avg Loss (500): 1.2818 | Epsilon: 0.050
# Episode 700/2000 | Avg Reward (50): 288.4 | Avg Loss (500): 1.0499 | Epsilon: 0.050
# Episode 750/2000 | Avg Reward (50): 245.0 | Avg Loss (500): 0.4947 | Epsilon: 0.050
# Episode 800/2000 | Avg Reward (50): 267.3 | Avg Loss (500): 1.4844 | Epsilon: 0.050
# Episode 850/2000 | Avg Reward (50): 272.7 | Avg Loss (500): 3.5315 | Epsilon: 0.050
# Episode 900/2000 | Avg Reward (50): 396.8 | Avg Loss (500): 7.6101 | Epsilon: 0.050
# Episode 950/2000 | Avg Reward (50): 469.4 | Avg Loss (500): 11.6434 | Epsilon: 0.050
# Episode 1000/2000 | Avg Reward (50): 458.3 | Avg Loss (500): 13.5268 | Epsilon: 0.050
# Episode 1050/2000 | Avg Reward (50): 484.3 | Avg Loss (500): 14.4513 | Epsilon: 0.050
# Episode 1100/2000 | Avg Reward (50): 488.9 | Avg Loss (500): 20.1815 | Epsilon: 0.050
# Episode 1150/2000 | Avg Reward (50): 493.8 | Avg Loss (500): 12.6388 | Epsilon: 0.050
# Episode 1200/2000 | Avg Reward (50): 468.3 | Avg Loss (500): 14.3131 | Epsilon: 0.050
# Episode 1250/2000 | Avg Reward (50): 493.4 | Avg Loss (500): 18.9784 | Epsilon: 0.050
# Episode 1300/2000 | Avg Reward (50): 443.4 | Avg Loss (500): 15.7085 | Epsilon: 0.050
# Episode 1350/2000 | Avg Reward (50): 480.5 | Avg Loss (500): 12.6299 | Epsilon: 0.050
# Episode 1400/2000 | Avg Reward (50): 461.2 | Avg Loss (500): 18.3966 | Epsilon: 0.050
# Episode 1450/2000 | Avg Reward (50): 498.3 | Avg Loss (500): 19.9236 | Epsilon: 0.050
# Episode 1500/2000 | Avg Reward (50): 499.6 | Avg Loss (500): 19.1896 | Epsilon: 0.050
# Episode 1550/2000 | Avg Reward (50): 489.3 | Avg Loss (500): 20.4502 | Epsilon: 0.050
# Episode 1600/2000 | Avg Reward (50): 494.4 | Avg Loss (500): 15.9493 | Epsilon: 0.050
# Episode 1650/2000 | Avg Reward (50): 490.2 | Avg Loss (500): 17.6716 | Epsilon: 0.050
# Episode 1700/2000 | Avg Reward (50): 443.4 | Avg Loss (500): 24.5274 | Epsilon: 0.050
# Episode 1750/2000 | Avg Reward (50): 500.0 | Avg Loss (500): 22.2273 | Epsilon: 0.050
# Episode 1800/2000 | Avg Reward (50): 500.0 | Avg Loss (500): 23.3011 | Epsilon: 0.050
# Episode 1850/2000 | Avg Reward (50): 500.0 | Avg Loss (500): 15.2078 | Epsilon: 0.050
# Episode 1900/2000 | Avg Reward (50): 500.0 | Avg Loss (500): 18.3869 | Epsilon: 0.050
# Episode 1950/2000 | Avg Reward (50): 500.0 | Avg Loss (500): 21.5317 | Epsilon: 0.050
# Episode 2000/2000 | Avg Reward (50): 493.5 | Avg Loss (500): 13.2779 | Epsilon: 0.050
# Episode 50/2000 | Avg Reward (50): 22.1 | Avg Loss (500): 1.1172 | Epsilon: 0.895
# Episode 100/2000 | Avg Reward (50): 18.9 | Avg Loss (500): 0.7449 | Epsilon: 0.805
# Episode 150/2000 | Avg Reward (50): 19.1 | Avg Loss (500): 0.7665 | Epsilon: 0.715
# Episode 200/2000 | Avg Reward (50): 14.3 | Avg Loss (500): 1.0118 | Epsilon: 0.647
# Episode 250/2000 | Avg Reward (50): 13.8 | Avg Loss (500): 1.2305 | Epsilon: 0.581
# Episode 300/2000 | Avg Reward (50): 12.3 | Avg Loss (500): 1.4069 | Epsilon: 0.523
# Episode 350/2000 | Avg Reward (50): 12.2 | Avg Loss (500): 1.5326 | Epsilon: 0.465
# Episode 400/2000 | Avg Reward (50): 12.9 | Avg Loss (500): 1.6696 | Epsilon: 0.403
# Episode 450/2000 | Avg Reward (50): 12.2 | Avg Loss (500): 1.8471 | Epsilon: 0.345
# Episode 500/2000 | Avg Reward (50): 44.7 | Avg Loss (500): 2.3656 | Epsilon: 0.133
# Episode 550/2000 | Avg Reward (50): 53.3 | Avg Loss (500): 3.2968 | Epsilon: 0.050
# Episode 600/2000 | Avg Reward (50): 51.2 | Avg Loss (500): 4.8159 | Epsilon: 0.050
# Episode 650/2000 | Avg Reward (50): 71.2 | Avg Loss (500): 5.9383 | Epsilon: 0.050
# Episode 700/2000 | Avg Reward (50): 169.2 | Avg Loss (500): 2.0714 | Epsilon: 0.050
# Episode 750/2000 | Avg Reward (50): 313.4 | Avg Loss (500): 0.8632 | Epsilon: 0.050
# Episode 800/2000 | Avg Reward (50): 282.0 | Avg Loss (500): 0.9361 | Epsilon: 0.050
# Episode 850/2000 | Avg Reward (50): 368.9 | Avg Loss (500): 2.6971 | Epsilon: 0.050
# Episode 900/2000 | Avg Reward (50): 425.7 | Avg Loss (500): 3.9499 | Epsilon: 0.050
# Episode 950/2000 | Avg Reward (50): 476.0 | Avg Loss (500): 9.0557 | Epsilon: 0.050
# Episode 1000/2000 | Avg Reward (50): 500.0 | Avg Loss (500): 15.6730 | Epsilon: 0.050
# Episode 1050/2000 | Avg Reward (50): 500.0 | Avg Loss (500): 21.0612 | Epsilon: 0.050
# Episode 1100/2000 | Avg Reward (50): 499.0 | Avg Loss (500): 18.3069 | Epsilon: 0.050
# Episode 1150/2000 | Avg Reward (50): 499.3 | Avg Loss (500): 10.6445 | Epsilon: 0.050
# Episode 1200/2000 | Avg Reward (50): 493.7 | Avg Loss (500): 15.0689 | Epsilon: 0.050
# Episode 1250/2000 | Avg Reward (50): 481.3 | Avg Loss (500): 11.4223 | Epsilon: 0.050
# Episode 1300/2000 | Avg Reward (50): 500.0 | Avg Loss (500): 19.6492 | Epsilon: 0.050
# Episode 1350/2000 | Avg Reward (50): 500.0 | Avg Loss (500): 15.7934 | Epsilon: 0.050
# Episode 1400/2000 | Avg Reward (50): 500.0 | Avg Loss (500): 18.0414 | Epsilon: 0.050
# Episode 1450/2000 | Avg Reward (50): 500.0 | Avg Loss (500): 20.2898 | Epsilon: 0.050
# Episode 1500/2000 | Avg Reward (50): 500.0 | Avg Loss (500): 18.3181 | Epsilon: 0.050
# Episode 1550/2000 | Avg Reward (50): 500.0 | Avg Loss (500): 18.8481 | Epsilon: 0.050
# Episode 1600/2000 | Avg Reward (50): 499.4 | Avg Loss (500): 11.6959 | Epsilon: 0.050
# Episode 1650/2000 | Avg Reward (50): 500.0 | Avg Loss (500): 18.5198 | Epsilon: 0.050
# Episode 1700/2000 | Avg Reward (50): 499.2 | Avg Loss (500): 21.4992 | Epsilon: 0.050
# Episode 1750/2000 | Avg Reward (50): 500.0 | Avg Loss (500): 18.2233 | Epsilon: 0.050
# Episode 1800/2000 | Avg Reward (50): 500.0 | Avg Loss (500): 19.4357 | Epsilon: 0.050
# Episode 1850/2000 | Avg Reward (50): 500.0 | Avg Loss (500): 18.3566 | Epsilon: 0.050
# Episode 1900/2000 | Avg Reward (50): 500.0 | Avg Loss (500): 21.7122 | Epsilon: 0.050
# Episode 1950/2000 | Avg Reward (50): 500.0 | Avg Loss (500): 16.7301 | Epsilon: 0.050
# Episode 2000/2000 | Avg Reward (50): 500.0 | Avg Loss (500): 19.9587 | Epsilon: 0.050
#
# Training with epsilon_decay=50000...
# Episode 50/2000 | Avg Reward (50): 22.7 | Avg Loss (500): 0.9957 | Epsilon: 0.978
# Episode 100/2000 | Avg Reward (50): 20.2 | Avg Loss (500): 0.6251 | Epsilon: 0.959
# Episode 150/2000 | Avg Reward (50): 17.6 | Avg Loss (500): 0.6196 | Epsilon: 0.943
# Episode 200/2000 | Avg Reward (50): 21.1 | Avg Loss (500): 0.8427 | Epsilon: 0.922
# Episode 250/2000 | Avg Reward (50): 20.9 | Avg Loss (500): 1.0579 | Epsilon: 0.903
# Episode 300/2000 | Avg Reward (50): 18.8 | Avg Loss (500): 1.1812 | Epsilon: 0.885
# Episode 350/2000 | Avg Reward (50): 24.8 | Avg Loss (500): 1.5364 | Epsilon: 0.861
# Episode 400/2000 | Avg Reward (50): 28.2 | Avg Loss (500): 1.9314 | Epsilon: 0.835
# Episode 450/2000 | Avg Reward (50): 33.4 | Avg Loss (500): 2.5708 | Epsilon: 0.803
# Episode 500/2000 | Avg Reward (50): 34.6 | Avg Loss (500): 3.4001 | Epsilon: 0.770
# Episode 550/2000 | Avg Reward (50): 40.8 | Avg Loss (500): 4.6531 | Epsilon: 0.731
# Episode 600/2000 | Avg Reward (50): 51.1 | Avg Loss (500): 5.8748 | Epsilon: 0.683
# Episode 650/2000 | Avg Reward (50): 74.4 | Avg Loss (500): 7.4515 | Epsilon: 0.612
# Episode 700/2000 | Avg Reward (50): 90.5 | Avg Loss (500): 8.5372 | Epsilon: 0.526
# Episode 750/2000 | Avg Reward (50): 169.2 | Avg Loss (500): 8.7678 | Epsilon: 0.365
# Episode 800/2000 | Avg Reward (50): 293.9 | Avg Loss (500): 3.4826 | Epsilon: 0.086
# Episode 850/2000 | Avg Reward (50): 277.5 | Avg Loss (500): 0.7778 | Epsilon: 0.050
# Episode 900/2000 | Avg Reward (50): 261.7 | Avg Loss (500): 0.0917 | Epsilon: 0.050
# Episode 950/2000 | Avg Reward (50): 245.0 | Avg Loss (500): 0.0335 | Epsilon: 0.050
# Episode 1000/2000 | Avg Reward (50): 233.3 | Avg Loss (500): 0.0347 | Epsilon: 0.050
# Episode 1050/2000 | Avg Reward (50): 223.0 | Avg Loss (500): 0.3610 | Epsilon: 0.050
# Episode 1100/2000 | Avg Reward (50): 210.9 | Avg Loss (500): 0.0294 | Epsilon: 0.050
# Episode 1150/2000 | Avg Reward (50): 259.2 | Avg Loss (500): 0.0286 | Epsilon: 0.050
# Episode 1200/2000 | Avg Reward (50): 394.4 | Avg Loss (500): 4.7242 | Epsilon: 0.050
# Episode 1250/2000 | Avg Reward (50): 448.4 | Avg Loss (500): 4.4214 | Epsilon: 0.050
# Episode 1300/2000 | Avg Reward (50): 481.0 | Avg Loss (500): 7.1410 | Epsilon: 0.050
# Episode 1350/2000 | Avg Reward (50): 492.7 | Avg Loss (500): 9.6645 | Epsilon: 0.050
# Episode 1400/2000 | Avg Reward (50): 497.3 | Avg Loss (500): 16.2995 | Epsilon: 0.050
# Episode 1450/2000 | Avg Reward (50): 494.7 | Avg Loss (500): 12.7869 | Epsilon: 0.050
# Episode 1500/2000 | Avg Reward (50): 496.6 | Avg Loss (500): 17.3744 | Epsilon: 0.050
# Episode 1550/2000 | Avg Reward (50): 496.9 | Avg Loss (500): 18.1203 | Epsilon: 0.050
# Episode 1600/2000 | Avg Reward (50): 500.0 | Avg Loss (500): 18.1342 | Epsilon: 0.050
# Episode 1650/2000 | Avg Reward (50): 500.0 | Avg Loss (500): 16.4886 | Epsilon: 0.050
# Episode 1700/2000 | Avg Reward (50): 498.7 | Avg Loss (500): 15.9882 | Epsilon: 0.050
# Episode 1750/2000 | Avg Reward (50): 500.0 | Avg Loss (500): 17.1340 | Epsilon: 0.050
# Episode 1800/2000 | Avg Reward (50): 486.9 | Avg Loss (500): 10.7109 | Epsilon: 0.050
# Episode 1850/2000 | Avg Reward (50): 500.0 | Avg Loss (500): 14.6839 | Epsilon: 0.050
# Episode 1900/2000 | Avg Reward (50): 500.0 | Avg Loss (500): 18.3581 | Epsilon: 0.050
# Episode 1950/2000 | Avg Reward (50): 500.0 | Avg Loss (500): 14.0772 | Epsilon: 0.050
# Episode 2000/2000 | Avg Reward (50): 500.0 | Avg Loss (500): 13.9022 | Epsilon: 0.050
# Episode 50/2000 | Avg Reward (50): 21.6 | Avg Loss (500): 1.2322 | Epsilon: 0.979
# Episode 100/2000 | Avg Reward (50): 23.4 | Avg Loss (500): 0.6962 | Epsilon: 0.957
# Episode 150/2000 | Avg Reward (50): 22.1 | Avg Loss (500): 0.7499 | Epsilon: 0.936
# Episode 200/2000 | Avg Reward (50): 19.1 | Avg Loss (500): 1.0087 | Epsilon: 0.918
# Episode 250/2000 | Avg Reward (50): 20.0 | Avg Loss (500): 1.2398 | Epsilon: 0.899
# Episode 300/2000 | Avg Reward (50): 25.7 | Avg Loss (500): 1.5097 | Epsilon: 0.875
# Episode 350/2000 | Avg Reward (50): 36.0 | Avg Loss (500): 2.1607 | Epsilon: 0.840
# Episode 400/2000 | Avg Reward (50): 29.8 | Avg Loss (500): 2.6010 | Epsilon: 0.812
# Episode 450/2000 | Avg Reward (50): 37.5 | Avg Loss (500): 3.5613 | Epsilon: 0.777
# Episode 500/2000 | Avg Reward (50): 33.3 | Avg Loss (500): 4.8156 | Epsilon: 0.745
# Episode 550/2000 | Avg Reward (50): 36.2 | Avg Loss (500): 6.2121 | Epsilon: 0.710
# Episode 600/2000 | Avg Reward (50): 51.0 | Avg Loss (500): 8.2110 | Epsilon: 0.662
# Episode 650/2000 | Avg Reward (50): 78.7 | Avg Loss (500): 10.0237 | Epsilon: 0.587
# Episode 700/2000 | Avg Reward (50): 108.1 | Avg Loss (500): 10.4227 | Epsilon: 0.485
# Episode 750/2000 | Avg Reward (50): 236.7 | Avg Loss (500): 9.2998 | Epsilon: 0.260
# Episode 800/2000 | Avg Reward (50): 208.0 | Avg Loss (500): 6.3755 | Epsilon: 0.062
# Episode 850/2000 | Avg Reward (50): 236.7 | Avg Loss (500): 1.8639 | Epsilon: 0.050
# Episode 900/2000 | Avg Reward (50): 297.2 | Avg Loss (500): 3.2805 | Epsilon: 0.050
# Episode 950/2000 | Avg Reward (50): 286.9 | Avg Loss (500): 0.7357 | Epsilon: 0.050
# Episode 1000/2000 | Avg Reward (50): 218.8 | Avg Loss (500): 0.4721 | Epsilon: 0.050
# Episode 1050/2000 | Avg Reward (50): 198.9 | Avg Loss (500): 0.1303 | Epsilon: 0.050
# Episode 1100/2000 | Avg Reward (50): 297.2 | Avg Loss (500): 2.5016 | Epsilon: 0.050
# Episode 1150/2000 | Avg Reward (50): 343.3 | Avg Loss (500): 3.1877 | Epsilon: 0.050
# Episode 1200/2000 | Avg Reward (50): 387.5 | Avg Loss (500): 0.5816 | Epsilon: 0.050
# Episode 1250/2000 | Avg Reward (50): 444.4 | Avg Loss (500): 6.1099 | Epsilon: 0.050
# Episode 1300/2000 | Avg Reward (50): 473.4 | Avg Loss (500): 10.4186 | Epsilon: 0.050
# Episode 1350/2000 | Avg Reward (50): 493.2 | Avg Loss (500): 10.3542 | Epsilon: 0.050
# Episode 1400/2000 | Avg Reward (50): 493.6 | Avg Loss (500): 12.3970 | Epsilon: 0.050
# Episode 1450/2000 | Avg Reward (50): 498.1 | Avg Loss (500): 19.2904 | Epsilon: 0.050
# Episode 1500/2000 | Avg Reward (50): 500.0 | Avg Loss (500): 18.9416 | Epsilon: 0.050
# Episode 1550/2000 | Avg Reward (50): 500.0 | Avg Loss (500): 18.5201 | Epsilon: 0.050
# Episode 1600/2000 | Avg Reward (50): 500.0 | Avg Loss (500): 18.0124 | Epsilon: 0.050
# Episode 1650/2000 | Avg Reward (50): 499.9 | Avg Loss (500): 17.8590 | Epsilon: 0.050
# Episode 1700/2000 | Avg Reward (50): 500.0 | Avg Loss (500): 17.4662 | Epsilon: 0.050
# Episode 1750/2000 | Avg Reward (50): 500.0 | Avg Loss (500): 19.5099 | Epsilon: 0.050
# Episode 1800/2000 | Avg Reward (50): 500.0 | Avg Loss (500): 20.5981 | Epsilon: 0.050
# Episode 1850/2000 | Avg Reward (50): 500.0 | Avg Loss (500): 17.4856 | Epsilon: 0.050
# Episode 1900/2000 | Avg Reward (50): 500.0 | Avg Loss (500): 22.2375 | Epsilon: 0.050
# Episode 1950/2000 | Avg Reward (50): 500.0 | Avg Loss (500): 21.2458 | Epsilon: 0.050
# Episode 2000/2000 | Avg Reward (50): 500.0 | Avg Loss (500): 20.5468 | Epsilon: 0.050
# Episode 50/2000 | Avg Reward (50): 24.8 | Avg Loss (500): 1.0324 | Epsilon: 0.976
# Episode 100/2000 | Avg Reward (50): 21.9 | Avg Loss (500): 0.7288 | Epsilon: 0.956
# Episode 150/2000 | Avg Reward (50): 22.3 | Avg Loss (500): 0.8296 | Epsilon: 0.934
# Episode 200/2000 | Avg Reward (50): 21.3 | Avg Loss (500): 1.1136 | Epsilon: 0.914
# Episode 250/2000 | Avg Reward (50): 22.3 | Avg Loss (500): 1.4340 | Epsilon: 0.893
# Episode 300/2000 | Avg Reward (50): 21.5 | Avg Loss (500): 1.7592 | Epsilon: 0.873
# Episode 350/2000 | Avg Reward (50): 22.7 | Avg Loss (500): 2.1684 | Epsilon: 0.851
# Episode 400/2000 | Avg Reward (50): 31.1 | Avg Loss (500): 2.6368 | Epsilon: 0.822
# Episode 450/2000 | Avg Reward (50): 33.6 | Avg Loss (500): 3.2002 | Epsilon: 0.790
# Episode 500/2000 | Avg Reward (50): 33.1 | Avg Loss (500): 3.9860 | Epsilon: 0.758
# Episode 550/2000 | Avg Reward (50): 39.6 | Avg Loss (500): 5.4394 | Epsilon: 0.721
# Episode 600/2000 | Avg Reward (50): 44.0 | Avg Loss (500): 7.1693 | Epsilon: 0.679
# Episode 650/2000 | Avg Reward (50): 53.1 | Avg Loss (500): 9.0647 | Epsilon: 0.628
# Episode 700/2000 | Avg Reward (50): 94.3 | Avg Loss (500): 10.8670 | Epsilon: 0.539
# Episode 750/2000 | Avg Reward (50): 162.3 | Avg Loss (500): 8.6984 | Epsilon: 0.384
# Episode 800/2000 | Avg Reward (50): 323.0 | Avg Loss (500): 2.4573 | Epsilon: 0.078
# Episode 850/2000 | Avg Reward (50): 336.6 | Avg Loss (500): 1.4622 | Epsilon: 0.050
# Episode 900/2000 | Avg Reward (50): 354.9 | Avg Loss (500): 1.8106 | Epsilon: 0.050
# Episode 950/2000 | Avg Reward (50): 455.5 | Avg Loss (500): 8.5640 | Epsilon: 0.050
# Episode 1000/2000 | Avg Reward (50): 469.9 | Avg Loss (500): 7.5482 | Epsilon: 0.050
# Episode 1050/2000 | Avg Reward (50): 495.8 | Avg Loss (500): 18.1989 | Epsilon: 0.050
# Episode 1100/2000 | Avg Reward (50): 497.5 | Avg Loss (500): 19.2522 | Epsilon: 0.050
# Episode 1150/2000 | Avg Reward (50): 497.5 | Avg Loss (500): 20.7320 | Epsilon: 0.050
# Episode 1200/2000 | Avg Reward (50): 500.0 | Avg Loss (500): 18.1310 | Epsilon: 0.050
# Episode 1250/2000 | Avg Reward (50): 500.0 | Avg Loss (500): 18.1470 | Epsilon: 0.050
# Episode 1300/2000 | Avg Reward (50): 500.0 | Avg Loss (500): 19.9778 | Epsilon: 0.050
# Episode 1350/2000 | Avg Reward (50): 500.0 | Avg Loss (500): 21.1272 | Epsilon: 0.050
# Episode 1400/2000 | Avg Reward (50): 500.0 | Avg Loss (500): 15.4607 | Epsilon: 0.050
# Episode 1450/2000 | Avg Reward (50): 500.0 | Avg Loss (500): 16.1956 | Epsilon: 0.050
# Episode 1500/2000 | Avg Reward (50): 500.0 | Avg Loss (500): 18.5081 | Epsilon: 0.050
# Episode 1550/2000 | Avg Reward (50): 500.0 | Avg Loss (500): 17.1872 | Epsilon: 0.050
# Episode 1600/2000 | Avg Reward (50): 500.0 | Avg Loss (500): 18.3920 | Epsilon: 0.050
# Episode 1650/2000 | Avg Reward (50): 500.0 | Avg Loss (500): 16.7681 | Epsilon: 0.050
# Episode 1700/2000 | Avg Reward (50): 500.0 | Avg Loss (500): 19.6066 | Epsilon: 0.050
# Episode 1750/2000 | Avg Reward (50): 500.0 | Avg Loss (500): 22.1302 | Epsilon: 0.050
# Episode 1800/2000 | Avg Reward (50): 500.0 | Avg Loss (500): 16.1761 | Epsilon: 0.050
# Episode 1850/2000 | Avg Reward (50): 500.0 | Avg Loss (500): 21.6952 | Epsilon: 0.050
# Episode 1900/2000 | Avg Reward (50): 500.0 | Avg Loss (500): 20.4047 | Epsilon: 0.050
# Episode 1950/2000 | Avg Reward (50): 500.0 | Avg Loss (500): 16.9805 | Epsilon: 0.050
# Episode 2000/2000 | Avg Reward (50): 496.0 | Avg Loss (500): 14.8242 | Epsilon: 0.050
#
# ============================================================
# Final Performance (last 100 episodes):
# ============================================================
# Epsilon Decay 1000: 500.0 ± 0.0
# Epsilon Decay 5000: 497.7 ± 2.5
# Epsilon Decay 10000: 492.8 ± 8.0
# Epsilon Decay 50000: 499.3 ± 1.0
# Plot saved: c:\Users\Jensw\Desktop\tdde78lab\labs\lab1_value_based\experiments\plots\epsilon_decay_ablation_on_cartpole-v1.png

# %% [markdown]
# ---
#
# ## Summary
#
# 1. What are the two key components that make DQN stable (vs naive Q-learning with neural networks)?
#
# Key factors are:
#
# The use of a replay buffer to break correlations in data to mitigate unstable learning.
#
# Updating the target network slower, in Q-learning the target is always based on current state but in DQN we use a separate target network that is updated less frequently, so the targets stay more stable instead of constantly changing with the main network (network trained every step).
#
#
# 2. When does Double DQN help the most? When does it not matter?
#
# Double DQN is more suitable for more complex environments where Q-values tend to be overestimated. Overestimation happens when the max operator in Q-learning selects the highest estimated Q-value, which can be too high due to noise or estimation errors.
#
# It matters less in simple or deterministic environments, where overestimation is smaller
#
# 3. What is the benefit of the Dueling architecture, and on which environment did it help most?
#
# The beenfit is that we sepparate how "good" a state is from wich action is the "best". Looking at the data ouptputs from the CartPole vs LunarLander:¨
#
# CartPole:
# DQN: 499.3 ± 1.0
# Double DQN: 500.0 ± 0.0
# Dueling DQN: 467.8 ± 42.9
#
# LunarLander:
# DQN: 212.2 ± 37.2
# Double DQN: 213.2 ± 20.6
# Dueling DQN: 223.2 ± 13.3
#
# we see that use of Dueling DQN actualy worsens the score for the CartPole problem, but for LunarLander we get a slightly better score. So the use of Double DQN helped the most for the LunarLander enviorment.
#
# 4. Which hyperparameter (buffer size, target update frequency, epsilon decay) had the largest impact on performance, and why?
#
# ## Buffer Size:
# ![image.png](attachment:image.png)
#
# ## Target update frequency:
# ![image-2.png](attachment:image-2.png)
#
# ## Epsilon decay:
# ![image-3.png](attachment:image-3.png)
#
# It seems buffer size had the largest impact on performance, having to lage of a buffer after a certain pont makes the score decrease dramatically. This is because the buffer stores too many old experiences, so the model keeps learning from outdated data which slows learning and makes training less stable
#
# 5. What would you investigate next if you had more time?

# %% [markdown]
# ---
#
# **Lab designed by Amath Sow:** amath.sow@liu.se
#
# **TDDE78 — Deep Reinforcement Learning, Linköping University, Spring 2026**
